# %% [markdown]
# ## Coches de Segunda Mano - Limpieza y Análisis
#
# Para este ejercicio vamos a usar el archivo llamado _**coches_segunda_mano.csv**_, usaremos **pandas** para leer el archivo en Python y tenerlo como **pd.DataFrame**:
#
# El **Dataframe** está compuesto por las siguiente columnas y tipos de datos:
#
# |Columna                 |Descripción                                         |dtype     |Procesar|
# |------------------------|----------------------------------------------------|----------|--------|
# |**fecha_matriculacion** |Fecha de matriculación del coche.                   |**string**|_Si_    |
# |**tipo_combustible**    |Tipo de combustible.                                |**string**|No      |
# |**kilometros**          |Kilometraje del coche.                              |**string**|_Si_    |
# |**tipo_carroceria**     |Tipo de carroceria del coche.                       |**string**|No      |
# |**tipo_cambio**         |Tipo de cambio del coche.                           |**string**|No      |
# |**potencia_cv**         |Potencia del coche en caballos de vapor.            |**float** |No      |
# |**garantia**            |Duración de la garantía del coche en meses.         |**string**|_Si_    |
# |**distintivo_ambiental**|Etiqueta de Distintivo Ambiental.                   |**string**|No      |
# |**precio**              |Precio del coche.                                   |**string**|_Si_    |
# |**peso_masa_kg**        |Peso del coche en kilogramos.                       |**float** |No      |
# |**puertas**             |Número de puertas.                                  |**float** |No      |
# |**plazas**              |Número de plazas/asientos del coche.                |**float** |No      |
# |**cilindros**           |Número de cilindros del coche.                      |**float** |No      |
# |**co2**                 |Emisiones de CO2 en g/km.                           |**string**|_Si_    |
# |**deposito**            |Tamaño del deposito de gasolina del coche el litros.|**string**|_Si_    |
#
#
# El ejercicio será dividido en dos partes: **Limpieza** y **Análisis**.
#
# ### 01. Limpieza
#
# En esta parte nos enfocaremos en limpiar y transformar algunas columnas que tienen tipo de datos incorrecto o tienen valores erroneos:
#
# 0. Lee el archivo con **pandas**, usaremos **df** como nombre para la variable del **DataFrame**.
# ---
# 1. Transforma la columna de _**kilometros**_ a tipo **float**:
#     - _Ejemplo_: '2.500 km' $\longrightarrow$ 2500.0
#     - Si existe algun elemento que no se pueda transformar a número reemplazalo por **np.nan**.
#     - Reemplaza los **np.nan** por la media de todos los valores de esta columna.
# ---
# 2. Transforma la columna de _**precio**_ a tipo **float**:
#     - _Ejemplo_: '33.400 €' $\longrightarrow$ 33400.0
#     - Si existe algun elemento que no se pueda transformar a número reemplazalo por **np.nan**.
#     - Reemplaza los **np.nan** por la media de todos los valores de esta columna.
# ---
# 3. Transforma la columna de _**deposito**_ a tipo **float**:
#     - _Ejemplo_: '35,00' $\longrightarrow$ 35.0
#     - Si existe algun elemento que no se pueda transformar a número reemplazalo por **np.nan**.
#     - Reemplaza los **np.nan** por la media de todos los valores de esta columna.
# ---
# 4. Transforma la columna de _**co2**_ a tipo **float**:
#     - _Ejemplo_: '139' $\longrightarrow$ 139.0
#     - Si existe algun elemento que no se pueda transformar a número reemplazalo por **np.nan**.
#     - Reemplaza los **np.nan** por la media de todos los valores de esta columna.
# ---
# 5. Separa la columna de _**fecha_matriculacion**_ en 2 columnas: _**month**_ y _**year**_
#     - Columna _**month**_ a tipo _**int**_:
#         - _Ejemplo_: '05/2023' $\longrightarrow$ 5
#     - Columna _**year**_ a tipo _**int**_:
#         - _Ejemplo_: '05/2023' $\longrightarrow$ 2023
#     - Elimina la columna _**fecha_matriculacion**_ del **DataFrame**.
# ---
# 6. Columna _**garantia**_:
#     - Elimina la palabra "meses" de todos los elementos que contengan esa cadena. Transforma esos elementos a tipo **float**.
#     - Reemplaza a **0** los elementos que sean igual a **"No"**.
#     - Reemplaza a **np.nan** los elementos que sean igual a **"Sí"**.
#     - Reemplaza los **np.nan** por la media de todos los valores de esta columna.
# ---
# 7. Guarda el **DataFrame** en un archivo **.csv** usando la siguiente linea de código:
# ```python
# df.to_csv("coches_segunda_mano_limpio.csv", index = False)
# ```
#
# **El resultado final debe ser un pd.DataFrame con 71218 filas y 16 columnas.**

# %% [markdown]
# **RESOLUCIÓN:**
#
# Empezamos, como siempre, importando las librerías con las que vamos a trabajar en este ejercicio:

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# 0. Lee el archivo con **pandas**, usaremos **df** como nombre para la variable del **DataFrame**.

# %%
df = pd.read_csv("coches_segunda_mano.csv")

df.head(3)
# Out:
#   fecha_matriculacion tipo_combustible kilometros tipo_carroceria tipo_cambio  \
# 0             05/2023         Gasolina      10 km         Berlina      Manual
# 1             06/2023         Gasolina      10 km         Berlina      Manual
# 2             12/2023         Gasolina      15 km         Berlina      Manual
#
#    potencia_cv  garantia distintivo_ambiental    precio  peso_masa_kg  \
# 0        140.0  36 meses                    C  33.400 €        1425.0
# 1        140.0  36 meses                    C  33.900 €        1425.0
# 2        165.0  36 meses                    C  27.200 €        1425.0
#
#    puertas  plazas  cilindros  co2 deposito
# 0      3.0     4.0        4.0  139    35,00
# 1      3.0     4.0        4.0  139    35,00
# 2      3.0     4.0        4.0    -    35,00

# %% [markdown]
# 1. Transforma la columna de _**kilometros**_ a tipo **float**:
#     - _Ejemplo_: '2.500 km' $\longrightarrow$ 2500.0
#     - Si existe algun elemento que no se pueda transformar a número reemplazalo por **np.nan**.
#     - Reemplaza los **np.nan** por la media de todos los valores de esta columna.

# %% [markdown]
# Para poder buscar y reemplazar un determinado string en nuestra columna tenemos el atributo *.str.replace()*, el cual toma como primer parámetro los caracteres que buscamos y como segundo parámetro por lo que lo queremos sustituir. En este caso, como quiero sólo eliminarlos simplemente pongo un string vacío como segundo parámetro.
#
# A continuación, recasteo mi columna entera a tipo float con el atributo *.astype()*.
#
# Para guardar estos cambios en mi dataframe es necesario asignarle a cada línea de código la serie donde quiero que se produzcan los cambios, que en mi caso es la columna df["kilometros"].

# %%
df["kilometros"] = df["kilometros"].str.replace('.', '')

df["kilometros"] = df["kilometros"].str.replace(' km', '')

df["kilometros"] = df["kilometros"].astype(float)

df["kilometros"]
# Out:
# 0           10.0
# 1           10.0
# 2           15.0
# 3           50.0
# 4         2500.0
#           ...
# 71213    99000.0
# 71214    26761.0
# 71215    66070.0
# 71216    31800.0
# 71217    39700.0
# Name: kilometros, Length: 71218, dtype: float64

# %% [markdown]
# Esta columna de nuestro data frame no posee ningún NaN, por lo que no hizo falta remplazar ningún valor.

# %% [markdown]
# 2. Transforma la columna de _**precio**_ a tipo **float**:
#     - _Ejemplo_: '33.400 €' $\longrightarrow$ 33400.0
#     - Si existe algun elemento que no se pueda transformar a número reemplazalo por **np.nan**.
#     - Reemplaza los **np.nan** por la media de todos los valores de esta columna.

# %% [markdown]
# Para este ejercicio realizaremos el mismo proceddemiento que en el ejercicio anterior:

# %%
df["precio"] = df["precio"].str.replace('.', '')

df["precio"] = df["precio"].str.replace(' €', '')

df["precio"] = df["precio"].astype(float)

df["precio"]
# Out:
# 0        33400.0
# 1        33900.0
# 2        27200.0
# 3        38900.0
# 4        29850.0
#           ...
# 71213    51490.0
# 71214    68900.0
# 71215    67900.0
# 71216    61500.0
# 71217    59890.0
# Name: precio, Length: 71218, dtype: float64

# %% [markdown]
# Esta columna de nuestro data frame no posee ningún NaN, por lo que no hizo falta remplazar ningún valor.

# %% [markdown]
# 3. Transforma la columna de _**deposito**_ a tipo **float**:
#     - _Ejemplo_: '35,00' $\longrightarrow$ 35.0
#     - Si existe algun elemento que no se pueda transformar a número reemplazalo por **np.nan**.
#     - Reemplaza los **np.nan** por la media de todos los valores de esta columna.

# %% [markdown]
# De nuevo, realizamos el mismo procedimiento que en el ejercicio anterior:

# %%
df["deposito"] = df["deposito"].str.replace(',', '.')

df["deposito"] = df["deposito"].astype(float)

df["deposito"]
# Out:
# 0        35.0
# 1        35.0
# 2        35.0
# 3        35.0
# 4        35.0
#          ...
# 71213    70.0
# 71214    70.0
# 71215    70.0
# 71216    70.0
# 71217    70.0
# Name: deposito, Length: 71218, dtype: float64

# %% [markdown]
# Esta columna de nuestro data frame no posee ningún NaN, por lo que no hizo falta remplazar ningún valor.

# %% [markdown]
# 4. Transforma la columna de _**co2**_ a tipo **float**:
#     - _Ejemplo_: '139' $\longrightarrow$ 139.0
#     - Si existe algun elemento que no se pueda transformar a número reemplazalo por **np.nan**.
#     - Reemplaza los **np.nan** por la media de todos los valores de esta columna.

# %% [markdown]
# Como podemos observar, esta columna sí que posee NaNs, aunque Python de momento no los considera como tal porque lo toma como otro de los valores string de los que está compuesta nuestra columna de co2:

# %%
df.head(5)
# Out:
#   fecha_matriculacion tipo_combustible  kilometros tipo_carroceria  \
# 0             05/2023         Gasolina        10.0         Berlina
# 1             06/2023         Gasolina        10.0         Berlina
# 2             12/2023         Gasolina        15.0         Berlina
# 3             01/2024         Gasolina        50.0         Berlina
# 4             05/2023         Gasolina      2500.0         Berlina
#
#   tipo_cambio  potencia_cv  garantia distintivo_ambiental   precio  \
# 0      Manual        140.0  36 meses                    C  33400.0
# 1      Manual        140.0  36 meses                    C  33900.0
# 2      Manual        165.0  36 meses                    C  27200.0
# 3      Manual        180.0  12 meses                    C  38900.0
# 4  Automático        180.0  36 meses                    C  29850.0
#
#    peso_masa_kg  puertas  plazas  cilindros  co2  deposito
# 0        1425.0      3.0     4.0        4.0  139      35.0
# 1        1425.0      3.0     4.0        4.0  139      35.0
# 2        1425.0      3.0     4.0        4.0    -      35.0
# 3        1545.0      3.0     4.0        4.0    -      35.0
# 4        1545.0      3.0     4.0        4.0    -      35.0

# %% [markdown]
# Como tenemos elementos que no se pueden transformar en números, en este caso se trata de strings "-", procederemos a tranformarlos en np.nan mediante el atributo *.replace()*, que  es similar al *.str.replace()* sólo que este sí que permite como parámetros varios tipos de valores aparte del string.

# %%
df["co2"] = df["co2"].replace("-", np.nan)

# %%
df.head(5)
# Out:
#   fecha_matriculacion tipo_combustible  kilometros tipo_carroceria  \
# 0             05/2023         Gasolina        10.0         Berlina
# 1             06/2023         Gasolina        10.0         Berlina
# 2             12/2023         Gasolina        15.0         Berlina
# 3             01/2024         Gasolina        50.0         Berlina
# 4             05/2023         Gasolina      2500.0         Berlina
#
#   tipo_cambio  potencia_cv  garantia distintivo_ambiental   precio  \
# 0      Manual        140.0  36 meses                    C  33400.0
# 1      Manual        140.0  36 meses                    C  33900.0
# 2      Manual        165.0  36 meses                    C  27200.0
# 3      Manual        180.0  12 meses                    C  38900.0
# 4  Automático        180.0  36 meses                    C  29850.0
#
#    peso_masa_kg  puertas  plazas  cilindros  co2  deposito
# 0        1425.0      3.0     4.0        4.0  139      35.0
# 1        1425.0      3.0     4.0        4.0  139      35.0
# 2        1425.0      3.0     4.0        4.0  NaN      35.0
# 3        1545.0      3.0     4.0        4.0  NaN      35.0
# 4        1545.0      3.0     4.0        4.0  NaN      35.0

# %% [markdown]
# Ahora que Python ya reconoce estos valores como tipo NaN, podemos hacer una suma de estos:

# %%
df.isna().sum()
# Out:
# fecha_matriculacion         0
# tipo_combustible            0
# kilometros                  0
# tipo_carroceria             0
# tipo_cambio                 0
# potencia_cv                 0
# garantia                    0
# distintivo_ambiental        0
# precio                      0
# peso_masa_kg                0
# puertas                     0
# plazas                      0
# cilindros                   0
# co2                     15630
# deposito                    0
# dtype: int64

# %% [markdown]
# Como podemos ver, ahora nuestra columna de *co2* contiene 15630 NaNs, por lo que debemos asignarle un valor a cada uno de ellos, el cual será el promedio de toda la columna. Pero primero recastearemos nuestra columna a tipo float:

# %%
df["co2"] = df["co2"].astype(float)

df["co2"]
# Out:
# 0        139.0
# 1        139.0
# 2          NaN
# 3          NaN
# 4          NaN
#          ...
# 71213     48.0
# 71214     48.0
# 71215     48.0
# 71216     48.0
# 71217     48.0
# Name: co2, Length: 71218, dtype: float64

# %%
df["co2"] = df["co2"].fillna(df["co2"].mean())

df["co2"]
# Out:
# 0        139.000000
# 1        139.000000
# 2        129.957545
# 3        129.957545
# 4        129.957545
#             ...
# 71213     48.000000
# 71214     48.000000
# 71215     48.000000
# 71216     48.000000
# 71217     48.000000
# Name: co2, Length: 71218, dtype: float64

# %%
df.head(5)
# Out:
#   fecha_matriculacion tipo_combustible  kilometros tipo_carroceria  \
# 0             05/2023         Gasolina        10.0         Berlina
# 1             06/2023         Gasolina        10.0         Berlina
# 2             12/2023         Gasolina        15.0         Berlina
# 3             01/2024         Gasolina        50.0         Berlina
# 4             05/2023         Gasolina      2500.0         Berlina
#
#   tipo_cambio  potencia_cv  garantia distintivo_ambiental   precio  \
# 0      Manual        140.0  36 meses                    C  33400.0
# 1      Manual        140.0  36 meses                    C  33900.0
# 2      Manual        165.0  36 meses                    C  27200.0
# 3      Manual        180.0  12 meses                    C  38900.0
# 4  Automático        180.0  36 meses                    C  29850.0
#
#    peso_masa_kg  puertas  plazas  cilindros         co2  deposito
# 0        1425.0      3.0     4.0        4.0  139.000000      35.0
# 1        1425.0      3.0     4.0        4.0  139.000000      35.0
# 2        1425.0      3.0     4.0        4.0  129.957545      35.0
# 3        1545.0      3.0     4.0        4.0  129.957545      35.0
# 4        1545.0      3.0     4.0        4.0  129.957545      35.0

# %% [markdown]
# Finalmente, todos esos NaNs que hemos reemplazado son ahora un float con el valor del promedio de la columna, que es 129.

# %% [markdown]
# 5. Separa la columna de _**fecha_matriculacion**_ en 2 columnas: _**month**_ y _**year**_
#     - Columna _**month**_ a tipo _**int**_:
#         - _Ejemplo_: '05/2023' $\longrightarrow$ 5
#     - Columna _**year**_ a tipo _**int**_:
#         - _Ejemplo_: '05/2023' $\longrightarrow$ 2023
#     - Elimina la columna _**fecha_matriculacion**_ del **DataFrame**.

# %% [markdown]
# Para esta tarea nos ayudaremos del atributo *.map()*, recorrerá toda nuestra columna y le aplicará la operación/comando que queramos a cada fila. En este caso, utilizo *.split()* para separar cada string por el caracter "/". El resultado lo guardo en la varirable *fecha*:

# %%
fecha = df["fecha_matriculacion"].map(lambda x : x.split("/"))

fecha
# Out:
# 0        [05, 2023]
# 1        [06, 2023]
# 2        [12, 2023]
# 3        [01, 2024]
# 4        [05, 2023]
#             ...
# 71213    [11, 2020]
# 71214    [05, 2022]
# 71215    [02, 2021]
# 71216    [12, 2020]
# 71217    [01, 2021]
# Name: fecha_matriculacion, Length: 71218, dtype: object

# %% [markdown]
# A continuación, generamos un bucle que me devuelve una lista con todos los primeros elementos de la variable *fecha*. Esta lista contendrá nuestra sucesión de meses:

# %%
meses = []

for i in fecha:
    meses.append(i[0])

meses
# Out:
# ['05',
#  '06',
#  '12',
#  '01',
#  '05',
#  '06',
#  '06',
#  '10',
#  '11',
#  '10',
#  '11',
#  '02',
#  '09',
#  '02',
#  '02',
#  '02',
#  '09',
#  '09',
#  '03',
#  '09',
#  '11',
#  '11',
#  '08',
#  '01',
#  '03',
#  '03',
#  '06',
#  '10',
#  '10',
#  '10',
#  '06',
#  '10',
#  '08',
#  '10',
#  '11',
#  '08',
#  '07',
#  '06',
#  '06',
#  '07',
#  '06',
#  '06',
#  '12',
#  '02',
#  '02',
#  '02',
#  '02',
#  '02',
#  '04',
#  '10',
#  '01',
#  '01',
#  '05',
#  '05',
#  '05',
#  '05',
#  '08',
#  '02',
#  '06',
#  '11',
#  '10',
#  '06',
#  '05',
#  '06',
#  '06',
#  '07',
#  '08',
#  '05',
#  '05',
#  '05',
#  '04',
#  '05',
#  '04',
#  '04',
#  '04',
#  '08',
#  '11',
#  '11',
#  '11',
#  '10',
#  '10',
#  '04',
#  '05',
#  '12',
#  '10',
#  '02',
#  '05',
#  '05',
#  '02',
#  '10',
#  '08',
#  '03',
#  '10',
#  '01',
#  '01',
#  '10',
#  '12',
#  '06',
#  '11',
#  '09',
#  '03',
#  '07',
#  '02',
#  '06',
#  '08',
#  '11',
#  '11',
#  '01',
#  '02',
#  '10',
#  '09',
#  '02',
#  '03',
#  '02',
#  '04',
#  '11',
#  '03',
#  '08',
#  '03',
#  '01',
#  '07',
#  '10',
#  '11',
#  '11',
#  '01',
#  '08',
#  '08',
#  '02',
#  '02',
#  '03',
#  '03',
#  '07',
#  '04',
#  '03',
#  '07',
#  '02',
#  '06',
#  '09',
#  '11',
#  '01',
#  '09',
#  '06',
#  '09',
#  '03',
#  '09',
#  '07',
#  '07',
#  '05',
#  '11',
#  '07',
#  '07',
#  '07',
#  '07',
#  '10',
#  '07',
#  '11',
#  '06',
#  '01',
#  '07',
#  '02',
#  '03',
#  '03',
#  '12',
#  '10',
#  '12',
#  '07',
#  '03',
#  '10',
#  '01',
#  '01',
#  '01',
#  '09',
#  '07',
#  '07',
#  '08',
#  '08',
#  '07',
#  '10',
#  '06',
#  '08',
#  '10',
#  '09',
#  '09',
#  '07',
#  '05',
#  '11',
#  '07',
#  '07',
#  '07',
#  '09',
#  '09',
#  '09',
#  '02',
#  '02',
#  '10',
#  '12',
#  '03',
#  '02',
#  '09',
#  '05',
#  '04',
#  '07',
#  '06',
#  '10',
#  '02',
#  '08',
#  '01',
#  '01',
#  '07',
#  '10',
#  '06',
#  '12',
#  '02',
#  '01',
#  '09',
#  '04',
#  '08',
#  '09',
#  '02',
#  '08',
#  '02',
#  '02',
#  '01',
#  '08',
#  '09',
#  '09',
#  '09',
#  '04',
#  '05',
#  '11',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '09',
#  '04',
#  '09',
#  '08',
#  '07',
#  '07',
#  '02',
#  '07',
#  '12',
#  '12',
#  '01',
#  '08',
#  '09',
#  '09',
#  '01',
#  '01',
#  '06',
#  '07',
#  '07',
#  '01',
#  '01',
#  '02',
#  '01',
#  '06',
#  '02',
#  '01',
#  '03',
#  '06',
#  '01',
#  '09',
#  '07',
#  '01',
#  '02',
#  '02',
#  '01',
#  '07',
#  '01',
#  '01',
#  '01',
#  '03',
#  '05',
#  '06',
#  '05',
#  '05',
#  '12',
#  '11',
#  '01',
#  '01',
#  '02',
#  '02',
#  '02',
#  '06',
#  '02',
#  '02',
#  '02',
#  '01',
#  '03',
#  '03',
#  '08',
#  '02',
#  '09',
#  '01',
#  '01',
#  '06',
#  '03',
#  '02',
#  '07',
#  '05',
#  '04',
#  '01',
#  '01',
#  '04',
#  '04',
#  '04',
#  '10',
#  '06',
#  '01',
#  '06',
#  '06',
#  '01',
#  '02',
#  '04',
#  '01',
#  '09',
#  '12',
#  '04',
#  '04',
#  '05',
#  '01',
#  '12',
#  '09',
#  '01',
#  '01',
#  '02',
#  '01',
#  '06',
#  '04',
#  '02',
#  '01',
#  '02',
#  '10',
#  '01',
#  '01',
#  '08',
#  '02',
#  '05',
#  '12',
#  '02',
#  '03',
#  '03',
#  '06',
#  '01',
#  '01',
#  '01',
#  '06',
#  '02',
#  '01',
#  '01',
#  '01',
#  '07',
#  '05',
#  '05',
#  '08',
#  '09',
#  '09',
#  '12',
#  '12',
#  '01',
#  '01',
#  '01',
#  '01',
#  '11',
#  '11',
#  '12',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '08',
#  '09',
#  '09',
#  '10',
#  '12',
#  '12',
#  '11',
#  '01',
#  '10',
#  '12',
#  '12',
#  '11',
#  '06',
#  '01',
#  '12',
#  '05',
#  '04',
#  '05',
#  '01',
#  '01',
#  '02',
#  '01',
#  '01',
#  '01',
#  '01',
#  '02',
#  '04',
#  '04',
#  '02',
#  '01',
#  '01',
#  '05',
#  '02',
#  '04',
#  '01',
#  '03',
#  '05',
#  '09',
#  '04',
#  '04',
#  '07',
#  '07',
#  '01',
#  '12',
#  '01',
#  '01',
#  '02',
#  '09',
#  '01',
#  '12',
#  '08',
#  '01',
#  '12',
#  '12',
#  '01',
#  '01',
#  '02',
#  '10',
#  '08',
#  '01',
#  '01',
#  '03',
#  '10',
#  '01',
#  '01',
#  '01',
#  '01',
#  '10',
#  '05',
#  '05',
#  '05',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '02',
#  '12',
#  '07',
#  '09',
#  '10',
#  '12',
#  '01',
#  '01',
#  '01',
#  '01',
#  '11',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '12',
#  '12',
#  '06',
#  '01',
#  '04',
#  '02',
#  '02',
#  '07',
#  '09',
#  '01',
#  '02',
#  '09',
#  '10',
#  '01',
#  '01',
#  '01',
#  '01',
#  '03',
#  '04',
#  '02',
#  '01',
#  '01',
#  '11',
#  '10',
#  '10',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '10',
#  '01',
#  '01',
#  '01',
#  '01',
#  '07',
#  '06',
#  '08',
#  '08',
#  '08',
#  '08',
#  '04',
#  '04',
#  '09',
#  '05',
#  '09',
#  '06',
#  '06',
#  '09',
#  '12',
#  '11',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '06',
#  '07',
#  '10',
#  '10',
#  '10',
#  '01',
#  '01',
#  '01',
#  '01',
#  '07',
#  '07',
#  '01',
#  '01',
#  '02',
#  '01',
#  '01',
#  '05',
#  '01',
#  '02',
#  '07',
#  '10',
#  '09',
#  '09',
#  '07',
#  '10',
#  '10',
#  '02',
#  '04',
#  '01',
#  '06',
#  '03',
#  '03',
#  '10',
#  '03',
#  '03',
#  '01',
#  '04',
#  '03',
#  '04',
#  '04',
#  '06',
#  '03',
#  '09',
#  '06',
#  '01',
#  '01',
#  '01',
#  '06',
#  '12',
#  '11',
#  '06',
#  '02',
#  '04',
#  '10',
#  '09',
#  '05',
#  '12',
#  '04',
#  '01',
#  '04',
#  '05',
#  '12',
#  '05',
#  '04',
#  '04',
#  '05',
#  '01',
#  '02',
#  '12',
#  '09',
#  '07',
#  '07',
#  '10',
#  '05',
#  '05',
#  '09',
#  '08',
#  '05',
#  '08',
#  '09',
#  '01',
#  '12',
#  '09',
#  '05',
#  '11',
#  '11',
#  '10',
#  '04',
#  '05',
#  '12',
#  '12',
#  '12',
#  '11',
#  '04',
#  '09',
#  '08',
#  '12',
#  '12',
#  '08',
#  '06',
#  '08',
#  '03',
#  '06',
#  '07',
#  '04',
#  '08',
#  '10',
#  '06',
#  '03',
#  '07',
#  '12',
#  '08',
#  '06',
#  '05',
#  '05',
#  '09',
#  '01',
#  '01',
#  '01',
#  '01',
#  '10',
#  '03',
#  '03',
#  '12',
#  '09',
#  '09',
#  '10',
#  '03',
#  '12',
#  '12',
#  '04',
#  '04',
#  '10',
#  '01',
#  '07',
#  '01',
#  '11',
#  '10',
#  '10',
#  '03',
#  '05',
#  '08',
#  '11',
#  '10',
#  '12',
#  '11',
#  '12',
#  '11',
#  '01',
#  '10',
#  '12',
#  '12',
#  '02',
#  '01',
#  '06',
#  '01',
#  '01',
#  '07',
#  '10',
#  '10',
#  '11',
#  '06',
#  '01',
#  '04',
#  '08',
#  '08',
#  '09',
#  '05',
#  '07',
#  '07',
#  '07',
#  '07',
#  '10',
#  '07',
#  '06',
#  '01',
#  '11',
#  '01',
#  '05',
#  '08',
#  '10',
#  '05',
#  '03',
#  '04',
#  '06',
#  '10',
#  '10',
#  '03',
#  '01',
#  '02',
#  '03',
#  '02',
#  '09',
#  '04',
#  '12',
#  '12',
#  '06',
#  '06',
#  '09',
#  '07',
#  '08',
#  '08',
#  '10',
#  '10',
#  '01',
#  '01',
#  '01',
#  '02',
#  '12',
#  '12',
#  '12',
#  '09',
#  '12',
#  '02',
#  '01',
#  '05',
#  '05',
#  '01',
#  '04',
#  '05',
#  '03',
#  '04',
#  '02',
#  '04',
#  '09',
#  '07',
#  '08',
#  '03',
#  '09',
#  '09',
#  '12',
#  '12',
#  '11',
#  '03',
#  '09',
#  '01',
#  '01',
#  '09',
#  '05',
#  '05',
#  '07',
#  '05',
#  '10',
#  '10',
#  '11',
#  '12',
#  '04',
#  '10',
#  '05',
#  '08',
#  '10',
#  '07',
#  '11',
#  '12',
#  '09',
#  '10',
#  '12',
#  '12',
#  '12',
#  '12',
#  '05',
#  '11',
#  '06',
#  '10',
#  '01',
#  '06',
#  '10',
#  '02',
#  '01',
#  '04',
#  '08',
#  '01',
#  '03',
#  '04',
#  '03',
#  '09',
#  '09',
#  '04',
#  '01',
#  '01',
#  '03',
#  '06',
#  '07',
#  '07',
#  '07',
#  '07',
#  '06',
#  '06',
#  '11',
#  '09',
#  '09',
#  '08',
#  '06',
#  '09',
#  '09',
#  '04',
#  '09',
#  '09',
#  '09',
#  '06',
#  '02',
#  '09',
#  '06',
#  '02',
#  '12',
#  '10',
#  '03',
#  '04',
#  '07',
#  '07',
#  '08',
#  '08',
#  '09',
#  '03',
#  '09',
#  '09',
#  '09',
#  '09',
#  '03',
#  '09',
#  '05',
#  '06',
#  '06',
#  '06',
#  '06',
#  '09',
#  '09',
#  '09',
#  '09',
#  '10',
#  '10',
#  '01',
#  '03',
#  '07',
#  '12',
#  '10',
#  '04',
#  '08',
#  '09',
#  '09',
#  '09',
#  '09',
#  '09',
#  '09',
#  '09',
#  '09',
#  '09',
#  '09',
#  '08',
#  '07',
#  '11',
#  '09',
#  '04',
#  '04',
#  '03',
#  '03',
#  '08',
#  '09',
#  '09',
#  '09',
#  '10',
#  '07',
#  '07',
#  '12',
#  '04',
#  '10',
#  '11',
#  '08',
#  '08',
#  '10',
#  '08',
#  '10',
#  '05',
#  '03',
#  '03',
#  '03',
#  '09',
#  '04',
#  '09',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '09',
#  '08',
#  '07',
#  '07',
#  '07',
#  '03',
#  '03',
#  '03',
#  '03',
#  '03',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '09',
#  '03',
#  '09',
#  '07',
#  '08',
#  '06',
#  '06',
#  '06',
#  '06',
#  '05',
#  '09',
#  '03',
#  '08',
#  '04',
#  '07',
#  '03',
#  '12',
#  '10',
#  '12',
#  '12',
#  '07',
#  '04',
#  '04',
#  '03',
#  '03',
#  '03',
#  '07',
#  '10',
#  '04',
#  '04',
#  '01',
#  '11',
#  '04',
#  '08',
#  '08',
#  '01',
#  '01',
#  '01',
#  '04',
#  '02',
#  '12',
#  '07',
#  '01',
#  '09',
#  '08',
#  '01',
#  '09',
#  '11',
#  '10',
#  '08',
#  '08',
#  '05',
#  '03',
#  '04',
#  '04',
#  ...]

# %% [markdown]
# Y hago lo mismo para los años:

# %%
años = []

for i in fecha:
    años.append(i[1])

años
# Out:
# ['2023',
#  '2023',
#  '2023',
#  '2024',
#  '2023',
#  '2023',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2023',
#  '2023',
#  '2024',
#  '2024',
#  '2024',
#  '2022',
#  '2022',
#  '2023',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2022',
#  '2022',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2023',
#  '2023',
#  '2022',
#  '2022',
#  '2022',
#  '2023',
#  '2023',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2021',
#  '2023',
#  '2022',
#  '2023',
#  '2022',
#  '2022',
#  '2023',
#  '2022',
#  '2022',
#  '2022',
#  '2023',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2023',
#  '2022',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2024',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2024',
#  '2022',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2022',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2022',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2022',
#  '2022',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2024',
#  '2022',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2024',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2024',
#  '2023',
#  '2023',
#  '2023',
#  '2024',
#  '2022',
#  '2022',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2024',
#  '2023',
#  '2023',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2024',
#  '2023',
#  '2023',
#  '2023',
#  '2024',
#  '2024',
#  '2023',
#  '2023',
#  '2023',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2023',
#  '2024',
#  '2024',
#  '2022',
#  '2023',
#  '2024',
#  '2023',
#  '2023',
#  '2024',
#  '2024',
#  '2024',
#  '2022',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2024',
#  '2022',
#  '2023',
#  '2023',
#  '2024',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2024',
#  '2023',
#  '2023',
#  '2024',
#  '2024',
#  '2023',
#  '2024',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2023',
#  '2023',
#  '2023',
#  '2024',
#  '2023',
#  '2023',
#  '2024',
#  '2024',
#  '2023',
#  '2024',
#  '2023',
#  '2023',
#  '2024',
#  '2023',
#  '2023',
#  '2022',
#  '2024',
#  '2024',
#  '2024',
#  '2023',
#  '2023',
#  '2024',
#  '2024',
#  '2024',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2022',
#  '2022',
#  '2023',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2022',
#  '2022',
#  '2023',
#  '2024',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2024',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2024',
#  '2024',
#  '2024',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2024',
#  '2023',
#  '2023',
#  '2023',
#  '2024',
#  '2024',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2024',
#  '2023',
#  '2023',
#  '2024',
#  '2024',
#  '2022',
#  '2024',
#  '2023',
#  '2023',
#  '2024',
#  '2023',
#  '2023',
#  '2024',
#  '2024',
#  '2024',
#  '2023',
#  '2023',
#  '2024',
#  '2024',
#  '2023',
#  '2023',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2022',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2022',
#  '2022',
#  '2023',
#  '2024',
#  '2023',
#  '2024',
#  '2024',
#  '2022',
#  '2022',
#  '2024',
#  '2024',
#  '2023',
#  '2023',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2022',
#  '2022',
#  '2023',
#  '2024',
#  '2024',
#  '2023',
#  '2022',
#  '2022',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2022',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2023',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2023',
#  '2023',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2023',
#  '2024',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2024',
#  '2022',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2024',
#  '2024',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2023',
#  '2022',
#  '2023',
#  '2022',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2022',
#  '2022',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2024',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2021',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2022',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2022',
#  '2022',
#  '2023',
#  '2024',
#  '2024',
#  '2023',
#  '2024',
#  '2024',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2021',
#  '2021',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2022',
#  '2023',
#  '2022',
#  '2024',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2022',
#  '2022',
#  '2023',
#  '2024',
#  '2023',
#  '2022',
#  '2021',
#  '2023',
#  '2023',
#  '2022',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2024',
#  '2024',
#  '2024',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2024',
#  '2023',
#  '2023',
#  '2024',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2021',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2024',
#  '2023',
#  '2023',
#  '2023',
#  '2024',
#  '2023',
#  '2023',
#  '2024',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2024',
#  '2024',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2022',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2024',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2022',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2022',
#  '2022',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2022',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2024',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2024',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  ...]

# %% [markdown]
# Y para que estos datos se me guarden en mi dataframe, sólo debo crear sus respectivas series:

# %%
df["month"] = meses
df["year"] = años

# %% [markdown]
# De esta manera, vemos que se nos han agregado estas dos columnas al final de nuestro dataframe:

# %%
df.head(5)
# Out:
#   fecha_matriculacion tipo_combustible kilometros tipo_carroceria tipo_cambio  \
# 0             05/2023         Gasolina      10 km         Berlina      Manual
# 1             06/2023         Gasolina      10 km         Berlina      Manual
# 2             12/2023         Gasolina      15 km         Berlina      Manual
# 3             01/2024         Gasolina      50 km         Berlina      Manual
# 4             05/2023         Gasolina   2.500 km         Berlina  Automático
#
#    potencia_cv  garantia distintivo_ambiental    precio  peso_masa_kg  \
# 0        140.0  36 meses                    C  33.400 €        1425.0
# 1        140.0  36 meses                    C  33.900 €        1425.0
# 2        165.0  36 meses                    C  27.200 €        1425.0
# 3        180.0  12 meses                    C  38.900 €        1545.0
# 4        180.0  36 meses                    C  29.850 €        1545.0
#
#    puertas  plazas  cilindros  co2 deposito month  year
# 0      3.0     4.0        4.0  139    35,00    05  2023
# 1      3.0     4.0        4.0  139    35,00    06  2023
# 2      3.0     4.0        4.0    -    35,00    12  2023
# 3      3.0     4.0        4.0    -    35,00    01  2024
# 4      3.0     4.0        4.0    -    35,00    05  2023

# %% [markdown]
# También recasteamos estos valores a tipo int:

# %%
df["month"] = df["month"].astype(int)
df["year"] = df["year"].astype(int)

# %% [markdown]
# Y eliminamos la columna "fecha_matriculacion", que ya no nos aporta nada:

# %%
df = df.drop("fecha_matriculacion", axis=1)

df.head(3)
# Out:
#   tipo_combustible  kilometros tipo_carroceria tipo_cambio  potencia_cv  \
# 0         Gasolina        10.0         Berlina      Manual        140.0
# 1         Gasolina        10.0         Berlina      Manual        140.0
# 2         Gasolina        15.0         Berlina      Manual        165.0
#
#    garantia distintivo_ambiental   precio  peso_masa_kg  puertas  plazas  \
# 0  36 meses                    C  33400.0        1425.0      3.0     4.0
# 1  36 meses                    C  33900.0        1425.0      3.0     4.0
# 2  36 meses                    C  27200.0        1425.0      3.0     4.0
#
#    cilindros         co2  deposito  month  year
# 0        4.0  139.000000      35.0      5  2023
# 1        4.0  139.000000      35.0      6  2023
# 2        4.0  129.957545      35.0     12  2023

# %% [markdown]
# 6. Columna _**garantia**_:
#     - Elimina la palabra "meses" de todos los elementos que contengan esa cadena. Transforma esos elementos a tipo **float**.
#     - Reemplaza a **0** los elementos que sean igual a **"No"**.
#     - Reemplaza a **np.nan** los elementos que sean igual a **"Sí"**.
#     - Reemplaza los **np.nan** por la media de todos los valores de esta columna.

# %%
df["garantia"] = df["garantia"].str.replace('meses', '')
df["garantia"] = df["garantia"].str.replace('No', '0')
df["garantia"] = df["garantia"].replace("Sí", np.nan)

df["garantia"] = df["garantia"].astype(float)

df["garantia"] = df["garantia"].fillna(df["garantia"].mean())

df["garantia"]
# Out:
# 0        36.0
# 1        36.0
# 2        36.0
# 3        12.0
# 4        36.0
#          ...
# 71213    12.0
# 71214    12.0
# 71215    12.0
# 71216    12.0
# 71217    12.0
# Name: garantia, Length: 71218, dtype: float64

# %%
df.head(3)
# Out:
#   tipo_combustible kilometros tipo_carroceria tipo_cambio  potencia_cv  \
# 0         Gasolina      10 km         Berlina      Manual        140.0
# 1         Gasolina      10 km         Berlina      Manual        140.0
# 2         Gasolina      15 km         Berlina      Manual        165.0
#
#    garantia distintivo_ambiental    precio  peso_masa_kg  puertas  plazas  \
# 0      36.0                    C  33.400 €        1425.0      3.0     4.0
# 1      36.0                    C  33.900 €        1425.0      3.0     4.0
# 2      36.0                    C  27.200 €        1425.0      3.0     4.0
#
#    cilindros  co2 deposito  month  year
# 0        4.0  139    35,00      5  2023
# 1        4.0  139    35,00      6  2023
# 2        4.0    -    35,00     12  2023

# %% [markdown]
# 7. Guarda el **DataFrame** en un archivo **.csv** usando la siguiente linea de código:
# ```python
# df.to_csv("coches_segunda_mano_limpio.csv", index = False)
# ```
#
# **El resultado final debe ser un pd.DataFrame con 71218 filas y 16 columnas.**

# %% [markdown]
# Nos aseguramos de que nuestro dataframe tenga el número exacto de filas y columnas que nos piden mediante el atributo *.shape()*:

# %%
df.shape
# Out:
# (71218, 16)

# %% [markdown]
# Y lo gardamos:

# %%
df.to_csv("coches_segunda_mano_limpio.csv", index = False)

# %% [markdown]
# ### 02. Análisis
#
# Responde a las siguientes preguntas usando el **DataFrame** de la parte anterior:
#
# 1. Muestra los estadísticos descriptivos (media, mediana, mínimo, máximo, ...) de todas las columnas del **DataFrame**.

# %%
df_limpio = pd.read_csv("coches_segunda_mano_limpio.csv")

df_limpio.head(3)
# Out:
#   tipo_combustible  kilometros tipo_carroceria tipo_cambio  potencia_cv  \
# 0         Gasolina        10.0         Berlina      Manual        140.0
# 1         Gasolina        10.0         Berlina      Manual        140.0
# 2         Gasolina        15.0         Berlina      Manual        165.0
#
#    garantia distintivo_ambiental   precio  peso_masa_kg  puertas  plazas  \
# 0      36.0                    C  33400.0        1425.0      3.0     4.0
# 1      36.0                    C  33900.0        1425.0      3.0     4.0
# 2      36.0                    C  27200.0        1425.0      3.0     4.0
#
#    cilindros         co2  deposito  month  year
# 0        4.0  139.000000      35.0      5  2023
# 1        4.0  139.000000      35.0      6  2023
# 2        4.0  129.957545      35.0     12  2023

# %% [markdown]
# Una forma rápida de obtener los principales descriptivos de mi dataframe es mediante el atributo *.describe()*:

# %%
df_limpio.describe()
# Out:
#          kilometros   potencia_cv       garantia        precio  peso_masa_kg  \
# count  7.121800e+04  71218.000000   71218.000000  7.121800e+04  71218.000000
# mean   7.343444e+04    164.535693      17.237630  3.173700e+04   1973.483586
# std    6.060011e+04    107.269527     470.721874  5.722351e+04    379.079845
# min    0.000000e+00      1.000000       0.000000  1.000000e+00      0.000000
# 25%    2.630100e+04    110.000000      12.000000  1.459900e+04   1740.000000
# 50%    6.300000e+04    130.000000      12.000000  2.000000e+04   1920.000000
# 75%    1.050310e+05    170.000000      12.000000  2.899000e+04   2140.000000
# max    1.965000e+06    887.000000  122412.000000  2.650000e+06   3500.000000
#
#             puertas        plazas     cilindros           co2      deposito  \
# count  71218.000000  71218.000000  71218.000000  71218.000000  71218.000000
# mean       4.704766      4.929821      4.039751    129.957545     52.866878
# std        0.774109      0.612382      1.151842     38.605896     13.586073
# min        2.000000      2.000000      2.000000     13.000000      0.000000
# 25%        5.000000      5.000000      3.000000    109.000000     45.000000
# 50%        5.000000      5.000000      4.000000    127.000000     50.000000
# 75%        5.000000      5.000000      4.000000    131.000000     60.000000
# max        5.000000      9.000000     16.000000    596.000000    121.000000
#
#               month          year
# count  71218.000000  71218.000000
# mean       5.920764   2018.523365
# std        3.377524      3.965661
# min        1.000000   2000.000000
# 25%        3.000000   2017.000000
# 50%        6.000000   2019.000000
# 75%        9.000000   2021.000000
# max       12.000000   2024.000000

# %% [markdown]
# 2. ¿En que año se matricularon más coches? Muestra el resultado en porcentaje, ordenado de mayor a menor.

# %% [markdown]
# Para ello emplearemos *.value_counts(normalize=True)*, que me da la proporción de cada valor en nuestra columna de interés. Sin embargo, como queremos el porcentaje, multiplicamos el resultado anterior por 100:

# %%
proporciones_año = df_limpio["year"].value_counts(normalize=True)
proporciones_año*100
# Out:
# year
# 2019    15.807801
# 2022    12.508074
# 2023    11.139038
# 2018    10.627931
# 2021    10.436968
# 2020     9.465304
# 2017     7.038951
# 2016     5.226207
# 2015     3.958269
# 2014     2.676290
# 2013     1.731304
# 2012     1.558595
# 2011     1.265130
# 2010     1.133140
# 2024     1.076975
# 2007     0.901457
# 2008     0.886012
# 2009     0.860737
# 2006     0.681008
# 2005     0.273807
# 2004     0.221854
# 2002     0.181134
# 2003     0.151647
# 2000     0.098290
# 2001     0.094077
# Name: proportion, dtype: float64

# %% [markdown]
# El año con mayor porcentaje de coches matriculados fue el 2019, con un 15,8%.

# %% [markdown]
# 3. ¿Que cantidad (en porcentaje) de coches tienen el valor de _**potencia_cv**_ mayor que la media?

# %% [markdown]
# Para obtener el resultado básicamente divido la cantidad de coches con potencia por encima de la media entre la cantidad total de coches y lo multiplico por 100:

# %%
(len(df_limpio[df_limpio["potencia_cv"] > df_limpio["potencia_cv"].mean()])/len(df_limpio["potencia_cv"]))*100
# Out:
# 26.352888314751887

# %% [markdown]
# Solo el 26,35% de los coches tienen un valor de potencia por encima de la media.

# %% [markdown]
# 4. ¿Cuales son las 3 categorias de la columna _**tipo_combustible**_ que menos se repiten?

# %% [markdown]
# Volvemos a utilizar *.value_count()* pero esta vez con el parámetro *ascending=True*, que devuelve los valores ordenados de menor a mayor:

# %%
df_limpio["tipo_combustible"].value_counts(ascending=True).head(3)
# Out:
# tipo_combustible
# Corriente eléctrica              2
# Mixto Gasolina/Etanol            5
# Diesel y corriente eléctrica    28
# Name: count, dtype: int64

# %% [markdown]
# Las categorías que menos se repiten son, en orden ascendente: corriente elétrica, mixto gasolina/etanol y diesel.

# %% [markdown]
# 5. Agrupando los datos por la columna _**distintivo_ambiental**_, ¿Cual categoria tiene de media el _**precio**_ más alto?

# %% [markdown]
# Agrupamos nuestros valores por "distintivo_ambiental" y pedimos la media de precio para cada clase de "distintivo_ambiental". Como queremos el valor más alto, ordenamos los valores de mayor a menor.

# %%
df_limpio.groupby("distintivo_ambiental", as_index = False)["precio"].mean().sort_values(by = "precio", ascending = False).head(1)
# Out:
#   distintivo_ambiental        precio
# 0          0 EMISIONES  75550.708129

# %% [markdown]
# La categoría con el precio más alto son los coches 0 emisiones, con una media de 75550 €.

# %% [markdown]
# 6. Agrupando los datos por la columna _**year**_, ¿Que año tiene de media el _**co2**_ más bajo?

# %% [markdown]
# Agrupamos nuestros valores por "year" y pedimos la media de co2 por cada clase de "year" (por cada año). Como queremos el valor más bajo, ordenamos los valores de menor a mayor.

# %%
df_limpio.groupby("year", as_index = False)["co2"].mean().sort_values(by = "co2", ascending = True).head(1)
# Out:
#     year         co2
# 20  2020  123.427461

# %% [markdown]
# El año con las emisiones más bajas de CO2 fue el 2020, con una media de 123 g/km.

# %%
##############################################################################################################################
