# %% [markdown]
# **Semana 01/Ejercicio 01 - Sistema de Gestión de Empleados**
#
# Para este ejercicio vamos a simular una "base de datos" con información de empleados de una empresa ficticia.
#
# Vamos a utilizar el archivo _**empleados.pkl**_ que es un diccionario con información de empleados.
#
# Un empleado cuenta con la siguiente información:
#
# |Atributo        |Descripción                                               |Tipo de dato|Rango                   |
# |----------------|----------------------------------------------------------|------------|------------------------|
# |**id**          |Un identificador único para cada empleado.                |**int**     |[1, 9999]               |
# |**nombre**      |Nombre del empleado.                                      |**string**  |                        |
# |**apellido**    |Apellido del empleado.                                    |**string**  |                        |
# |**departamento**|Departamento al que pertenece el empleado.                |**string**  |[1, 10]                 |
# |**sueldo**      |Sueldo mensual del empleado.                              |**float**   |[10000, 20000]          |
# |**fecha**       |Fecha en que el empleado comenzó a trabajar en la empresa.|**datetime**|[2000-01-01, 2000-31-12]|
# |**email**       |Correo electrónico del empleado.                          |**string**  |                        |
#
#
# Ejemplo de un empleado:
#
# ```python
# {"id"          : 4371,
#  "nombre"      : "nombre_4371",
#  "apellido"    : "apellido_4371",
#  "departamento": 8,
#  "sueldo"      : 15521.0,
#  "fecha"       : "2012-06-01",
#  "email"       : "nombre_4371.apellido_4371@python.com"}
# ```
#
# Para interactuar con este diccionario vamos a definir diferentes funciones:
#
# - **get_empleado(id_, empleados)**: Esta función buscará en el diccionario _**empleados**_ un empleado cuyo "id" sea igual al parámetro de entrada **id_** y mostrará por pantalla toda la información disponible de ese empleado.
#
# - **get_top_empleados(sueldo, empleados)**: Esta función retornará una lista con los "id"s de los empleados cuyo "sueldo" sea mayor o igual al parámetro _**sueldo**_.
#
# - **put_empleado(empleados)**: Esta función añadirá al diccionario _**empleados**_ un empleado nuevo. Los datos del empleado nuevo serán generados aleatoriamente usando la librería **random** y se generará un diccionario con estos datos, además el nuevo empleado no puede tener un "id" ya existente. Esta función debe retornar un diccionario de empleados nuevo, usalo para sobrescribir el diccionario de empleados anterior.
#
# **Las 3 funciones toman como parámetro de entrada el diccionario de _empleados_.**
#
# **Implementación**: Comprobar la funcionalidad de las tres funciones anteriores.

# %% [markdown]
# **RESOLUCIÓN**
#
# Como siempre, empezamos este ejercicio importando las librerías de las que vamos a hacer uso. Esta vez, aparte de utilizar *random*, emplearemos también *pickle* para leer archivos en binario (con la extensión .pkl) y *datetime.date*, para trabajar con fechas.

# %%
import pickle
import random
from datetime import date

# %% [markdown]
# A continuación, abrimos nuestro archivo *.pkl* en modo lectura y lo cargamos en la variable *empleados_db*:

# %%
with open("empleados.pkl", "br") as file:
    empleados_db = pickle.load(file)
    
empleados_db
# Out:
# {0: {'id': 4616,
#   'nombre': 'nombre_4616',
#   'apellido': 'apellido_4616',
#   'departamento': 6,
#   'sueldo': 12667.0,
#   'fecha': '2011-09-30',
#   'email': 'nombre_4616.apellido_4616@python.com'},
#  1: {'id': 7536,
#   'nombre': 'nombre_7536',
#   'apellido': 'apellido_7536',
#   'departamento': 9,
#   'sueldo': 18283.0,
#   'fecha': '2003-10-02',
#   'email': 'nombre_7536.apellido_7536@python.com'},
#  2: {'id': 9867,
#   'nombre': 'nombre_9867',
#   'apellido': 'apellido_9867',
#   'departamento': 4,
#   'sueldo': 15451.0,
#   'fecha': '1997-05-15',
#   'email': 'nombre_9867.apellido_9867@python.com'},
#  3: {'id': 2703,
#   'nombre': 'nombre_2703',
#   'apellido': 'apellido_2703',
#   'departamento': 5,
#   'sueldo': 15559.0,
#   'fecha': '2016-12-25',
#   'email': 'nombre_2703.apellido_2703@python.com'},
#  4: {'id': 1389,
#   'nombre': 'nombre_1389',
#   'apellido': 'apellido_1389',
#   'departamento': 8,
#   'sueldo': 12799.0,
#   'fecha': '2020-07-31',
#   'email': 'nombre_1389.apellido_1389@python.com'},
#  5: {'id': 9019,
#   'nombre': 'nombre_9019',
#   'apellido': 'apellido_9019',
#   'departamento': 2,
#   'sueldo': 18700.0,
#   'fecha': '1999-09-10',
#   'email': 'nombre_9019.apellido_9019@python.com'},
#  6: {'id': 7431,
#   'nombre': 'nombre_7431',
#   'apellido': 'apellido_7431',
#   'departamento': 4,
#   'sueldo': 19730.0,
#   'fecha': '2004-01-15',
#   'email': 'nombre_7431.apellido_7431@python.com'},
#  7: {'id': 93,
#   'nombre': 'nombre_93',
#   'apellido': 'apellido_93',
#   'departamento': 3,
#   'sueldo': 15903.0,
#   'fecha': '2024-02-17',
#   'email': 'nombre_93.apellido_93@python.com'},
#  8: {'id': 3967,
#   'nombre': 'nombre_3967',
#   'apellido': 'apellido_3967',
#   'departamento': 7,
#   'sueldo': 17404.0,
#   'fecha': '2013-07-10',
#   'email': 'nombre_3967.apellido_3967@python.com'},
#  9: {'id': 9571,
#   'nombre': 'nombre_9571',
#   'apellido': 'apellido_9571',
#   'departamento': 4,
#   'sueldo': 11341.0,
#   'fecha': '1998-03-07',
#   'email': 'nombre_9571.apellido_9571@python.com'},
#  10: {'id': 582,
#   'nombre': 'nombre_582',
#   'apellido': 'apellido_582',
#   'departamento': 5,
#   'sueldo': 19599.0,
#   'fecha': '2022-10-16',
#   'email': 'nombre_582.apellido_582@python.com'},
#  11: {'id': 209,
#   'nombre': 'nombre_209',
#   'apellido': 'apellido_209',
#   'departamento': 3,
#   'sueldo': 15130.0,
#   'fecha': '2023-10-24',
#   'email': 'nombre_209.apellido_209@python.com'},
#  12: {'id': 2081,
#   'nombre': 'nombre_2081',
#   'apellido': 'apellido_2081',
#   'departamento': 9,
#   'sueldo': 12481.0,
#   'fecha': '2018-09-08',
#   'email': 'nombre_2081.apellido_2081@python.com'},
#  13: {'id': 848,
#   'nombre': 'nombre_848',
#   'apellido': 'apellido_848',
#   'departamento': 10,
#   'sueldo': 16307.0,
#   'fecha': '2022-01-23',
#   'email': 'nombre_848.apellido_848@python.com'},
#  14: {'id': 936,
#   'nombre': 'nombre_936',
#   'apellido': 'apellido_936',
#   'departamento': 3,
#   'sueldo': 13179.0,
#   'fecha': '2021-10-27',
#   'email': 'nombre_936.apellido_936@python.com'},
#  15: {'id': 1945,
#   'nombre': 'nombre_1945',
#   'apellido': 'apellido_1945',
#   'departamento': 7,
#   'sueldo': 16731.0,
#   'fecha': '2019-01-22',
#   'email': 'nombre_1945.apellido_1945@python.com'},
#  16: {'id': 4993,
#   'nombre': 'nombre_4993',
#   'apellido': 'apellido_4993',
#   'departamento': 10,
#   'sueldo': 16275.0,
#   'fecha': '2010-09-18',
#   'email': 'nombre_4993.apellido_4993@python.com'},
#  17: {'id': 5600,
#   'nombre': 'nombre_5600',
#   'apellido': 'apellido_5600',
#   'departamento': 4,
#   'sueldo': 18921.0,
#   'fecha': '2009-01-19',
#   'email': 'nombre_5600.apellido_5600@python.com'},
#  18: {'id': 4706,
#   'nombre': 'nombre_4706',
#   'apellido': 'apellido_4706',
#   'departamento': 4,
#   'sueldo': 15945.0,
#   'fecha': '2011-07-02',
#   'email': 'nombre_4706.apellido_4706@python.com'},
#  19: {'id': 880,
#   'nombre': 'nombre_880',
#   'apellido': 'apellido_880',
#   'departamento': 10,
#   'sueldo': 17509.0,
#   'fecha': '2021-12-22',
#   'email': 'nombre_880.apellido_880@python.com'},
#  20: {'id': 9568,
#   'nombre': 'nombre_9568',
#   'apellido': 'apellido_9568',
#   'departamento': 10,
#   'sueldo': 16534.0,
#   'fecha': '1998-03-10',
#   'email': 'nombre_9568.apellido_9568@python.com'},
#  21: {'id': 9760,
#   'nombre': 'nombre_9760',
#   'apellido': 'apellido_9760',
#   'departamento': 2,
#   'sueldo': 10541.0,
#   'fecha': '1997-08-30',
#   'email': 'nombre_9760.apellido_9760@python.com'},
#  22: {'id': 7814,
#   'nombre': 'nombre_7814',
#   'apellido': 'apellido_7814',
#   'departamento': 1,
#   'sueldo': 17435.0,
#   'fecha': '2002-12-28',
#   'email': 'nombre_7814.apellido_7814@python.com'},
#  23: {'id': 1841,
#   'nombre': 'nombre_1841',
#   'apellido': 'apellido_1841',
#   'departamento': 9,
#   'sueldo': 12677.0,
#   'fecha': '2019-05-06',
#   'email': 'nombre_1841.apellido_1841@python.com'},
#  24: {'id': 8026,
#   'nombre': 'nombre_8026',
#   'apellido': 'apellido_8026',
#   'departamento': 3,
#   'sueldo': 16541.0,
#   'fecha': '2002-05-30',
#   'email': 'nombre_8026.apellido_8026@python.com'},
#  25: {'id': 7323,
#   'nombre': 'nombre_7323',
#   'apellido': 'apellido_7323',
#   'departamento': 10,
#   'sueldo': 15289.0,
#   'fecha': '2004-05-02',
#   'email': 'nombre_7323.apellido_7323@python.com'},
#  26: {'id': 7963,
#   'nombre': 'nombre_7963',
#   'apellido': 'apellido_7963',
#   'departamento': 6,
#   'sueldo': 11607.0,
#   'fecha': '2002-08-01',
#   'email': 'nombre_7963.apellido_7963@python.com'},
#  27: {'id': 7203,
#   'nombre': 'nombre_7203',
#   'apellido': 'apellido_7203',
#   'departamento': 1,
#   'sueldo': 19182.0,
#   'fecha': '2004-08-30',
#   'email': 'nombre_7203.apellido_7203@python.com'},
#  28: {'id': 2911,
#   'nombre': 'nombre_2911',
#   'apellido': 'apellido_2911',
#   'departamento': 1,
#   'sueldo': 17535.0,
#   'fecha': '2016-05-31',
#   'email': 'nombre_2911.apellido_2911@python.com'},
#  29: {'id': 190,
#   'nombre': 'nombre_190',
#   'apellido': 'apellido_190',
#   'departamento': 9,
#   'sueldo': 13832.0,
#   'fecha': '2023-11-12',
#   'email': 'nombre_190.apellido_190@python.com'},
#  30: {'id': 3922,
#   'nombre': 'nombre_3922',
#   'apellido': 'apellido_3922',
#   'departamento': 4,
#   'sueldo': 12349.0,
#   'fecha': '2013-08-24',
#   'email': 'nombre_3922.apellido_3922@python.com'},
#  31: {'id': 3042,
#   'nombre': 'nombre_3042',
#   'apellido': 'apellido_3042',
#   'departamento': 9,
#   'sueldo': 13892.0,
#   'fecha': '2016-01-21',
#   'email': 'nombre_3042.apellido_3042@python.com'},
#  32: {'id': 3166,
#   'nombre': 'nombre_3166',
#   'apellido': 'apellido_3166',
#   'departamento': 4,
#   'sueldo': 16371.0,
#   'fecha': '2015-09-19',
#   'email': 'nombre_3166.apellido_3166@python.com'},
#  33: {'id': 2256,
#   'nombre': 'nombre_2256',
#   'apellido': 'apellido_2256',
#   'departamento': 5,
#   'sueldo': 10729.0,
#   'fecha': '2018-03-17',
#   'email': 'nombre_2256.apellido_2256@python.com'},
#  34: {'id': 8457,
#   'nombre': 'nombre_8457',
#   'apellido': 'apellido_8457',
#   'departamento': 3,
#   'sueldo': 14964.0,
#   'fecha': '2001-03-25',
#   'email': 'nombre_8457.apellido_8457@python.com'},
#  35: {'id': 7408,
#   'nombre': 'nombre_7408',
#   'apellido': 'apellido_7408',
#   'departamento': 1,
#   'sueldo': 14518.0,
#   'fecha': '2004-02-07',
#   'email': 'nombre_7408.apellido_7408@python.com'},
#  36: {'id': 2406,
#   'nombre': 'nombre_2406',
#   'apellido': 'apellido_2406',
#   'departamento': 7,
#   'sueldo': 11434.0,
#   'fecha': '2017-10-18',
#   'email': 'nombre_2406.apellido_2406@python.com'},
#  37: {'id': 7796,
#   'nombre': 'nombre_7796',
#   'apellido': 'apellido_7796',
#   'departamento': 7,
#   'sueldo': 15986.0,
#   'fecha': '2003-01-15',
#   'email': 'nombre_7796.apellido_7796@python.com'},
#  38: {'id': 8825,
#   'nombre': 'nombre_8825',
#   'apellido': 'apellido_8825',
#   'departamento': 8,
#   'sueldo': 15941.0,
#   'fecha': '2000-03-22',
#   'email': 'nombre_8825.apellido_8825@python.com'},
#  39: {'id': 8783,
#   'nombre': 'nombre_8783',
#   'apellido': 'apellido_8783',
#   'departamento': 9,
#   'sueldo': 19159.0,
#   'fecha': '2000-05-03',
#   'email': 'nombre_8783.apellido_8783@python.com'},
#  40: {'id': 5749,
#   'nombre': 'nombre_5749',
#   'apellido': 'apellido_5749',
#   'departamento': 4,
#   'sueldo': 19269.0,
#   'fecha': '2008-08-23',
#   'email': 'nombre_5749.apellido_5749@python.com'},
#  41: {'id': 5208,
#   'nombre': 'nombre_5208',
#   'apellido': 'apellido_5208',
#   'departamento': 1,
#   'sueldo': 16653.0,
#   'fecha': '2010-02-15',
#   'email': 'nombre_5208.apellido_5208@python.com'},
#  42: {'id': 9958,
#   'nombre': 'nombre_9958',
#   'apellido': 'apellido_9958',
#   'departamento': 10,
#   'sueldo': 17807.0,
#   'fecha': '1997-02-13',
#   'email': 'nombre_9958.apellido_9958@python.com'},
#  43: {'id': 607,
#   'nombre': 'nombre_607',
#   'apellido': 'apellido_607',
#   'departamento': 5,
#   'sueldo': 17981.0,
#   'fecha': '2022-09-21',
#   'email': 'nombre_607.apellido_607@python.com'},
#  44: {'id': 420,
#   'nombre': 'nombre_420',
#   'apellido': 'apellido_420',
#   'departamento': 7,
#   'sueldo': 18496.0,
#   'fecha': '2023-03-27',
#   'email': 'nombre_420.apellido_420@python.com'},
#  45: {'id': 3304,
#   'nombre': 'nombre_3304',
#   'apellido': 'apellido_3304',
#   'departamento': 8,
#   'sueldo': 13842.0,
#   'fecha': '2015-05-04',
#   'email': 'nombre_3304.apellido_3304@python.com'},
#  46: {'id': 4013,
#   'nombre': 'nombre_4013',
#   'apellido': 'apellido_4013',
#   'departamento': 2,
#   'sueldo': 17029.0,
#   'fecha': '2013-05-25',
#   'email': 'nombre_4013.apellido_4013@python.com'},
#  47: {'id': 8384,
#   'nombre': 'nombre_8384',
#   'apellido': 'apellido_8384',
#   'departamento': 3,
#   'sueldo': 12079.0,
#   'fecha': '2001-06-06',
#   'email': 'nombre_8384.apellido_8384@python.com'},
#  48: {'id': 7919,
#   'nombre': 'nombre_7919',
#   'apellido': 'apellido_7919',
#   'departamento': 3,
#   'sueldo': 14229.0,
#   'fecha': '2002-09-14',
#   'email': 'nombre_7919.apellido_7919@python.com'},
#  49: {'id': 666,
#   'nombre': 'nombre_666',
#   'apellido': 'apellido_666',
#   'departamento': 9,
#   'sueldo': 10282.0,
#   'fecha': '2022-07-24',
#   'email': 'nombre_666.apellido_666@python.com'},
#  50: {'id': 5483,
#   'nombre': 'nombre_5483',
#   'apellido': 'apellido_5483',
#   'departamento': 6,
#   'sueldo': 16613.0,
#   'fecha': '2009-05-16',
#   'email': 'nombre_5483.apellido_5483@python.com'},
#  51: {'id': 5272,
#   'nombre': 'nombre_5272',
#   'apellido': 'apellido_5272',
#   'departamento': 1,
#   'sueldo': 16326.0,
#   'fecha': '2009-12-13',
#   'email': 'nombre_5272.apellido_5272@python.com'},
#  52: {'id': 6661,
#   'nombre': 'nombre_6661',
#   'apellido': 'apellido_6661',
#   'departamento': 2,
#   'sueldo': 17343.0,
#   'fecha': '2006-02-23',
#   'email': 'nombre_6661.apellido_6661@python.com'},
#  53: {'id': 6290,
#   'nombre': 'nombre_6290',
#   'apellido': 'apellido_6290',
#   'departamento': 4,
#   'sueldo': 10317.0,
#   'fecha': '2007-03-01',
#   'email': 'nombre_6290.apellido_6290@python.com'},
#  54: {'id': 6229,
#   'nombre': 'nombre_6229',
#   'apellido': 'apellido_6229',
#   'departamento': 10,
#   'sueldo': 12800.0,
#   'fecha': '2007-05-01',
#   'email': 'nombre_6229.apellido_6229@python.com'},
#  55: {'id': 8900,
#   'nombre': 'nombre_8900',
#   'apellido': 'apellido_8900',
#   'departamento': 4,
#   'sueldo': 15696.0,
#   'fecha': '2000-01-07',
#   'email': 'nombre_8900.apellido_8900@python.com'},
#  56: {'id': 2481,
#   'nombre': 'nombre_2481',
#   'apellido': 'apellido_2481',
#   'departamento': 4,
#   'sueldo': 18589.0,
#   'fecha': '2017-08-04',
#   'email': 'nombre_2481.apellido_2481@python.com'},
#  57: {'id': 3825,
#   'nombre': 'nombre_3825',
#   'apellido': 'apellido_3825',
#   'departamento': 4,
#   'sueldo': 17112.0,
#   'fecha': '2013-11-29',
#   'email': 'nombre_3825.apellido_3825@python.com'},
#  58: {'id': 2121,
#   'nombre': 'nombre_2121',
#   'apellido': 'apellido_2121',
#   'departamento': 5,
#   'sueldo': 19237.0,
#   'fecha': '2018-07-30',
#   'email': 'nombre_2121.apellido_2121@python.com'},
#  59: {'id': 5655,
#   'nombre': 'nombre_5655',
#   'apellido': 'apellido_5655',
#   'departamento': 10,
#   'sueldo': 12303.0,
#   'fecha': '2008-11-25',
#   'email': 'nombre_5655.apellido_5655@python.com'},
#  60: {'id': 1056,
#   'nombre': 'nombre_1056',
#   'apellido': 'apellido_1056',
#   'departamento': 10,
#   'sueldo': 16860.0,
#   'fecha': '2021-06-29',
#   'email': 'nombre_1056.apellido_1056@python.com'},
#  61: {'id': 2698,
#   'nombre': 'nombre_2698',
#   'apellido': 'apellido_2698',
#   'departamento': 5,
#   'sueldo': 18910.0,
#   'fecha': '2016-12-30',
#   'email': 'nombre_2698.apellido_2698@python.com'},
#  62: {'id': 7283,
#   'nombre': 'nombre_7283',
#   'apellido': 'apellido_7283',
#   'departamento': 1,
#   'sueldo': 11293.0,
#   'fecha': '2004-06-11',
#   'email': 'nombre_7283.apellido_7283@python.com'},
#  63: {'id': 1927,
#   'nombre': 'nombre_1927',
#   'apellido': 'apellido_1927',
#   'departamento': 2,
#   'sueldo': 13131.0,
#   'fecha': '2019-02-09',
#   'email': 'nombre_1927.apellido_1927@python.com'},
#  64: {'id': 861,
#   'nombre': 'nombre_861',
#   'apellido': 'apellido_861',
#   'departamento': 1,
#   'sueldo': 18394.0,
#   'fecha': '2022-01-10',
#   'email': 'nombre_861.apellido_861@python.com'},
#  65: {'id': 3033,
#   'nombre': 'nombre_3033',
#   'apellido': 'apellido_3033',
#   'departamento': 7,
#   'sueldo': 15095.0,
#   'fecha': '2016-01-30',
#   'email': 'nombre_3033.apellido_3033@python.com'},
#  66: {'id': 4609,
#   'nombre': 'nombre_4609',
#   'apellido': 'apellido_4609',
#   'departamento': 5,
#   'sueldo': 14243.0,
#   'fecha': '2011-10-07',
#   'email': 'nombre_4609.apellido_4609@python.com'},
#  67: {'id': 7843,
#   'nombre': 'nombre_7843',
#   'apellido': 'apellido_7843',
#   'departamento': 7,
#   'sueldo': 11519.0,
#   'fecha': '2002-11-29',
#   'email': 'nombre_7843.apellido_7843@python.com'},
#  68: {'id': 5345,
#   'nombre': 'nombre_5345',
#   'apellido': 'apellido_5345',
#   'departamento': 4,
#   'sueldo': 13805.0,
#   'fecha': '2009-10-01',
#   'email': 'nombre_5345.apellido_5345@python.com'},
#  69: {'id': 8480,
#   'nombre': 'nombre_8480',
#   'apellido': 'apellido_8480',
#   'departamento': 5,
#   'sueldo': 10561.0,
#   'fecha': '2001-03-02',
#   'email': 'nombre_8480.apellido_8480@python.com'},
#  70: {'id': 9999,
#   'nombre': 'nombre_9999',
#   'apellido': 'apellido_9999',
#   'departamento': 4,
#   'sueldo': 10975.0,
#   'fecha': '1997-01-03',
#   'email': 'nombre_9999.apellido_9999@python.com'},
#  71: {'id': 8950,
#   'nombre': 'nombre_8950',
#   'apellido': 'apellido_8950',
#   'departamento': 2,
#   'sueldo': 11964.0,
#   'fecha': '1999-11-18',
#   'email': 'nombre_8950.apellido_8950@python.com'},
#  72: {'id': 8791,
#   'nombre': 'nombre_8791',
#   'apellido': 'apellido_8791',
#   'departamento': 7,
#   'sueldo': 11673.0,
#   'fecha': '2000-04-25',
#   'email': 'nombre_8791.apellido_8791@python.com'},
#  73: {'id': 9834,
#   'nombre': 'nombre_9834',
#   'apellido': 'apellido_9834',
#   'departamento': 5,
#   'sueldo': 18726.0,
#   'fecha': '1997-06-17',
#   'email': 'nombre_9834.apellido_9834@python.com'},
#  74: {'id': 2966,
#   'nombre': 'nombre_2966',
#   'apellido': 'apellido_2966',
#   'departamento': 6,
#   'sueldo': 13095.0,
#   'fecha': '2016-04-06',
#   'email': 'nombre_2966.apellido_2966@python.com'},
#  75: {'id': 4439,
#   'nombre': 'nombre_4439',
#   'apellido': 'apellido_4439',
#   'departamento': 8,
#   'sueldo': 11601.0,
#   'fecha': '2012-03-25',
#   'email': 'nombre_4439.apellido_4439@python.com'},
#  76: {'id': 2904,
#   'nombre': 'nombre_2904',
#   'apellido': 'apellido_2904',
#   'departamento': 7,
#   'sueldo': 16649.0,
#   'fecha': '2016-06-07',
#   'email': 'nombre_2904.apellido_2904@python.com'},
#  77: {'id': 8253,
#   'nombre': 'nombre_8253',
#   'apellido': 'apellido_8253',
#   'departamento': 5,
#   'sueldo': 13245.0,
#   'fecha': '2001-10-15',
#   'email': 'nombre_8253.apellido_8253@python.com'},
#  78: {'id': 5850,
#   'nombre': 'nombre_5850',
#   'apellido': 'apellido_5850',
#   'departamento': 10,
#   'sueldo': 11976.0,
#   'fecha': '2008-05-14',
#   'email': 'nombre_5850.apellido_5850@python.com'},
#  79: {'id': 8689,
#   'nombre': 'nombre_8689',
#   'apellido': 'apellido_8689',
#   'departamento': 9,
#   'sueldo': 19574.0,
#   'fecha': '2000-08-05',
#   'email': 'nombre_8689.apellido_8689@python.com'},
#  80: {'id': 3158,
#   'nombre': 'nombre_3158',
#   'apellido': 'apellido_3158',
#   'departamento': 4,
#   'sueldo': 13117.0,
#   'fecha': '2015-09-27',
#   'email': 'nombre_3158.apellido_3158@python.com'},
#  81: {'id': 2700,
#   'nombre': 'nombre_2700',
#   'apellido': 'apellido_2700',
#   'departamento': 2,
#   'sueldo': 17487.0,
#   'fecha': '2016-12-28',
#   'email': 'nombre_2700.apellido_2700@python.com'},
#  82: {'id': 3891,
#   'nombre': 'nombre_3891',
#   'apellido': 'apellido_3891',
#   'departamento': 6,
#   'sueldo': 17651.0,
#   'fecha': '2013-09-24',
#   'email': 'nombre_3891.apellido_3891@python.com'},
#  83: {'id': 1202,
#   'nombre': 'nombre_1202',
#   'apellido': 'apellido_1202',
#   'departamento': 10,
#   'sueldo': 11020.0,
#   'fecha': '2021-02-03',
#   'email': 'nombre_1202.apellido_1202@python.com'},
#  84: {'id': 3314,
#   'nombre': 'nombre_3314',
#   'apellido': 'apellido_3314',
#   'departamento': 1,
#   'sueldo': 14369.0,
#   'fecha': '2015-04-24',
#   'email': 'nombre_3314.apellido_3314@python.com'},
#  85: {'id': 7045,
#   'nombre': 'nombre_7045',
#   'apellido': 'apellido_7045',
#   'departamento': 10,
#   'sueldo': 14119.0,
#   'fecha': '2005-02-04',
#   'email': 'nombre_7045.apellido_7045@python.com'},
#  86: {'id': 6549,
#   'nombre': 'nombre_6549',
#   'apellido': 'apellido_6549',
#   'departamento': 8,
#   'sueldo': 18406.0,
#   'fecha': '2006-06-15',
#   'email': 'nombre_6549.apellido_6549@python.com'},
#  87: {'id': 43,
#   'nombre': 'nombre_43',
#   'apellido': 'apellido_43',
#   'departamento': 8,
#   'sueldo': 16915.0,
#   'fecha': '2024-04-07',
#   'email': 'nombre_43.apellido_43@python.com'},
#  88: {'id': 1308,
#   'nombre': 'nombre_1308',
#   'apellido': 'apellido_1308',
#   'departamento': 5,
#   'sueldo': 17648.0,
#   'fecha': '2020-10-20',
#   'email': 'nombre_1308.apellido_1308@python.com'},
#  89: {'id': 9357,
#   'nombre': 'nombre_9357',
#   'apellido': 'apellido_9357',
#   'departamento': 4,
#   'sueldo': 10049.0,
#   'fecha': '1998-10-07',
#   'email': 'nombre_9357.apellido_9357@python.com'},
#  90: {'id': 2239,
#   'nombre': 'nombre_2239',
#   'apellido': 'apellido_2239',
#   'departamento': 10,
#   'sueldo': 16462.0,
#   'fecha': '2018-04-03',
#   'email': 'nombre_2239.apellido_2239@python.com'},
#  91: {'id': 3917,
#   'nombre': 'nombre_3917',
#   'apellido': 'apellido_3917',
#   'departamento': 10,
#   'sueldo': 16694.0,
#   'fecha': '2013-08-29',
#   'email': 'nombre_3917.apellido_3917@python.com'},
#  92: {'id': 5545,
#   'nombre': 'nombre_5545',
#   'apellido': 'apellido_5545',
#   'departamento': 10,
#   'sueldo': 13885.0,
#   'fecha': '2009-03-15',
#   'email': 'nombre_5545.apellido_5545@python.com'},
#  93: {'id': 5609,
#   'nombre': 'nombre_5609',
#   'apellido': 'apellido_5609',
#   'departamento': 6,
#   'sueldo': 14648.0,
#   'fecha': '2009-01-10',
#   'email': 'nombre_5609.apellido_5609@python.com'},
#  94: {'id': 9518,
#   'nombre': 'nombre_9518',
#   'apellido': 'apellido_9518',
#   'departamento': 1,
#   'sueldo': 13301.0,
#   'fecha': '1998-04-29',
#   'email': 'nombre_9518.apellido_9518@python.com'},
#  95: {'id': 4638,
#   'nombre': 'nombre_4638',
#   'apellido': 'apellido_4638',
#   'departamento': 4,
#   'sueldo': 17643.0,
#   'fecha': '2011-09-08',
#   'email': 'nombre_4638.apellido_4638@python.com'},
#  96: {'id': 1301,
#   'nombre': 'nombre_1301',
#   'apellido': 'apellido_1301',
#   'departamento': 9,
#   'sueldo': 16396.0,
#   'fecha': '2020-10-27',
#   'email': 'nombre_1301.apellido_1301@python.com'},
#  97: {'id': 1864,
#   'nombre': 'nombre_1864',
#   'apellido': 'apellido_1864',
#   'departamento': 3,
#   'sueldo': 19127.0,
#   'fecha': '2019-04-13',
#   'email': 'nombre_1864.apellido_1864@python.com'},
#  98: {'id': 526,
#   'nombre': 'nombre_526',
#   'apellido': 'apellido_526',
#   'departamento': 9,
#   'sueldo': 11581.0,
#   'fecha': '2022-12-11',
#   'email': 'nombre_526.apellido_526@python.com'},
#  99: {'id': 646,
#   'nombre': 'nombre_646',
#   'apellido': 'apellido_646',
#   'departamento': 9,
#   'sueldo': 16426.0,
#   'fecha': '2022-08-13',
#   'email': 'nombre_646.apellido_646@python.com'},
#  100: {'id': 2274,
#   'nombre': 'nombre_2274',
#   'apellido': 'apellido_2274',
#   'departamento': 7,
#   'sueldo': 15647.0,
#   'fecha': '2018-02-27',
#   'email': 'nombre_2274.apellido_2274@python.com'},
#  101: {'id': 3285,
#   'nombre': 'nombre_3285',
#   'apellido': 'apellido_3285',
#   'departamento': 1,
#   'sueldo': 14938.0,
#   'fecha': '2015-05-23',
#   'email': 'nombre_3285.apellido_3285@python.com'},
#  102: {'id': 105,
#   'nombre': 'nombre_105',
#   'apellido': 'apellido_105',
#   'departamento': 6,
#   'sueldo': 12033.0,
#   'fecha': '2024-02-05',
#   'email': 'nombre_105.apellido_105@python.com'},
#  103: {'id': 7392,
#   'nombre': 'nombre_7392',
#   'apellido': 'apellido_7392',
#   'departamento': 6,
#   'sueldo': 12443.0,
#   'fecha': '2004-02-23',
#   'email': 'nombre_7392.apellido_7392@python.com'},
#  104: {'id': 8984,
#   'nombre': 'nombre_8984',
#   'apellido': 'apellido_8984',
#   'departamento': 9,
#   'sueldo': 17580.0,
#   'fecha': '1999-10-15',
#   'email': 'nombre_8984.apellido_8984@python.com'},
#  105: {'id': 3944,
#   'nombre': 'nombre_3944',
#   'apellido': 'apellido_3944',
#   'departamento': 10,
#   'sueldo': 18508.0,
#   'fecha': '2013-08-02',
#   'email': 'nombre_3944.apellido_3944@python.com'},
#  106: {'id': 7327,
#   'nombre': 'nombre_7327',
#   'apellido': 'apellido_7327',
#   'departamento': 10,
#   'sueldo': 14885.0,
#   'fecha': '2004-04-28',
#   'email': 'nombre_7327.apellido_7327@python.com'},
#  107: {'id': 1053,
#   'nombre': 'nombre_1053',
#   'apellido': 'apellido_1053',
#   'departamento': 4,
#   'sueldo': 10041.0,
#   'fecha': '2021-07-02',
#   'email': 'nombre_1053.apellido_1053@python.com'},
#  108: {'id': 9409,
#   'nombre': 'nombre_9409',
#   'apellido': 'apellido_9409',
#   'departamento': 8,
#   'sueldo': 16822.0,
#   'fecha': '1998-08-16',
#   'email': 'nombre_9409.apellido_9409@python.com'},
#  109: {'id': 7670,
#   'nombre': 'nombre_7670',
#   'apellido': 'apellido_7670',
#   'departamento': 7,
#   'sueldo': 13026.0,
#   'fecha': '2003-05-21',
#   'email': 'nombre_7670.apellido_7670@python.com'},
#  110: {'id': 1043,
#   'nombre': 'nombre_1043',
#   'apellido': 'apellido_1043',
#   'departamento': 5,
#   'sueldo': 16444.0,
#   'fecha': '2021-07-12',
#   'email': 'nombre_1043.apellido_1043@python.com'},
#  111: {'id': 880,
#   'nombre': 'nombre_880',
#   'apellido': 'apellido_880',
#   'departamento': 10,
#   'sueldo': 18450.0,
#   'fecha': '2021-12-22',
#   'email': 'nombre_880.apellido_880@python.com'},
#  112: {'id': 3859,
#   'nombre': 'nombre_3859',
#   'apellido': 'apellido_3859',
#   'departamento': 3,
#   'sueldo': 11596.0,
#   'fecha': '2013-10-26',
#   'email': 'nombre_3859.apellido_3859@python.com'},
#  113: {'id': 6948,
#   'nombre': 'nombre_6948',
#   'apellido': 'apellido_6948',
#   'departamento': 8,
#   'sueldo': 11721.0,
#   'fecha': '2005-05-12',
#   'email': 'nombre_6948.apellido_6948@python.com'},
#  114: {'id': 7785,
#   'nombre': 'nombre_7785',
#   'apellido': 'apellido_7785',
#   'departamento': 6,
#   'sueldo': 11147.0,
#   'fecha': '2003-01-26',
#   'email': 'nombre_7785.apellido_7785@python.com'},
#  115: {'id': 8141,
#   'nombre': 'nombre_8141',
#   'apellido': 'apellido_8141',
#   'departamento': 3,
#   'sueldo': 11011.0,
#   'fecha': '2002-02-04',
#   'email': 'nombre_8141.apellido_8141@python.com'},
#  116: {'id': 7560,
#   'nombre': 'nombre_7560',
#   'apellido': 'apellido_7560',
#   'departamento': 2,
#   'sueldo': 17123.0,
#   'fecha': '2003-09-08',
#   'email': 'nombre_7560.apellido_7560@python.com'},
#  117: {'id': 1796,
#   'nombre': 'nombre_1796',
#   'apellido': 'apellido_1796',
#   'departamento': 9,
#   'sueldo': 14164.0,
#   'fecha': '2019-06-20',
#   'email': 'nombre_1796.apellido_1796@python.com'},
#  118: {'id': 256,
#   'nombre': 'nombre_256',
#   'apellido': 'apellido_256',
#   'departamento': 8,
#   'sueldo': 12023.0,
#   'fecha': '2023-09-07',
#   'email': 'nombre_256.apellido_256@python.com'},
#  119: {'id': 635,
#   'nombre': 'nombre_635',
#   'apellido': 'apellido_635',
#   'departamento': 6,
#   'sueldo': 19111.0,
#   'fecha': '2022-08-24',
#   'email': 'nombre_635.apellido_635@python.com'},
#  120: {'id': 3916,
#   'nombre': 'nombre_3916',
#   'apellido': 'apellido_3916',
#   'departamento': 6,
#   'sueldo': 19838.0,
#   'fecha': '2013-08-30',
#   'email': 'nombre_3916.apellido_3916@python.com'},
#  121: {'id': 7375,
#   'nombre': 'nombre_7375',
#   'apellido': 'apellido_7375',
#   'departamento': 7,
#   'sueldo': 16252.0,
#   'fecha': '2004-03-11',
#   'email': 'nombre_7375.apellido_7375@python.com'},
#  122: {'id': 8708,
#   'nombre': 'nombre_8708',
#   'apellido': 'apellido_8708',
#   'departamento': 1,
#   'sueldo': 12820.0,
#   'fecha': '2000-07-17',
#   'email': 'nombre_8708.apellido_8708@python.com'},
#  123: {'id': 3726,
#   'nombre': 'nombre_3726',
#   'apellido': 'apellido_3726',
#   'departamento': 4,
#   'sueldo': 15646.0,
#   'fecha': '2014-03-08',
#   'email': 'nombre_3726.apellido_3726@python.com'},
#  124: {'id': 5842,
#   'nombre': 'nombre_5842',
#   'apellido': 'apellido_5842',
#   'departamento': 4,
#   'sueldo': 12752.0,
#   'fecha': '2008-05-22',
#   'email': 'nombre_5842.apellido_5842@python.com'},
#  125: {'id': 1915,
#   'nombre': 'nombre_1915',
#   'apellido': 'apellido_1915',
#   'departamento': 8,
#   'sueldo': 11867.0,
#   'fecha': '2019-02-21',
#   'email': 'nombre_1915.apellido_1915@python.com'},
#  126: {'id': 1049,
#   'nombre': 'nombre_1049',
#   'apellido': 'apellido_1049',
#   'departamento': 4,
#   'sueldo': 11786.0,
#   'fecha': '2021-07-06',
#   'email': 'nombre_1049.apellido_1049@python.com'},
#  127: {'id': 4145,
#   'nombre': 'nombre_4145',
#   'apellido': 'apellido_4145',
#   'departamento': 10,
#   'sueldo': 16471.0,
#   'fecha': '2013-01-13',
#   'email': 'nombre_4145.apellido_4145@python.com'},
#  128: {'id': 8058,
#   'nombre': 'nombre_8058',
#   'apellido': 'apellido_8058',
#   'departamento': 6,
#   'sueldo': 13323.0,
#   'fecha': '2002-04-28',
#   'email': 'nombre_8058.apellido_8058@python.com'},
#  129: {'id': 1479,
#   'nombre': 'nombre_1479',
#   'apellido': 'apellido_1479',
#   'departamento': 4,
#   'sueldo': 10889.0,
#   'fecha': '2020-05-02',
#   'email': 'nombre_1479.apellido_1479@python.com'},
#  130: {'id': 8638,
#   'nombre': 'nombre_8638',
#   'apellido': 'apellido_8638',
#   'departamento': 10,
#   'sueldo': 15410.0,
#   'fecha': '2000-09-25',
#   'email': 'nombre_8638.apellido_8638@python.com'},
#  131: {'id': 3754,
#   'nombre': 'nombre_3754',
#   'apellido': 'apellido_3754',
#   'departamento': 4,
#   'sueldo': 14569.0,
#   'fecha': '2014-02-08',
#   'email': 'nombre_3754.apellido_3754@python.com'},
#  132: {'id': 7157,
#   'nombre': 'nombre_7157',
#   'apellido': 'apellido_7157',
#   'departamento': 9,
#   'sueldo': 16632.0,
#   'fecha': '2004-10-15',
#   'email': 'nombre_7157.apellido_7157@python.com'},
#  133: {'id': 9398,
#   'nombre': 'nombre_9398',
#   'apellido': 'apellido_9398',
#   'departamento': 7,
#   'sueldo': 16683.0,
#   'fecha': '1998-08-27',
#   'email': 'nombre_9398.apellido_9398@python.com'},
#  134: {'id': 5335,
#   'nombre': 'nombre_5335',
#   'apellido': 'apellido_5335',
#   'departamento': 1,
#   'sueldo': 18026.0,
#   'fecha': '2009-10-11',
#   'email': 'nombre_5335.apellido_5335@python.com'},
#  135: {'id': 3559,
#   'nombre': 'nombre_3559',
#   'apellido': 'apellido_3559',
#   'departamento': 10,
#   'sueldo': 15766.0,
#   'fecha': '2014-08-22',
#   'email': 'nombre_3559.apellido_3559@python.com'},
#  136: {'id': 2656,
#   'nombre': 'nombre_2656',
#   'apellido': 'apellido_2656',
#   'departamento': 10,
#   'sueldo': 18162.0,
#   'fecha': '2017-02-10',
#   'email': 'nombre_2656.apellido_2656@python.com'},
#  137: {'id': 1781,
#   'nombre': 'nombre_1781',
#   'apellido': 'apellido_1781',
#   'departamento': 4,
#   'sueldo': 14342.0,
#   'fecha': '2019-07-05',
#   'email': 'nombre_1781.apellido_1781@python.com'},
#  138: {'id': 9763,
#   'nombre': 'nombre_9763',
#   'apellido': 'apellido_9763',
#   'departamento': 8,
#   'sueldo': 11616.0,
#   'fecha': '1997-08-27',
#   'email': 'nombre_9763.apellido_9763@python.com'},
#  139: {'id': 9233,
#   'nombre': 'nombre_9233',
#   'apellido': 'apellido_9233',
#   'departamento': 3,
#   'sueldo': 13165.0,
#   'fecha': '1999-02-08',
#   'email': 'nombre_9233.apellido_9233@python.com'},
#  140: {'id': 6854,
#   'nombre': 'nombre_6854',
#   'apellido': 'apellido_6854',
#   'departamento': 1,
#   'sueldo': 13597.0,
#   'fecha': '2005-08-14',
#   'email': 'nombre_6854.apellido_6854@python.com'},
#  141: {'id': 3610,
#   'nombre': 'nombre_3610',
#   'apellido': 'apellido_3610',
#   'departamento': 1,
#   'sueldo': 12318.0,
#   'fecha': '2014-07-02',
#   'email': 'nombre_3610.apellido_3610@python.com'},
#  142: {'id': 321,
#   'nombre': 'nombre_321',
#   'apellido': 'apellido_321',
#   'departamento': 2,
#   'sueldo': 12108.0,
#   'fecha': '2023-07-04',
#   'email': 'nombre_321.apellido_321@python.com'},
#  143: {'id': 6892,
#   'nombre': 'nombre_6892',
#   'apellido': 'apellido_6892',
#   'departamento': 2,
#   'sueldo': 16510.0,
#   'fecha': '2005-07-07',
#   'email': 'nombre_6892.apellido_6892@python.com'},
#  144: {'id': 3543,
#   'nombre': 'nombre_3543',
#   'apellido': 'apellido_3543',
#   'departamento': 2,
#   'sueldo': 17695.0,
#   'fecha': '2014-09-07',
#   'email': 'nombre_3543.apellido_3543@python.com'},
#  145: {'id': 4242,
#   'nombre': 'nombre_4242',
#   'apellido': 'apellido_4242',
#   'departamento': 4,
#   'sueldo': 17761.0,
#   'fecha': '2012-10-08',
#   'email': 'nombre_4242.apellido_4242@python.com'},
#  146: {'id': 3672,
#   'nombre': 'nombre_3672',
#   'apellido': 'apellido_3672',
#   'departamento': 8,
#   'sueldo': 16024.0,
#   'fecha': '2014-05-01',
#   'email': 'nombre_3672.apellido_3672@python.com'},
#  147: {'id': 4115,
#   'nombre': 'nombre_4115',
#   'apellido': 'apellido_4115',
#   'departamento': 7,
#   'sueldo': 15905.0,
#   'fecha': '2013-02-12',
#   'email': 'nombre_4115.apellido_4115@python.com'},
#  148: {'id': 894,
#   'nombre': 'nombre_894',
#   'apellido': 'apellido_894',
#   'departamento': 5,
#   'sueldo': 12541.0,
#   'fecha': '2021-12-08',
#   'email': 'nombre_894.apellido_894@python.com'},
#  149: {'id': 8505,
#   'nombre': 'nombre_8505',
#   'apellido': 'apellido_8505',
#   'departamento': 9,
#   'sueldo': 10367.0,
#   'fecha': '2001-02-05',
#   'email': 'nombre_8505.apellido_8505@python.com'},
#  150: {'id': 3890,
#   'nombre': 'nombre_3890',
#   'apellido': 'apellido_3890',
#   'departamento': 8,
#   'sueldo': 10616.0,
#   'fecha': '2013-09-25',
#   'email': 'nombre_3890.apellido_3890@python.com'},
#  151: {'id': 5267,
#   'nombre': 'nombre_5267',
#   'apellido': 'apellido_5267',
#   'departamento': 9,
#   'sueldo': 11228.0,
#   'fecha': '2009-12-18',
#   'email': 'nombre_5267.apellido_5267@python.com'},
#  152: {'id': 6618,
#   'nombre': 'nombre_6618',
#   'apellido': 'apellido_6618',
#   'departamento': 5,
#   'sueldo': 10162.0,
#   'fecha': '2006-04-07',
#   'email': 'nombre_6618.apellido_6618@python.com'},
#  153: {'id': 3522,
#   'nombre': 'nombre_3522',
#   'apellido': 'apellido_3522',
#   'departamento': 6,
#   'sueldo': 14986.0,
#   'fecha': '2014-09-28',
#   'email': 'nombre_3522.apellido_3522@python.com'},
#  154: {'id': 3736,
#   'nombre': 'nombre_3736',
#   'apellido': 'apellido_3736',
#   'departamento': 9,
#   'sueldo': 15206.0,
#   'fecha': '2014-02-26',
#   'email': 'nombre_3736.apellido_3736@python.com'},
#  155: {'id': 1312,
#   'nombre': 'nombre_1312',
#   'apellido': 'apellido_1312',
#   'departamento': 2,
#   'sueldo': 17919.0,
#   'fecha': '2020-10-16',
#   'email': 'nombre_1312.apellido_1312@python.com'},
#  156: {'id': 9894,
#   'nombre': 'nombre_9894',
#   'apellido': 'apellido_9894',
#   'departamento': 9,
#   'sueldo': 16905.0,
#   'fecha': '1997-04-18',
#   'email': 'nombre_9894.apellido_9894@python.com'},
#  157: {'id': 193,
#   'nombre': 'nombre_193',
#   'apellido': 'apellido_193',
#   'departamento': 6,
#   'sueldo': 10154.0,
#   'fecha': '2023-11-09',
#   'email': 'nombre_193.apellido_193@python.com'},
#  158: {'id': 4690,
#   'nombre': 'nombre_4690',
#   'apellido': 'apellido_4690',
#   'departamento': 2,
#   'sueldo': 11266.0,
#   'fecha': '2011-07-18',
#   'email': 'nombre_4690.apellido_4690@python.com'},
#  159: {'id': 5262,
#   'nombre': 'nombre_5262',
#   'apellido': 'apellido_5262',
#   'departamento': 10,
#   'sueldo': 14724.0,
#   'fecha': '2009-12-23',
#   'email': 'nombre_5262.apellido_5262@python.com'},
#  160: {'id': 6075,
#   'nombre': 'nombre_6075',
#   'apellido': 'apellido_6075',
#   'departamento': 3,
#   'sueldo': 19039.0,
#   'fecha': '2007-10-02',
#   'email': 'nombre_6075.apellido_6075@python.com'},
#  161: {'id': 9385,
#   'nombre': 'nombre_9385',
#   'apellido': 'apellido_9385',
#   'departamento': 9,
#   'sueldo': 12405.0,
#   'fecha': '1998-09-09',
#   'email': 'nombre_9385.apellido_9385@python.com'},
#  162: {'id': 9324,
#   'nombre': 'nombre_9324',
#   'apellido': 'apellido_9324',
#   'departamento': 1,
#   'sueldo': 15114.0,
#   'fecha': '1998-11-09',
#   'email': 'nombre_9324.apellido_9324@python.com'},
#  163: {'id': 6126,
#   'nombre': 'nombre_6126',
#   'apellido': 'apellido_6126',
#   'departamento': 9,
#   'sueldo': 18655.0,
#   'fecha': '2007-08-12',
#   'email': 'nombre_6126.apellido_6126@python.com'},
#  164: {'id': 8828,
#   'nombre': 'nombre_8828',
#   'apellido': 'apellido_8828',
#   'departamento': 8,
#   'sueldo': 19704.0,
#   'fecha': '2000-03-19',
#   'email': 'nombre_8828.apellido_8828@python.com'},
#  165: {'id': 6325,
#   'nombre': 'nombre_6325',
#   'apellido': 'apellido_6325',
#   'departamento': 2,
#   'sueldo': 11369.0,
#   'fecha': '2007-01-25',
#   'email': 'nombre_6325.apellido_6325@python.com'},
#  166: {'id': 9354,
#   'nombre': 'nombre_9354',
#   'apellido': 'apellido_9354',
#   'departamento': 4,
#   'sueldo': 11515.0,
#   'fecha': '1998-10-10',
#   'email': 'nombre_9354.apellido_9354@python.com'},
#  167: {'id': 9853,
#   'nombre': 'nombre_9853',
#   'apellido': 'apellido_9853',
#   'departamento': 8,
#   'sueldo': 18895.0,
#   'fecha': '1997-05-29',
#   'email': 'nombre_9853.apellido_9853@python.com'},
#  168: {'id': 5250,
#   'nombre': 'nombre_5250',
#   'apellido': 'apellido_5250',
#   'departamento': 3,
#   'sueldo': 14027.0,
#   'fecha': '2010-01-04',
#   'email': 'nombre_5250.apellido_5250@python.com'},
#  169: {'id': 5648,
#   'nombre': 'nombre_5648',
#   'apellido': 'apellido_5648',
#   'departamento': 9,
#   'sueldo': 15092.0,
#   'fecha': '2008-12-02',
#   'email': 'nombre_5648.apellido_5648@python.com'},
#  170: {'id': 3686,
#   'nombre': 'nombre_3686',
#   'apellido': 'apellido_3686',
#   'departamento': 5,
#   'sueldo': 13496.0,
#   'fecha': '2014-04-17',
#   'email': 'nombre_3686.apellido_3686@python.com'},
#  171: {'id': 2930,
#   'nombre': 'nombre_2930',
#   'apellido': 'apellido_2930',
#   'departamento': 6,
#   'sueldo': 19946.0,
#   'fecha': '2016-05-12',
#   'email': 'nombre_2930.apellido_2930@python.com'},
#  172: {'id': 8022,
#   'nombre': 'nombre_8022',
#   'apellido': 'apellido_8022',
#   'departamento': 7,
#   'sueldo': 10032.0,
#   'fecha': '2002-06-03',
#   'email': 'nombre_8022.apellido_8022@python.com'},
#  173: {'id': 5688,
#   'nombre': 'nombre_5688',
#   'apellido': 'apellido_5688',
#   'departamento': 5,
#   'sueldo': 11739.0,
#   'fecha': '2008-10-23',
#   'email': 'nombre_5688.apellido_5688@python.com'},
#  174: {'id': 3679,
#   'nombre': 'nombre_3679',
#   'apellido': 'apellido_3679',
#   'departamento': 9,
#   'sueldo': 15106.0,
#   'fecha': '2014-04-24',
#   'email': 'nombre_3679.apellido_3679@python.com'},
#  175: {'id': 6836,
#   'nombre': 'nombre_6836',
#   'apellido': 'apellido_6836',
#   'departamento': 4,
#   'sueldo': 10568.0,
#   'fecha': '2005-09-01',
#   'email': 'nombre_6836.apellido_6836@python.com'},
#  176: {'id': 7196,
#   'nombre': 'nombre_7196',
#   'apellido': 'apellido_7196',
#   'departamento': 3,
#   'sueldo': 19041.0,
#   'fecha': '2004-09-06',
#   'email': 'nombre_7196.apellido_7196@python.com'},
#  177: {'id': 4640,
#   'nombre': 'nombre_4640',
#   'apellido': 'apellido_4640',
#   'departamento': 10,
#   'sueldo': 15708.0,
#   'fecha': '2011-09-06',
#   'email': 'nombre_4640.apellido_4640@python.com'},
#  178: {'id': 9495,
#   'nombre': 'nombre_9495',
#   'apellido': 'apellido_9495',
#   'departamento': 2,
#   'sueldo': 13746.0,
#   'fecha': '1998-05-22',
#   'email': 'nombre_9495.apellido_9495@python.com'},
#  179: {'id': 4736,
#   'nombre': 'nombre_4736',
#   'apellido': 'apellido_4736',
#   'departamento': 9,
#   'sueldo': 19433.0,
#   'fecha': '2011-06-02',
#   'email': 'nombre_4736.apellido_4736@python.com'},
#  180: {'id': 5454,
#   'nombre': 'nombre_5454',
#   'apellido': 'apellido_5454',
#   'departamento': 9,
#   'sueldo': 13458.0,
#   'fecha': '2009-06-14',
#   'email': 'nombre_5454.apellido_5454@python.com'},
#  181: {'id': 9280,
#   'nombre': 'nombre_9280',
#   'apellido': 'apellido_9280',
#   'departamento': 3,
#   'sueldo': 16470.0,
#   'fecha': '1998-12-23',
#   'email': 'nombre_9280.apellido_9280@python.com'},
#  182: {'id': 8036,
#   'nombre': 'nombre_8036',
#   'apellido': 'apellido_8036',
#   'departamento': 9,
#   'sueldo': 10800.0,
#   'fecha': '2002-05-20',
#   'email': 'nombre_8036.apellido_8036@python.com'},
#  183: {'id': 7651,
#   'nombre': 'nombre_7651',
#   'apellido': 'apellido_7651',
#   'departamento': 2,
#   'sueldo': 19542.0,
#   'fecha': '2003-06-09',
#   'email': 'nombre_7651.apellido_7651@python.com'},
#  184: {'id': 5954,
#   'nombre': 'nombre_5954',
#   'apellido': 'apellido_5954',
#   'departamento': 7,
#   'sueldo': 14207.0,
#   'fecha': '2008-01-31',
#   'email': 'nombre_5954.apellido_5954@python.com'},
#  185: {'id': 921,
#   'nombre': 'nombre_921',
#   'apellido': 'apellido_921',
#   'departamento': 3,
#   'sueldo': 10914.0,
#   'fecha': '2021-11-11',
#   'email': 'nombre_921.apellido_921@python.com'},
#  186: {'id': 3942,
#   'nombre': 'nombre_3942',
#   'apellido': 'apellido_3942',
#   'departamento': 8,
#   'sueldo': 14379.0,
#   'fecha': '2013-08-04',
#   'email': 'nombre_3942.apellido_3942@python.com'},
#  187: {'id': 452,
#   'nombre': 'nombre_452',
#   'apellido': 'apellido_452',
#   'departamento': 7,
#   'sueldo': 12205.0,
#   'fecha': '2023-02-23',
#   'email': 'nombre_452.apellido_452@python.com'},
#  188: {'id': 5413,
#   'nombre': 'nombre_5413',
#   'apellido': 'apellido_5413',
#   'departamento': 1,
#   'sueldo': 12582.0,
#   'fecha': '2009-07-25',
#   'email': 'nombre_5413.apellido_5413@python.com'},
#  189: {'id': 2920,
#   'nombre': 'nombre_2920',
#   'apellido': 'apellido_2920',
#   'departamento': 9,
#   'sueldo': 10825.0,
#   'fecha': '2016-05-22',
#   'email': 'nombre_2920.apellido_2920@python.com'},
#  190: {'id': 1270,
#   'nombre': 'nombre_1270',
#   'apellido': 'apellido_1270',
#   'departamento': 7,
#   'sueldo': 13104.0,
#   'fecha': '2020-11-27',
#   'email': 'nombre_1270.apellido_1270@python.com'},
#  191: {'id': 2174,
#   'nombre': 'nombre_2174',
#   'apellido': 'apellido_2174',
#   'departamento': 8,
#   'sueldo': 12031.0,
#   'fecha': '2018-06-07',
#   'email': 'nombre_2174.apellido_2174@python.com'},
#  192: {'id': 3166,
#   'nombre': 'nombre_3166',
#   'apellido': 'apellido_3166',
#   'departamento': 9,
#   'sueldo': 18871.0,
#   'fecha': '2015-09-19',
#   'email': 'nombre_3166.apellido_3166@python.com'},
#  193: {'id': 6005,
#   'nombre': 'nombre_6005',
#   'apellido': 'apellido_6005',
#   'departamento': 4,
#   'sueldo': 19026.0,
#   'fecha': '2007-12-11',
#   'email': 'nombre_6005.apellido_6005@python.com'},
#  194: {'id': 4279,
#   'nombre': 'nombre_4279',
#   'apellido': 'apellido_4279',
#   'departamento': 4,
#   'sueldo': 10629.0,
#   'fecha': '2012-09-01',
#   'email': 'nombre_4279.apellido_4279@python.com'},
#  195: {'id': 609,
#   'nombre': 'nombre_609',
#   'apellido': 'apellido_609',
#   'departamento': 7,
#   'sueldo': 18082.0,
#   'fecha': '2022-09-19',
#   'email': 'nombre_609.apellido_609@python.com'},
#  196: {'id': 250,
#   'nombre': 'nombre_250',
#   'apellido': 'apellido_250',
#   'departamento': 2,
#   'sueldo': 12680.0,
#   'fecha': '2023-09-13',
#   'email': 'nombre_250.apellido_250@python.com'},
#  197: {'id': 4423,
#   'nombre': 'nombre_4423',
#   'apellido': 'apellido_4423',
#   'departamento': 7,
#   'sueldo': 14576.0,
#   'fecha': '2012-04-10',
#   'email': 'nombre_4423.apellido_4423@python.com'},
#  198: {'id': 6265,
#   'nombre': 'nombre_6265',
#   'apellido': 'apellido_6265',
#   'departamento': 10,
#   'sueldo': 15151.0,
#   'fecha': '2007-03-26',
#   'email': 'nombre_6265.apellido_6265@python.com'},
#  199: {'id': 9814,
#   'nombre': 'nombre_9814',
#   'apellido': 'apellido_9814',
#   'departamento': 5,
#   'sueldo': 12519.0,
#   'fecha': '1997-07-07',
#   'email': 'nombre_9814.apellido_9814@python.com'},
#  200: {'id': 6915,
#   'nombre': 'nombre_6915',
#   'apellido': 'apellido_6915',
#   'departamento': 4,
#   'sueldo': 18735.0,
#   'fecha': '2005-06-14',
#   'email': 'nombre_6915.apellido_6915@python.com'},
#  201: {'id': 4854,
#   'nombre': 'nombre_4854',
#   'apellido': 'apellido_4854',
#   'departamento': 10,
#   'sueldo': 16556.0,
#   'fecha': '2011-02-04',
#   'email': 'nombre_4854.apellido_4854@python.com'},
#  202: {'id': 1547,
#   'nombre': 'nombre_1547',
#   'apellido': 'apellido_1547',
#   'departamento': 1,
#   'sueldo': 18918.0,
#   'fecha': '2020-02-24',
#   'email': 'nombre_1547.apellido_1547@python.com'},
#  203: {'id': 3599,
#   'nombre': 'nombre_3599',
#   'apellido': 'apellido_3599',
#   'departamento': 3,
#   'sueldo': 18207.0,
#   'fecha': '2014-07-13',
#   'email': 'nombre_3599.apellido_3599@python.com'},
#  204: {'id': 7840,
#   'nombre': 'nombre_7840',
#   'apellido': 'apellido_7840',
#   'departamento': 1,
#   'sueldo': 12108.0,
#   'fecha': '2002-12-02',
#   'email': 'nombre_7840.apellido_7840@python.com'},
#  205: {'id': 1537,
#   'nombre': 'nombre_1537',
#   'apellido': 'apellido_1537',
#   'departamento': 6,
#   'sueldo': 16575.0,
#   'fecha': '2020-03-05',
#   'email': 'nombre_1537.apellido_1537@python.com'},
#  206: {'id': 8081,
#   'nombre': 'nombre_8081',
#   'apellido': 'apellido_8081',
#   'departamento': 2,
#   'sueldo': 16382.0,
#   'fecha': '2002-04-05',
#   'email': 'nombre_8081.apellido_8081@python.com'},
#  207: {'id': 1252,
#   'nombre': 'nombre_1252',
#   'apellido': 'apellido_1252',
#   'departamento': 7,
#   'sueldo': 11039.0,
#   'fecha': '2020-12-15',
#   'email': 'nombre_1252.apellido_1252@python.com'},
#  208: {'id': 2736,
#   'nombre': 'nombre_2736',
#   'apellido': 'apellido_2736',
#   'departamento': 3,
#   'sueldo': 19012.0,
#   'fecha': '2016-11-22',
#   'email': 'nombre_2736.apellido_2736@python.com'},
#  209: {'id': 8852,
#   'nombre': 'nombre_8852',
#   'apellido': 'apellido_8852',
#   'departamento': 10,
#   'sueldo': 11121.0,
#   'fecha': '2000-02-24',
#   'email': 'nombre_8852.apellido_8852@python.com'},
#  210: {'id': 8188,
#   'nombre': 'nombre_8188',
#   'apellido': 'apellido_8188',
#   'departamento': 5,
#   'sueldo': 17031.0,
#   'fecha': '2001-12-19',
#   'email': 'nombre_8188.apellido_8188@python.com'},
#  211: {'id': 3891,
#   'nombre': 'nombre_3891',
#   'apellido': 'apellido_3891',
#   'departamento': 10,
#   'sueldo': 10499.0,
#   'fecha': '2013-09-24',
#   'email': 'nombre_3891.apellido_3891@python.com'},
#  212: {'id': 4506,
#   'nombre': 'nombre_4506',
#   'apellido': 'apellido_4506',
#   'departamento': 5,
#   'sueldo': 17160.0,
#   'fecha': '2012-01-18',
#   'email': 'nombre_4506.apellido_4506@python.com'},
#  213: {'id': 9854,
#   'nombre': 'nombre_9854',
#   'apellido': 'apellido_9854',
#   'departamento': 1,
#   'sueldo': 13569.0,
#   'fecha': '1997-05-28',
#   'email': 'nombre_9854.apellido_9854@python.com'},
#  214: {'id': 8708,
#   'nombre': 'nombre_8708',
#   'apellido': 'apellido_8708',
#   'departamento': 9,
#   'sueldo': 14813.0,
#   'fecha': '2000-07-17',
#   'email': 'nombre_8708.apellido_8708@python.com'},
#  215: {'id': 4995,
#   'nombre': 'nombre_4995',
#   'apellido': 'apellido_4995',
#   'departamento': 9,
#   'sueldo': 13807.0,
#   'fecha': '2010-09-16',
#   'email': 'nombre_4995.apellido_4995@python.com'},
#  216: {'id': 5533,
#   'nombre': 'nombre_5533',
#   'apellido': 'apellido_5533',
#   'departamento': 6,
#   'sueldo': 14688.0,
#   'fecha': '2009-03-27',
#   'email': 'nombre_5533.apellido_5533@python.com'},
#  217: {'id': 9829,
#   'nombre': 'nombre_9829',
#   'apellido': 'apellido_9829',
#   'departamento': 2,
#   'sueldo': 12810.0,
#   'fecha': '1997-06-22',
#   'email': 'nombre_9829.apellido_9829@python.com'},
#  218: {'id': 1174,
#   'nombre': 'nombre_1174',
#   'apellido': 'apellido_1174',
#   'departamento': 9,
#   'sueldo': 13416.0,
#   'fecha': '2021-03-03',
#   'email': 'nombre_1174.apellido_1174@python.com'},
#  219: {'id': 2448,
#   'nombre': 'nombre_2448',
#   'apellido': 'apellido_2448',
#   'departamento': 2,
#   'sueldo': 13758.0,
#   'fecha': '2017-09-06',
#   'email': 'nombre_2448.apellido_2448@python.com'},
#  220: {'id': 3481,
#   'nombre': 'nombre_3481',
#   'apellido': 'apellido_3481',
#   'departamento': 5,
#   'sueldo': 17799.0,
#   'fecha': '2014-11-08',
#   'email': 'nombre_3481.apellido_3481@python.com'},
#  221: {'id': 5378,
#   'nombre': 'nombre_5378',
#   'apellido': 'apellido_5378',
#   'departamento': 6,
#   'sueldo': 12201.0,
#   'fecha': '2009-08-29',
#   'email': 'nombre_5378.apellido_5378@python.com'},
#  222: {'id': 9588,
#   'nombre': 'nombre_9588',
#   'apellido': 'apellido_9588',
#   'departamento': 6,
#   'sueldo': 13039.0,
#   'fecha': '1998-02-18',
#   'email': 'nombre_9588.apellido_9588@python.com'},
#  223: {'id': 6857,
#   'nombre': 'nombre_6857',
#   'apellido': 'apellido_6857',
#   'departamento': 9,
#   'sueldo': 19482.0,
#   'fecha': '2005-08-11',
#   'email': 'nombre_6857.apellido_6857@python.com'},
#  224: {'id': 9925,
#   'nombre': 'nombre_9925',
#   'apellido': 'apellido_9925',
#   'departamento': 8,
#   'sueldo': 14835.0,
#   'fecha': '1997-03-18',
#   'email': 'nombre_9925.apellido_9925@python.com'},
#  225: {'id': 4053,
#   'nombre': 'nombre_4053',
#   'apellido': 'apellido_4053',
#   'departamento': 6,
#   'sueldo': 18106.0,
#   'fecha': '2013-04-15',
#   'email': 'nombre_4053.apellido_4053@python.com'},
#  226: {'id': 1123,
#   'nombre': 'nombre_1123',
#   'apellido': 'apellido_1123',
#   'departamento': 3,
#   'sueldo': 17179.0,
#   'fecha': '2021-04-23',
#   'email': 'nombre_1123.apellido_1123@python.com'},
#  227: {'id': 6667,
#   'nombre': 'nombre_6667',
#   'apellido': 'apellido_6667',
#   'departamento': 5,
#   'sueldo': 13206.0,
#   'fecha': '2006-02-17',
#   'email': 'nombre_6667.apellido_6667@python.com'},
#  228: {'id': 4079,
#   'nombre': 'nombre_4079',
#   'apellido': 'apellido_4079',
#   'departamento': 2,
#   'sueldo': 18830.0,
#   'fecha': '2013-03-20',
#   'email': 'nombre_4079.apellido_4079@python.com'},
#  229: {'id': 9794,
#   'nombre': 'nombre_9794',
#   'apellido': 'apellido_9794',
#   'departamento': 5,
#   'sueldo': 17418.0,
#   'fecha': '1997-07-27',
#   'email': 'nombre_9794.apellido_9794@python.com'},
#  230: {'id': 6650,
#   'nombre': 'nombre_6650',
#   'apellido': 'apellido_6650',
#   'departamento': 10,
#   'sueldo': 19688.0,
#   'fecha': '2006-03-06',
#   'email': 'nombre_6650.apellido_6650@python.com'},
#  231: {'id': 3113,
#   'nombre': 'nombre_3113',
#   'apellido': 'apellido_3113',
#   'departamento': 8,
#   'sueldo': 16138.0,
#   'fecha': '2015-11-11',
#   'email': 'nombre_3113.apellido_3113@python.com'},
#  232: {'id': 7267,
#   'nombre': 'nombre_7267',
#   'apellido': 'apellido_7267',
#   'departamento': 9,
#   'sueldo': 12759.0,
#   'fecha': '2004-06-27',
#   'email': 'nombre_7267.apellido_7267@python.com'},
#  233: {'id': 9349,
#   'nombre': 'nombre_9349',
#   'apellido': 'apellido_9349',
#   'departamento': 7,
#   'sueldo': 19450.0,
#   'fecha': '1998-10-15',
#   'email': 'nombre_9349.apellido_9349@python.com'},
#  234: {'id': 5873,
#   'nombre': 'nombre_5873',
#   'apellido': 'apellido_5873',
#   'departamento': 9,
#   'sueldo': 13245.0,
#   'fecha': '2008-04-21',
#   'email': 'nombre_5873.apellido_5873@python.com'},
#  235: {'id': 9638,
#   'nombre': 'nombre_9638',
#   'apellido': 'apellido_9638',
#   'departamento': 7,
#   'sueldo': 13400.0,
#   'fecha': '1997-12-30',
#   'email': 'nombre_9638.apellido_9638@python.com'},
#  236: {'id': 1478,
#   'nombre': 'nombre_1478',
#   'apellido': 'apellido_1478',
#   'departamento': 4,
#   'sueldo': 16742.0,
#   'fecha': '2020-05-03',
#   'email': 'nombre_1478.apellido_1478@python.com'},
#  237: {'id': 3400,
#   'nombre': 'nombre_3400',
#   'apellido': 'apellido_3400',
#   'departamento': 10,
#   'sueldo': 15640.0,
#   'fecha': '2015-01-28',
#   'email': 'nombre_3400.apellido_3400@python.com'},
#  238: {'id': 1411,
#   'nombre': 'nombre_1411',
#   'apellido': 'apellido_1411',
#   'departamento': 9,
#   'sueldo': 19607.0,
#   'fecha': '2020-07-09',
#   'email': 'nombre_1411.apellido_1411@python.com'},
#  239: {'id': 8951,
#   'nombre': 'nombre_8951',
#   'apellido': 'apellido_8951',
#   'departamento': 8,
#   'sueldo': 18600.0,
#   'fecha': '1999-11-17',
#   'email': 'nombre_8951.apellido_8951@python.com'},
#  240: {'id': 1796,
#   'nombre': 'nombre_1796',
#   'apellido': 'apellido_1796',
#   'departamento': 6,
#   'sueldo': 15460.0,
#   'fecha': '2019-06-20',
#   'email': 'nombre_1796.apellido_1796@python.com'},
#  241: {'id': 3534,
#   'nombre': 'nombre_3534',
#   'apellido': 'apellido_3534',
#   'departamento': 7,
#   'sueldo': 17490.0,
#   'fecha': '2014-09-16',
#   'email': 'nombre_3534.apellido_3534@python.com'},
#  242: {'id': 7995,
#   'nombre': 'nombre_7995',
#   'apellido': 'apellido_7995',
#   'departamento': 1,
#   'sueldo': 11119.0,
#   'fecha': '2002-06-30',
#   'email': 'nombre_7995.apellido_7995@python.com'},
#  243: {'id': 4443,
#   'nombre': 'nombre_4443',
#   'apellido': 'apellido_4443',
#   'departamento': 2,
#   'sueldo': 12583.0,
#   'fecha': '2012-03-21',
#   'email': 'nombre_4443.apellido_4443@python.com'},
#  244: {'id': 6960,
#   'nombre': 'nombre_6960',
#   'apellido': 'apellido_6960',
#   'departamento': 4,
#   'sueldo': 17236.0,
#   'fecha': '2005-04-30',
#   'email': 'nombre_6960.apellido_6960@python.com'},
#  245: {'id': 6345,
#   'nombre': 'nombre_6345',
#   'apellido': 'apellido_6345',
#   'departamento': 3,
#   'sueldo': 12156.0,
#   'fecha': '2007-01-05',
# ...
#   'apellido': 'apellido_5742',
#   'departamento': 2,
#   'sueldo': 18466.0,
#   'fecha': '2008-08-30',
#   'email': 'nombre_5742.apellido_5742@python.com'},
#  419: {'id': 2184,
#   'nombre': 'nombre_2184',
#   'apellido': 'apellido_2184',
#   'departamento': 1,
#   'sueldo': 11527.0,
#   'fecha': '2018-05-28',
#   'email': 'nombre_2184.apellido_2184@python.com'},
#  420: {'id': 7204,
#   'nombre': 'nombre_7204',
#   'apellido': 'apellido_7204',
#   'departamento': 5,
#   'sueldo': 13394.0,
#   'fecha': '2004-08-29',
#   'email': 'nombre_7204.apellido_7204@python.com'},
#  421: {'id': 3806,
#   'nombre': 'nombre_3806',
#   'apellido': 'apellido_3806',
#   'departamento': 8,
#   'sueldo': 19842.0,
#   'fecha': '2013-12-18',
#   'email': 'nombre_3806.apellido_3806@python.com'},
#  422: {'id': 2425,
#   'nombre': 'nombre_2425',
#   'apellido': 'apellido_2425',
#   'departamento': 5,
#   'sueldo': 12232.0,
#   'fecha': '2017-09-29',
#   'email': 'nombre_2425.apellido_2425@python.com'},
#  423: {'id': 3160,
#   'nombre': 'nombre_3160',
#   'apellido': 'apellido_3160',
#   'departamento': 6,
#   'sueldo': 11039.0,
#   'fecha': '2015-09-25',
#   'email': 'nombre_3160.apellido_3160@python.com'},
#  424: {'id': 2155,
#   'nombre': 'nombre_2155',
#   'apellido': 'apellido_2155',
#   'departamento': 6,
#   'sueldo': 15680.0,
#   'fecha': '2018-06-26',
#   'email': 'nombre_2155.apellido_2155@python.com'},
#  425: {'id': 4628,
#   'nombre': 'nombre_4628',
#   'apellido': 'apellido_4628',
#   'departamento': 7,
#   'sueldo': 16648.0,
#   'fecha': '2011-09-18',
#   'email': 'nombre_4628.apellido_4628@python.com'},
#  426: {'id': 5019,
#   'nombre': 'nombre_5019',
#   'apellido': 'apellido_5019',
#   'departamento': 7,
#   'sueldo': 11569.0,
#   'fecha': '2010-08-23',
#   'email': 'nombre_5019.apellido_5019@python.com'},
#  427: {'id': 7832,
#   'nombre': 'nombre_7832',
#   'apellido': 'apellido_7832',
#   'departamento': 4,
#   'sueldo': 13762.0,
#   'fecha': '2002-12-10',
#   'email': 'nombre_7832.apellido_7832@python.com'},
#  428: {'id': 1036,
#   'nombre': 'nombre_1036',
#   'apellido': 'apellido_1036',
#   'departamento': 9,
#   'sueldo': 19047.0,
#   'fecha': '2021-07-19',
#   'email': 'nombre_1036.apellido_1036@python.com'},
#  429: {'id': 419,
#   'nombre': 'nombre_419',
#   'apellido': 'apellido_419',
#   'departamento': 2,
#   'sueldo': 11998.0,
#   'fecha': '2023-03-28',
#   'email': 'nombre_419.apellido_419@python.com'},
#  430: {'id': 9744,
#   'nombre': 'nombre_9744',
#   'apellido': 'apellido_9744',
#   'departamento': 8,
#   'sueldo': 17134.0,
#   'fecha': '1997-09-15',
#   'email': 'nombre_9744.apellido_9744@python.com'},
#  431: {'id': 4948,
#   'nombre': 'nombre_4948',
#   'apellido': 'apellido_4948',
#   'departamento': 3,
#   'sueldo': 12968.0,
#   'fecha': '2010-11-02',
#   'email': 'nombre_4948.apellido_4948@python.com'},
#  432: {'id': 3169,
#   'nombre': 'nombre_3169',
#   'apellido': 'apellido_3169',
#   'departamento': 9,
#   'sueldo': 19858.0,
#   'fecha': '2015-09-16',
#   'email': 'nombre_3169.apellido_3169@python.com'},
#  433: {'id': 7422,
#   'nombre': 'nombre_7422',
#   'apellido': 'apellido_7422',
#   'departamento': 3,
#   'sueldo': 15035.0,
#   'fecha': '2004-01-24',
#   'email': 'nombre_7422.apellido_7422@python.com'},
#  434: {'id': 2552,
#   'nombre': 'nombre_2552',
#   'apellido': 'apellido_2552',
#   'departamento': 3,
#   'sueldo': 10568.0,
#   'fecha': '2017-05-25',
#   'email': 'nombre_2552.apellido_2552@python.com'},
#  435: {'id': 4645,
#   'nombre': 'nombre_4645',
#   'apellido': 'apellido_4645',
#   'departamento': 5,
#   'sueldo': 15701.0,
#   'fecha': '2011-09-01',
#   'email': 'nombre_4645.apellido_4645@python.com'},
#  436: {'id': 951,
#   'nombre': 'nombre_951',
#   'apellido': 'apellido_951',
#   'departamento': 9,
#   'sueldo': 14952.0,
#   'fecha': '2021-10-12',
#   'email': 'nombre_951.apellido_951@python.com'},
#  437: {'id': 6276,
#   'nombre': 'nombre_6276',
#   'apellido': 'apellido_6276',
#   'departamento': 7,
#   'sueldo': 11296.0,
#   'fecha': '2007-03-15',
#   'email': 'nombre_6276.apellido_6276@python.com'},
#  438: {'id': 9095,
#   'nombre': 'nombre_9095',
#   'apellido': 'apellido_9095',
#   'departamento': 3,
#   'sueldo': 15372.0,
#   'fecha': '1999-06-26',
#   'email': 'nombre_9095.apellido_9095@python.com'},
#  439: {'id': 5622,
#   'nombre': 'nombre_5622',
#   'apellido': 'apellido_5622',
#   'departamento': 4,
#   'sueldo': 11142.0,
#   'fecha': '2008-12-28',
#   'email': 'nombre_5622.apellido_5622@python.com'},
#  440: {'id': 6065,
#   'nombre': 'nombre_6065',
#   'apellido': 'apellido_6065',
#   'departamento': 1,
#   'sueldo': 17947.0,
#   'fecha': '2007-10-12',
#   'email': 'nombre_6065.apellido_6065@python.com'},
#  441: {'id': 6929,
#   'nombre': 'nombre_6929',
#   'apellido': 'apellido_6929',
#   'departamento': 5,
#   'sueldo': 12839.0,
#   'fecha': '2005-05-31',
#   'email': 'nombre_6929.apellido_6929@python.com'},
#  442: {'id': 7915,
#   'nombre': 'nombre_7915',
#   'apellido': 'apellido_7915',
#   'departamento': 7,
#   'sueldo': 12433.0,
#   'fecha': '2002-09-18',
#   'email': 'nombre_7915.apellido_7915@python.com'},
#  443: {'id': 4510,
#   'nombre': 'nombre_4510',
#   'apellido': 'apellido_4510',
#   'departamento': 8,
#   'sueldo': 13884.0,
#   'fecha': '2012-01-14',
#   'email': 'nombre_4510.apellido_4510@python.com'},
#  444: {'id': 1554,
#   'nombre': 'nombre_1554',
#   'apellido': 'apellido_1554',
#   'departamento': 4,
#   'sueldo': 16535.0,
#   'fecha': '2020-02-17',
#   'email': 'nombre_1554.apellido_1554@python.com'},
#  445: {'id': 2461,
#   'nombre': 'nombre_2461',
#   'apellido': 'apellido_2461',
#   'departamento': 2,
#   'sueldo': 13133.0,
#   'fecha': '2017-08-24',
#   'email': 'nombre_2461.apellido_2461@python.com'},
#  446: {'id': 9721,
#   'nombre': 'nombre_9721',
#   'apellido': 'apellido_9721',
#   'departamento': 2,
#   'sueldo': 18889.0,
#   'fecha': '1997-10-08',
#   'email': 'nombre_9721.apellido_9721@python.com'},
#  447: {'id': 9240,
#   'nombre': 'nombre_9240',
#   'apellido': 'apellido_9240',
#   'departamento': 2,
#   'sueldo': 11005.0,
#   'fecha': '1999-02-01',
#   'email': 'nombre_9240.apellido_9240@python.com'},
#  448: {'id': 5924,
#   'nombre': 'nombre_5924',
#   'apellido': 'apellido_5924',
#   'departamento': 6,
#   'sueldo': 15010.0,
#   'fecha': '2008-03-01',
#   'email': 'nombre_5924.apellido_5924@python.com'},
#  449: {'id': 7825,
#   'nombre': 'nombre_7825',
#   'apellido': 'apellido_7825',
#   'departamento': 4,
#   'sueldo': 11917.0,
#   'fecha': '2002-12-17',
#   'email': 'nombre_7825.apellido_7825@python.com'},
#  450: {'id': 7310,
#   'nombre': 'nombre_7310',
#   'apellido': 'apellido_7310',
#   'departamento': 3,
#   'sueldo': 12244.0,
#   'fecha': '2004-05-15',
#   'email': 'nombre_7310.apellido_7310@python.com'},
#  451: {'id': 2823,
#   'nombre': 'nombre_2823',
#   'apellido': 'apellido_2823',
#   'departamento': 6,
#   'sueldo': 18660.0,
#   'fecha': '2016-08-27',
#   'email': 'nombre_2823.apellido_2823@python.com'},
#  452: {'id': 7884,
#   'nombre': 'nombre_7884',
#   'apellido': 'apellido_7884',
#   'departamento': 2,
#   'sueldo': 16298.0,
#   'fecha': '2002-10-19',
#   'email': 'nombre_7884.apellido_7884@python.com'},
#  453: {'id': 4904,
#   'nombre': 'nombre_4904',
#   'apellido': 'apellido_4904',
#   'departamento': 10,
#   'sueldo': 13197.0,
#   'fecha': '2010-12-16',
#   'email': 'nombre_4904.apellido_4904@python.com'},
#  454: {'id': 8118,
#   'nombre': 'nombre_8118',
#   'apellido': 'apellido_8118',
#   'departamento': 5,
#   'sueldo': 13906.0,
#   'fecha': '2002-02-27',
#   'email': 'nombre_8118.apellido_8118@python.com'},
#  455: {'id': 1484,
#   'nombre': 'nombre_1484',
#   'apellido': 'apellido_1484',
#   'departamento': 5,
#   'sueldo': 13034.0,
#   'fecha': '2020-04-27',
#   'email': 'nombre_1484.apellido_1484@python.com'},
#  456: {'id': 7662,
#   'nombre': 'nombre_7662',
#   'apellido': 'apellido_7662',
#   'departamento': 2,
#   'sueldo': 12805.0,
#   'fecha': '2003-05-29',
#   'email': 'nombre_7662.apellido_7662@python.com'},
#  457: {'id': 3153,
#   'nombre': 'nombre_3153',
#   'apellido': 'apellido_3153',
#   'departamento': 4,
#   'sueldo': 12720.0,
#   'fecha': '2015-10-02',
#   'email': 'nombre_3153.apellido_3153@python.com'},
#  458: {'id': 897,
#   'nombre': 'nombre_897',
#   'apellido': 'apellido_897',
#   'departamento': 8,
#   'sueldo': 18205.0,
#   'fecha': '2021-12-05',
#   'email': 'nombre_897.apellido_897@python.com'},
#  459: {'id': 9425,
#   'nombre': 'nombre_9425',
#   'apellido': 'apellido_9425',
#   'departamento': 6,
#   'sueldo': 10153.0,
#   'fecha': '1998-07-31',
#   'email': 'nombre_9425.apellido_9425@python.com'},
#  460: {'id': 1454,
#   'nombre': 'nombre_1454',
#   'apellido': 'apellido_1454',
#   'departamento': 5,
#   'sueldo': 13045.0,
#   'fecha': '2020-05-27',
#   'email': 'nombre_1454.apellido_1454@python.com'},
#  461: {'id': 9291,
#   'nombre': 'nombre_9291',
#   'apellido': 'apellido_9291',
#   'departamento': 9,
#   'sueldo': 19970.0,
#   'fecha': '1998-12-12',
#   'email': 'nombre_9291.apellido_9291@python.com'},
#  462: {'id': 590,
#   'nombre': 'nombre_590',
#   'apellido': 'apellido_590',
#   'departamento': 8,
#   'sueldo': 15785.0,
#   'fecha': '2022-10-08',
#   'email': 'nombre_590.apellido_590@python.com'},
#  463: {'id': 5240,
#   'nombre': 'nombre_5240',
#   'apellido': 'apellido_5240',
#   'departamento': 1,
#   'sueldo': 14253.0,
#   'fecha': '2010-01-14',
#   'email': 'nombre_5240.apellido_5240@python.com'},
#  464: {'id': 5356,
#   'nombre': 'nombre_5356',
#   'apellido': 'apellido_5356',
#   'departamento': 1,
#   'sueldo': 16441.0,
#   'fecha': '2009-09-20',
#   'email': 'nombre_5356.apellido_5356@python.com'},
#  465: {'id': 3358,
#   'nombre': 'nombre_3358',
#   'apellido': 'apellido_3358',
#   'departamento': 4,
#   'sueldo': 18730.0,
#   'fecha': '2015-03-11',
#   'email': 'nombre_3358.apellido_3358@python.com'},
#  466: {'id': 8099,
#   'nombre': 'nombre_8099',
#   'apellido': 'apellido_8099',
#   'departamento': 3,
#   'sueldo': 17501.0,
#   'fecha': '2002-03-18',
#   'email': 'nombre_8099.apellido_8099@python.com'},
#  467: {'id': 3637,
#   'nombre': 'nombre_3637',
#   'apellido': 'apellido_3637',
#   'departamento': 4,
#   'sueldo': 14138.0,
#   'fecha': '2014-06-05',
#   'email': 'nombre_3637.apellido_3637@python.com'},
#  468: {'id': 4947,
#   'nombre': 'nombre_4947',
#   'apellido': 'apellido_4947',
#   'departamento': 2,
#   'sueldo': 10319.0,
#   'fecha': '2010-11-03',
#   'email': 'nombre_4947.apellido_4947@python.com'},
#  469: {'id': 8552,
#   'nombre': 'nombre_8552',
#   'apellido': 'apellido_8552',
#   'departamento': 3,
#   'sueldo': 19878.0,
#   'fecha': '2000-12-20',
#   'email': 'nombre_8552.apellido_8552@python.com'},
#  470: {'id': 3482,
#   'nombre': 'nombre_3482',
#   'apellido': 'apellido_3482',
#   'departamento': 10,
#   'sueldo': 13309.0,
#   'fecha': '2014-11-07',
#   'email': 'nombre_3482.apellido_3482@python.com'},
#  471: {'id': 7954,
#   'nombre': 'nombre_7954',
#   'apellido': 'apellido_7954',
#   'departamento': 10,
#   'sueldo': 11362.0,
#   'fecha': '2002-08-10',
#   'email': 'nombre_7954.apellido_7954@python.com'},
#  472: {'id': 1131,
#   'nombre': 'nombre_1131',
#   'apellido': 'apellido_1131',
#   'departamento': 8,
#   'sueldo': 17264.0,
#   'fecha': '2021-04-15',
#   'email': 'nombre_1131.apellido_1131@python.com'},
#  473: {'id': 206,
#   'nombre': 'nombre_206',
#   'apellido': 'apellido_206',
#   'departamento': 2,
#   'sueldo': 14829.0,
#   'fecha': '2023-10-27',
#   'email': 'nombre_206.apellido_206@python.com'},
#  474: {'id': 8323,
#   'nombre': 'nombre_8323',
#   'apellido': 'apellido_8323',
#   'departamento': 10,
#   'sueldo': 19395.0,
#   'fecha': '2001-08-06',
#   'email': 'nombre_8323.apellido_8323@python.com'},
#  475: {'id': 7445,
#   'nombre': 'nombre_7445',
#   'apellido': 'apellido_7445',
#   'departamento': 7,
#   'sueldo': 14664.0,
#   'fecha': '2004-01-01',
#   'email': 'nombre_7445.apellido_7445@python.com'},
#  476: {'id': 2042,
#   'nombre': 'nombre_2042',
#   'apellido': 'apellido_2042',
#   'departamento': 8,
#   'sueldo': 10419.0,
#   'fecha': '2018-10-17',
#   'email': 'nombre_2042.apellido_2042@python.com'},
#  477: {'id': 6034,
#   'nombre': 'nombre_6034',
#   'apellido': 'apellido_6034',
#   'departamento': 6,
#   'sueldo': 17398.0,
#   'fecha': '2007-11-12',
#   'email': 'nombre_6034.apellido_6034@python.com'},
#  478: {'id': 126,
#   'nombre': 'nombre_126',
#   'apellido': 'apellido_126',
#   'departamento': 5,
#   'sueldo': 19610.0,
#   'fecha': '2024-01-15',
#   'email': 'nombre_126.apellido_126@python.com'},
#  479: {'id': 7848,
#   'nombre': 'nombre_7848',
#   'apellido': 'apellido_7848',
#   'departamento': 6,
#   'sueldo': 10530.0,
#   'fecha': '2002-11-24',
#   'email': 'nombre_7848.apellido_7848@python.com'},
#  480: {'id': 5831,
#   'nombre': 'nombre_5831',
#   'apellido': 'apellido_5831',
#   'departamento': 6,
#   'sueldo': 11339.0,
#   'fecha': '2008-06-02',
#   'email': 'nombre_5831.apellido_5831@python.com'},
#  481: {'id': 5694,
#   'nombre': 'nombre_5694',
#   'apellido': 'apellido_5694',
#   'departamento': 3,
#   'sueldo': 16299.0,
#   'fecha': '2008-10-17',
#   'email': 'nombre_5694.apellido_5694@python.com'},
#  482: {'id': 2708,
#   'nombre': 'nombre_2708',
#   'apellido': 'apellido_2708',
#   'departamento': 7,
#   'sueldo': 10724.0,
#   'fecha': '2016-12-20',
#   'email': 'nombre_2708.apellido_2708@python.com'},
#  483: {'id': 6230,
#   'nombre': 'nombre_6230',
#   'apellido': 'apellido_6230',
#   'departamento': 9,
#   'sueldo': 18752.0,
#   'fecha': '2007-04-30',
#   'email': 'nombre_6230.apellido_6230@python.com'},
#  484: {'id': 1136,
#   'nombre': 'nombre_1136',
#   'apellido': 'apellido_1136',
#   'departamento': 4,
#   'sueldo': 15554.0,
#   'fecha': '2021-04-10',
#   'email': 'nombre_1136.apellido_1136@python.com'},
#  485: {'id': 4594,
#   'nombre': 'nombre_4594',
#   'apellido': 'apellido_4594',
#   'departamento': 6,
#   'sueldo': 12421.0,
#   'fecha': '2011-10-22',
#   'email': 'nombre_4594.apellido_4594@python.com'},
#  486: {'id': 7551,
#   'nombre': 'nombre_7551',
#   'apellido': 'apellido_7551',
#   'departamento': 3,
#   'sueldo': 16163.0,
#   'fecha': '2003-09-17',
#   'email': 'nombre_7551.apellido_7551@python.com'},
#  487: {'id': 7942,
#   'nombre': 'nombre_7942',
#   'apellido': 'apellido_7942',
#   'departamento': 6,
#   'sueldo': 14973.0,
#   'fecha': '2002-08-22',
#   'email': 'nombre_7942.apellido_7942@python.com'},
#  488: {'id': 4770,
#   'nombre': 'nombre_4770',
#   'apellido': 'apellido_4770',
#   'departamento': 3,
#   'sueldo': 12443.0,
#   'fecha': '2011-04-29',
#   'email': 'nombre_4770.apellido_4770@python.com'},
#  489: {'id': 6717,
#   'nombre': 'nombre_6717',
#   'apellido': 'apellido_6717',
#   'departamento': 10,
#   'sueldo': 18979.0,
#   'fecha': '2005-12-29',
#   'email': 'nombre_6717.apellido_6717@python.com'},
#  490: {'id': 8339,
#   'nombre': 'nombre_8339',
#   'apellido': 'apellido_8339',
#   'departamento': 1,
#   'sueldo': 19140.0,
#   'fecha': '2001-07-21',
#   'email': 'nombre_8339.apellido_8339@python.com'},
#  491: {'id': 9566,
#   'nombre': 'nombre_9566',
#   'apellido': 'apellido_9566',
#   'departamento': 5,
#   'sueldo': 17240.0,
#   'fecha': '1998-03-12',
#   'email': 'nombre_9566.apellido_9566@python.com'},
#  492: {'id': 4233,
#   'nombre': 'nombre_4233',
#   'apellido': 'apellido_4233',
#   'departamento': 4,
#   'sueldo': 13245.0,
#   'fecha': '2012-10-17',
#   'email': 'nombre_4233.apellido_4233@python.com'},
#  493: {'id': 3735,
#   'nombre': 'nombre_3735',
#   'apellido': 'apellido_3735',
#   'departamento': 10,
#   'sueldo': 19986.0,
#   'fecha': '2014-02-27',
#   'email': 'nombre_3735.apellido_3735@python.com'},
#  494: {'id': 7097,
#   'nombre': 'nombre_7097',
#   'apellido': 'apellido_7097',
#   'departamento': 9,
#   'sueldo': 19626.0,
#   'fecha': '2004-12-14',
#   'email': 'nombre_7097.apellido_7097@python.com'},
#  495: {'id': 996,
#   'nombre': 'nombre_996',
#   'apellido': 'apellido_996',
#   'departamento': 4,
#   'sueldo': 18997.0,
#   'fecha': '2021-08-28',
#   'email': 'nombre_996.apellido_996@python.com'},
#  496: {'id': 7485,
#   'nombre': 'nombre_7485',
#   'apellido': 'apellido_7485',
#   'departamento': 3,
#   'sueldo': 10201.0,
#   'fecha': '2003-11-22',
#   'email': 'nombre_7485.apellido_7485@python.com'},
#  497: {'id': 6188,
#   'nombre': 'nombre_6188',
#   'apellido': 'apellido_6188',
#   'departamento': 3,
#   'sueldo': 11632.0,
#   'fecha': '2007-06-11',
#   'email': 'nombre_6188.apellido_6188@python.com'},
#  498: {'id': 5634,
#   'nombre': 'nombre_5634',
#   'apellido': 'apellido_5634',
#   'departamento': 1,
#   'sueldo': 11698.0,
#   'fecha': '2008-12-16',
#   'email': 'nombre_5634.apellido_5634@python.com'},
#  499: {'id': 4716,
#   'nombre': 'nombre_4716',
#   'apellido': 'apellido_4716',
#   'departamento': 10,
#   'sueldo': 14708.0,
#   'fecha': '2011-06-22',
#   'email': 'nombre_4716.apellido_4716@python.com'}}

# %% [markdown]
# Ahora pasaremos a definir la función **get_empleado(id_, empleados)**, que buscará en el diccionario *empleados_db* un empleado cuyo "id" sea igual al parámetro de entrada **id_** y mostrará por pantalla toda la información disponible de ese empleado:

# %%
def get_empleado(id_, empleados_db):
    for i in empleados_db:
        if empleados_db[i]["id"] == id_:
            return empleados_db[i]

# %% [markdown]
# Comprobamos que la función funcione correctamente buscando, por ejemplo, el id del empleado asignado a la llave "1", cuyo id es 7536:

# %%
get_empleado(7536, empleados_db)
# Out:
# {'id': 7536,
#  'nombre': 'nombre_7536',
#  'apellido': 'apellido_7536',
#  'departamento': 9,
#  'sueldo': 18283.0,
#  'fecha': '2003-10-02',
#  'email': 'nombre_7536.apellido_7536@python.com'}

# %% [markdown]
# Una vez verificado el paso anterior, pasamos a la siguiente función. Esta vez definiremos la función **get_top_empleados(sueldo, empleados_db)**, que retornará una lista con los "id"s de los empleados cuyo "sueldo" sea mayor o igual al parámetro _**sueldo**_:

# %%
def get_top_empleados(sueldo, empleados_db):
    lista_id = []
    for i in empleados_db:
        if empleados_db[i]["sueldo"] >= sueldo:
            lista_id.append(empleados_db[i]["id"])
    return lista_id

# %% [markdown]
# Y, de nuevo, comprobamos que funcione correctamente:

# %%
get_top_empleados(10000, empleados_db)
# Out:
# [4616,
#  7536,
#  9867,
#  2703,
#  1389,
#  9019,
#  7431,
#  93,
#  3967,
#  9571,
#  582,
#  209,
#  2081,
#  848,
#  936,
#  1945,
#  4993,
#  5600,
#  4706,
#  880,
#  9568,
#  9760,
#  7814,
#  1841,
#  8026,
#  7323,
#  7963,
#  7203,
#  2911,
#  190,
#  3922,
#  3042,
#  3166,
#  2256,
#  8457,
#  7408,
#  2406,
#  7796,
#  8825,
#  8783,
#  5749,
#  5208,
#  9958,
#  607,
#  420,
#  3304,
#  4013,
#  8384,
#  7919,
#  666,
#  5483,
#  5272,
#  6661,
#  6290,
#  6229,
#  8900,
#  2481,
#  3825,
#  2121,
#  5655,
#  1056,
#  2698,
#  7283,
#  1927,
#  861,
#  3033,
#  4609,
#  7843,
#  5345,
#  8480,
#  9999,
#  8950,
#  8791,
#  9834,
#  2966,
#  4439,
#  2904,
#  8253,
#  5850,
#  8689,
#  3158,
#  2700,
#  3891,
#  1202,
#  3314,
#  7045,
#  6549,
#  43,
#  1308,
#  9357,
#  2239,
#  3917,
#  5545,
#  5609,
#  9518,
#  4638,
#  1301,
#  1864,
#  526,
#  646,
#  2274,
#  3285,
#  105,
#  7392,
#  8984,
#  3944,
#  7327,
#  1053,
#  9409,
#  7670,
#  1043,
#  880,
#  3859,
#  6948,
#  7785,
#  8141,
#  7560,
#  1796,
#  256,
#  635,
#  3916,
#  7375,
#  8708,
#  3726,
#  5842,
#  1915,
#  1049,
#  4145,
#  8058,
#  1479,
#  8638,
#  3754,
#  7157,
#  9398,
#  5335,
#  3559,
#  2656,
#  1781,
#  9763,
#  9233,
#  6854,
#  3610,
#  321,
#  6892,
#  3543,
#  4242,
#  3672,
#  4115,
#  894,
#  8505,
#  3890,
#  5267,
#  6618,
#  3522,
#  3736,
#  1312,
#  9894,
#  193,
#  4690,
#  5262,
#  6075,
#  9385,
#  9324,
#  6126,
#  8828,
#  6325,
#  9354,
#  9853,
#  5250,
#  5648,
#  3686,
#  2930,
#  8022,
#  5688,
#  3679,
#  6836,
#  7196,
#  4640,
#  9495,
#  4736,
#  5454,
#  9280,
#  8036,
#  7651,
#  5954,
#  921,
#  3942,
#  452,
#  5413,
#  2920,
#  1270,
#  2174,
#  3166,
#  6005,
#  4279,
#  609,
#  250,
#  4423,
#  6265,
#  9814,
#  6915,
#  4854,
#  1547,
#  3599,
#  7840,
#  1537,
#  8081,
#  1252,
#  2736,
#  8852,
#  8188,
#  3891,
#  4506,
#  9854,
#  8708,
#  4995,
#  5533,
#  9829,
#  1174,
#  2448,
#  3481,
#  5378,
#  9588,
#  6857,
#  9925,
#  4053,
#  1123,
#  6667,
#  4079,
#  9794,
#  6650,
#  3113,
#  7267,
#  9349,
#  5873,
#  9638,
#  1478,
#  3400,
#  1411,
#  8951,
#  1796,
#  3534,
#  7995,
#  4443,
#  6960,
#  6345,
#  184,
#  7847,
#  9272,
#  2817,
#  958,
#  4963,
#  4969,
#  9209,
#  6194,
#  6626,
#  2110,
#  2996,
#  2115,
#  8937,
#  4626,
#  5560,
#  195,
#  2546,
#  4792,
#  2364,
#  8706,
#  9818,
#  4357,
#  4156,
#  9157,
#  6008,
#  4958,
#  7725,
#  3391,
#  3908,
#  8102,
#  7864,
#  3934,
#  9531,
#  5880,
#  3102,
#  1348,
#  3869,
#  4895,
#  9346,
#  5366,
#  5317,
#  4886,
#  6497,
#  3201,
#  70,
#  847,
#  4776,
#  4352,
#  7485,
#  9590,
#  7408,
#  5484,
#  4867,
#  1737,
#  7032,
#  1991,
#  9700,
#  747,
#  5204,
#  8390,
#  1935,
#  449,
#  9691,
#  9224,
#  3166,
#  6692,
#  4312,
#  1775,
#  7177,
#  6119,
#  1753,
#  3183,
#  5153,
#  5535,
#  5008,
#  3671,
#  8271,
#  3823,
#  6666,
#  4207,
#  7479,
#  2828,
#  4209,
#  6184,
#  7682,
#  6414,
#  8704,
#  9638,
#  7642,
#  1466,
#  1820,
#  8866,
#  3060,
#  7510,
#  8238,
#  5518,
#  9876,
#  1561,
#  1795,
#  3133,
#  7329,
#  4392,
#  5376,
#  5970,
#  8774,
#  976,
#  781,
#  4634,
#  5391,
#  9778,
#  8189,
#  5140,
#  7206,
#  7722,
#  7131,
#  2060,
#  4012,
#  4443,
#  7353,
#  2493,
#  7095,
#  8059,
#  9078,
#  595,
#  5087,
#  1199,
#  1540,
#  1737,
#  9970,
#  5604,
#  2307,
#  2113,
#  3222,
#  1977,
#  782,
#  9632,
#  2223,
#  204,
#  3818,
#  4568,
#  2901,
#  3866,
#  6025,
#  3478,
#  6152,
#  981,
#  192,
#  2513,
#  33,
#  185,
#  4885,
#  4812,
#  8111,
#  3431,
#  3877,
#  8691,
#  2665,
#  8075,
#  1286,
#  6841,
#  2540,
#  4458,
#  8610,
#  3574,
#  1744,
#  9433,
#  4267,
#  7390,
#  5451,
#  630,
#  9005,
#  5742,
#  2184,
#  7204,
#  3806,
#  2425,
#  3160,
#  2155,
#  4628,
#  5019,
#  7832,
#  1036,
#  419,
#  9744,
#  4948,
#  3169,
#  7422,
#  2552,
#  4645,
#  951,
#  6276,
#  9095,
#  5622,
#  6065,
#  6929,
#  7915,
#  4510,
#  1554,
#  2461,
#  9721,
#  9240,
#  5924,
#  7825,
#  7310,
#  2823,
#  7884,
#  4904,
#  8118,
#  1484,
#  7662,
#  3153,
#  897,
#  9425,
#  1454,
#  9291,
#  590,
#  5240,
#  5356,
#  3358,
#  8099,
#  3637,
#  4947,
#  8552,
#  3482,
#  7954,
#  1131,
#  206,
#  8323,
#  7445,
#  2042,
#  6034,
#  126,
#  7848,
#  5831,
#  5694,
#  2708,
#  6230,
#  1136,
#  4594,
#  7551,
#  7942,
#  4770,
#  6717,
#  8339,
#  9566,
#  4233,
#  3735,
#  7097,
#  996,
#  7485,
#  6188,
#  5634,
#  4716]

# %% [markdown]
# Por último, definiremos la función **put_empleado(empleados_db)**, que añadirá al diccionario *empleados_db* un empleado nuevo. Los datos del empleado nuevo serán generados aleatoriamente usando la librería *random* y su id no podrá ser uno ya existente. Esta función retornará un diccionario de empleados nuevo que sobrescribe el diccionario de empleados anterior.
#
# Como se trata de una función que necesita de varios pasos, iré generando cada dato aleatoriamente uno por uno, empezando por el id. Como se nos pide que el nuevo id generado aleatoriamente NO coincida con ningún otro, crearé la función *get_id_random()*, que crea un id aleatorio y verifica que sea distinto a todos y cada uno de los ids ya predefinidos en el diccionario *empleados_db*:

# %%
def get_id_random():
    diff = False
    while diff == False:
        num_random = random.randint(1, 9999)
        diff = True # diff será true asumiendo que es único
        for i in empleados_db:
            if num_random == empleados_db[i]["id"]:
                diff == False
        if diff == True:
            return num_random

# %% [markdown]
# De este modo, puedo guardar una variable *id_random* que almacene el id random generado por mi función:

# %%
id_random = get_id_random()
id_random
# Out:
# 6898

# %% [markdown]
# De igual forma, guardaré una variable *fecha* que me de una fecha aleatoria entre el 01.01.2000 y el 31.12.2000, tal y como nos lo pide el enunciado:

# %%
fecha = date(year = 2000, month = random.randint(1, 12), day = random.randint(1, 28))

fecha
# Out:
# datetime.date(2000, 8, 3)

# %% [markdown]
# Para poder asignarle el formato deseado a mi fecha aleatoria debemos utilizar el método **.strftime()**, que convierte mi variable en un string:

# %%
fecha_str = fecha.strftime("%Y-%m-%d")
fecha_str
# Out:
# '2000-08-03'

# %% [markdown]
# Ahora que ya tenemos todos los datos necesarios para generar un nuevo empleado aleatorio, es hora de guardarlos todos en una misms variable del tipo diccionario bajo el nombre de *datos_random*. De este modo, cuando generemos un nuevo empleado, se nos mostrará siempre todos sus datos también:

# %%
datos_random = {'id': id_random,
 'nombre': f'nombre_{id_random}',
 'apellido': f'apellido_{id_random}',
 'departamento': random.randint(1, 10),
 'sueldo': float(random.randint(10000, 20000)),
 'fecha': fecha_str,
 'email': f'nombre_{id_random}.apellido_{id_random}@python.com'}

datos_random
# Out:
# {'id': 6898,
#  'nombre': 'nombre_6898',
#  'apellido': 'apellido_6898',
#  'departamento': 1,
#  'sueldo': 16191.0,
#  'fecha': '2000-08-03',
#  'email': 'nombre_6898.apellido_6898@python.com'}

# %% [markdown]
# Finalmente, defino la función **put_empleado(empleados_db)**, que agrega un empleado aleatorio y sus datos a mi diccionario *empleados_db*:

# %%
def put_empleado(empleados_db):
    llave = len(empleados_db)
    empleados_db[llave] = datos_random
    return empleados_db

put_empleado(empleados_db)
# Out:
# {0: {'id': 4616,
#   'nombre': 'nombre_4616',
#   'apellido': 'apellido_4616',
#   'departamento': 6,
#   'sueldo': 12667.0,
#   'fecha': '2011-09-30',
#   'email': 'nombre_4616.apellido_4616@python.com'},
#  1: {'id': 7536,
#   'nombre': 'nombre_7536',
#   'apellido': 'apellido_7536',
#   'departamento': 9,
#   'sueldo': 18283.0,
#   'fecha': '2003-10-02',
#   'email': 'nombre_7536.apellido_7536@python.com'},
#  2: {'id': 9867,
#   'nombre': 'nombre_9867',
#   'apellido': 'apellido_9867',
#   'departamento': 4,
#   'sueldo': 15451.0,
#   'fecha': '1997-05-15',
#   'email': 'nombre_9867.apellido_9867@python.com'},
#  3: {'id': 2703,
#   'nombre': 'nombre_2703',
#   'apellido': 'apellido_2703',
#   'departamento': 5,
#   'sueldo': 15559.0,
#   'fecha': '2016-12-25',
#   'email': 'nombre_2703.apellido_2703@python.com'},
#  4: {'id': 1389,
#   'nombre': 'nombre_1389',
#   'apellido': 'apellido_1389',
#   'departamento': 8,
#   'sueldo': 12799.0,
#   'fecha': '2020-07-31',
#   'email': 'nombre_1389.apellido_1389@python.com'},
#  5: {'id': 9019,
#   'nombre': 'nombre_9019',
#   'apellido': 'apellido_9019',
#   'departamento': 2,
#   'sueldo': 18700.0,
#   'fecha': '1999-09-10',
#   'email': 'nombre_9019.apellido_9019@python.com'},
#  6: {'id': 7431,
#   'nombre': 'nombre_7431',
#   'apellido': 'apellido_7431',
#   'departamento': 4,
#   'sueldo': 19730.0,
#   'fecha': '2004-01-15',
#   'email': 'nombre_7431.apellido_7431@python.com'},
#  7: {'id': 93,
#   'nombre': 'nombre_93',
#   'apellido': 'apellido_93',
#   'departamento': 3,
#   'sueldo': 15903.0,
#   'fecha': '2024-02-17',
#   'email': 'nombre_93.apellido_93@python.com'},
#  8: {'id': 3967,
#   'nombre': 'nombre_3967',
#   'apellido': 'apellido_3967',
#   'departamento': 7,
#   'sueldo': 17404.0,
#   'fecha': '2013-07-10',
#   'email': 'nombre_3967.apellido_3967@python.com'},
#  9: {'id': 9571,
#   'nombre': 'nombre_9571',
#   'apellido': 'apellido_9571',
#   'departamento': 4,
#   'sueldo': 11341.0,
#   'fecha': '1998-03-07',
#   'email': 'nombre_9571.apellido_9571@python.com'},
#  10: {'id': 582,
#   'nombre': 'nombre_582',
#   'apellido': 'apellido_582',
#   'departamento': 5,
#   'sueldo': 19599.0,
#   'fecha': '2022-10-16',
#   'email': 'nombre_582.apellido_582@python.com'},
#  11: {'id': 209,
#   'nombre': 'nombre_209',
#   'apellido': 'apellido_209',
#   'departamento': 3,
#   'sueldo': 15130.0,
#   'fecha': '2023-10-24',
#   'email': 'nombre_209.apellido_209@python.com'},
#  12: {'id': 2081,
#   'nombre': 'nombre_2081',
#   'apellido': 'apellido_2081',
#   'departamento': 9,
#   'sueldo': 12481.0,
#   'fecha': '2018-09-08',
#   'email': 'nombre_2081.apellido_2081@python.com'},
#  13: {'id': 848,
#   'nombre': 'nombre_848',
#   'apellido': 'apellido_848',
#   'departamento': 10,
#   'sueldo': 16307.0,
#   'fecha': '2022-01-23',
#   'email': 'nombre_848.apellido_848@python.com'},
#  14: {'id': 936,
#   'nombre': 'nombre_936',
#   'apellido': 'apellido_936',
#   'departamento': 3,
#   'sueldo': 13179.0,
#   'fecha': '2021-10-27',
#   'email': 'nombre_936.apellido_936@python.com'},
#  15: {'id': 1945,
#   'nombre': 'nombre_1945',
#   'apellido': 'apellido_1945',
#   'departamento': 7,
#   'sueldo': 16731.0,
#   'fecha': '2019-01-22',
#   'email': 'nombre_1945.apellido_1945@python.com'},
#  16: {'id': 4993,
#   'nombre': 'nombre_4993',
#   'apellido': 'apellido_4993',
#   'departamento': 10,
#   'sueldo': 16275.0,
#   'fecha': '2010-09-18',
#   'email': 'nombre_4993.apellido_4993@python.com'},
#  17: {'id': 5600,
#   'nombre': 'nombre_5600',
#   'apellido': 'apellido_5600',
#   'departamento': 4,
#   'sueldo': 18921.0,
#   'fecha': '2009-01-19',
#   'email': 'nombre_5600.apellido_5600@python.com'},
#  18: {'id': 4706,
#   'nombre': 'nombre_4706',
#   'apellido': 'apellido_4706',
#   'departamento': 4,
#   'sueldo': 15945.0,
#   'fecha': '2011-07-02',
#   'email': 'nombre_4706.apellido_4706@python.com'},
#  19: {'id': 880,
#   'nombre': 'nombre_880',
#   'apellido': 'apellido_880',
#   'departamento': 10,
#   'sueldo': 17509.0,
#   'fecha': '2021-12-22',
#   'email': 'nombre_880.apellido_880@python.com'},
#  20: {'id': 9568,
#   'nombre': 'nombre_9568',
#   'apellido': 'apellido_9568',
#   'departamento': 10,
#   'sueldo': 16534.0,
#   'fecha': '1998-03-10',
#   'email': 'nombre_9568.apellido_9568@python.com'},
#  21: {'id': 9760,
#   'nombre': 'nombre_9760',
#   'apellido': 'apellido_9760',
#   'departamento': 2,
#   'sueldo': 10541.0,
#   'fecha': '1997-08-30',
#   'email': 'nombre_9760.apellido_9760@python.com'},
#  22: {'id': 7814,
#   'nombre': 'nombre_7814',
#   'apellido': 'apellido_7814',
#   'departamento': 1,
#   'sueldo': 17435.0,
#   'fecha': '2002-12-28',
#   'email': 'nombre_7814.apellido_7814@python.com'},
#  23: {'id': 1841,
#   'nombre': 'nombre_1841',
#   'apellido': 'apellido_1841',
#   'departamento': 9,
#   'sueldo': 12677.0,
#   'fecha': '2019-05-06',
#   'email': 'nombre_1841.apellido_1841@python.com'},
#  24: {'id': 8026,
#   'nombre': 'nombre_8026',
#   'apellido': 'apellido_8026',
#   'departamento': 3,
#   'sueldo': 16541.0,
#   'fecha': '2002-05-30',
#   'email': 'nombre_8026.apellido_8026@python.com'},
#  25: {'id': 7323,
#   'nombre': 'nombre_7323',
#   'apellido': 'apellido_7323',
#   'departamento': 10,
#   'sueldo': 15289.0,
#   'fecha': '2004-05-02',
#   'email': 'nombre_7323.apellido_7323@python.com'},
#  26: {'id': 7963,
#   'nombre': 'nombre_7963',
#   'apellido': 'apellido_7963',
#   'departamento': 6,
#   'sueldo': 11607.0,
#   'fecha': '2002-08-01',
#   'email': 'nombre_7963.apellido_7963@python.com'},
#  27: {'id': 7203,
#   'nombre': 'nombre_7203',
#   'apellido': 'apellido_7203',
#   'departamento': 1,
#   'sueldo': 19182.0,
#   'fecha': '2004-08-30',
#   'email': 'nombre_7203.apellido_7203@python.com'},
#  28: {'id': 2911,
#   'nombre': 'nombre_2911',
#   'apellido': 'apellido_2911',
#   'departamento': 1,
#   'sueldo': 17535.0,
#   'fecha': '2016-05-31',
#   'email': 'nombre_2911.apellido_2911@python.com'},
#  29: {'id': 190,
#   'nombre': 'nombre_190',
#   'apellido': 'apellido_190',
#   'departamento': 9,
#   'sueldo': 13832.0,
#   'fecha': '2023-11-12',
#   'email': 'nombre_190.apellido_190@python.com'},
#  30: {'id': 3922,
#   'nombre': 'nombre_3922',
#   'apellido': 'apellido_3922',
#   'departamento': 4,
#   'sueldo': 12349.0,
#   'fecha': '2013-08-24',
#   'email': 'nombre_3922.apellido_3922@python.com'},
#  31: {'id': 3042,
#   'nombre': 'nombre_3042',
#   'apellido': 'apellido_3042',
#   'departamento': 9,
#   'sueldo': 13892.0,
#   'fecha': '2016-01-21',
#   'email': 'nombre_3042.apellido_3042@python.com'},
#  32: {'id': 3166,
#   'nombre': 'nombre_3166',
#   'apellido': 'apellido_3166',
#   'departamento': 4,
#   'sueldo': 16371.0,
#   'fecha': '2015-09-19',
#   'email': 'nombre_3166.apellido_3166@python.com'},
#  33: {'id': 2256,
#   'nombre': 'nombre_2256',
#   'apellido': 'apellido_2256',
#   'departamento': 5,
#   'sueldo': 10729.0,
#   'fecha': '2018-03-17',
#   'email': 'nombre_2256.apellido_2256@python.com'},
#  34: {'id': 8457,
#   'nombre': 'nombre_8457',
#   'apellido': 'apellido_8457',
#   'departamento': 3,
#   'sueldo': 14964.0,
#   'fecha': '2001-03-25',
#   'email': 'nombre_8457.apellido_8457@python.com'},
#  35: {'id': 7408,
#   'nombre': 'nombre_7408',
#   'apellido': 'apellido_7408',
#   'departamento': 1,
#   'sueldo': 14518.0,
#   'fecha': '2004-02-07',
#   'email': 'nombre_7408.apellido_7408@python.com'},
#  36: {'id': 2406,
#   'nombre': 'nombre_2406',
#   'apellido': 'apellido_2406',
#   'departamento': 7,
#   'sueldo': 11434.0,
#   'fecha': '2017-10-18',
#   'email': 'nombre_2406.apellido_2406@python.com'},
#  37: {'id': 7796,
#   'nombre': 'nombre_7796',
#   'apellido': 'apellido_7796',
#   'departamento': 7,
#   'sueldo': 15986.0,
#   'fecha': '2003-01-15',
#   'email': 'nombre_7796.apellido_7796@python.com'},
#  38: {'id': 8825,
#   'nombre': 'nombre_8825',
#   'apellido': 'apellido_8825',
#   'departamento': 8,
#   'sueldo': 15941.0,
#   'fecha': '2000-03-22',
#   'email': 'nombre_8825.apellido_8825@python.com'},
#  39: {'id': 8783,
#   'nombre': 'nombre_8783',
#   'apellido': 'apellido_8783',
#   'departamento': 9,
#   'sueldo': 19159.0,
#   'fecha': '2000-05-03',
#   'email': 'nombre_8783.apellido_8783@python.com'},
#  40: {'id': 5749,
#   'nombre': 'nombre_5749',
#   'apellido': 'apellido_5749',
#   'departamento': 4,
#   'sueldo': 19269.0,
#   'fecha': '2008-08-23',
#   'email': 'nombre_5749.apellido_5749@python.com'},
#  41: {'id': 5208,
#   'nombre': 'nombre_5208',
#   'apellido': 'apellido_5208',
#   'departamento': 1,
#   'sueldo': 16653.0,
#   'fecha': '2010-02-15',
#   'email': 'nombre_5208.apellido_5208@python.com'},
#  42: {'id': 9958,
#   'nombre': 'nombre_9958',
#   'apellido': 'apellido_9958',
#   'departamento': 10,
#   'sueldo': 17807.0,
#   'fecha': '1997-02-13',
#   'email': 'nombre_9958.apellido_9958@python.com'},
#  43: {'id': 607,
#   'nombre': 'nombre_607',
#   'apellido': 'apellido_607',
#   'departamento': 5,
#   'sueldo': 17981.0,
#   'fecha': '2022-09-21',
#   'email': 'nombre_607.apellido_607@python.com'},
#  44: {'id': 420,
#   'nombre': 'nombre_420',
#   'apellido': 'apellido_420',
#   'departamento': 7,
#   'sueldo': 18496.0,
#   'fecha': '2023-03-27',
#   'email': 'nombre_420.apellido_420@python.com'},
#  45: {'id': 3304,
#   'nombre': 'nombre_3304',
#   'apellido': 'apellido_3304',
#   'departamento': 8,
#   'sueldo': 13842.0,
#   'fecha': '2015-05-04',
#   'email': 'nombre_3304.apellido_3304@python.com'},
#  46: {'id': 4013,
#   'nombre': 'nombre_4013',
#   'apellido': 'apellido_4013',
#   'departamento': 2,
#   'sueldo': 17029.0,
#   'fecha': '2013-05-25',
#   'email': 'nombre_4013.apellido_4013@python.com'},
#  47: {'id': 8384,
#   'nombre': 'nombre_8384',
#   'apellido': 'apellido_8384',
#   'departamento': 3,
#   'sueldo': 12079.0,
#   'fecha': '2001-06-06',
#   'email': 'nombre_8384.apellido_8384@python.com'},
#  48: {'id': 7919,
#   'nombre': 'nombre_7919',
#   'apellido': 'apellido_7919',
#   'departamento': 3,
#   'sueldo': 14229.0,
#   'fecha': '2002-09-14',
#   'email': 'nombre_7919.apellido_7919@python.com'},
#  49: {'id': 666,
#   'nombre': 'nombre_666',
#   'apellido': 'apellido_666',
#   'departamento': 9,
#   'sueldo': 10282.0,
#   'fecha': '2022-07-24',
#   'email': 'nombre_666.apellido_666@python.com'},
#  50: {'id': 5483,
#   'nombre': 'nombre_5483',
#   'apellido': 'apellido_5483',
#   'departamento': 6,
#   'sueldo': 16613.0,
#   'fecha': '2009-05-16',
#   'email': 'nombre_5483.apellido_5483@python.com'},
#  51: {'id': 5272,
#   'nombre': 'nombre_5272',
#   'apellido': 'apellido_5272',
#   'departamento': 1,
#   'sueldo': 16326.0,
#   'fecha': '2009-12-13',
#   'email': 'nombre_5272.apellido_5272@python.com'},
#  52: {'id': 6661,
#   'nombre': 'nombre_6661',
#   'apellido': 'apellido_6661',
#   'departamento': 2,
#   'sueldo': 17343.0,
#   'fecha': '2006-02-23',
#   'email': 'nombre_6661.apellido_6661@python.com'},
#  53: {'id': 6290,
#   'nombre': 'nombre_6290',
#   'apellido': 'apellido_6290',
#   'departamento': 4,
#   'sueldo': 10317.0,
#   'fecha': '2007-03-01',
#   'email': 'nombre_6290.apellido_6290@python.com'},
#  54: {'id': 6229,
#   'nombre': 'nombre_6229',
#   'apellido': 'apellido_6229',
#   'departamento': 10,
#   'sueldo': 12800.0,
#   'fecha': '2007-05-01',
#   'email': 'nombre_6229.apellido_6229@python.com'},
#  55: {'id': 8900,
#   'nombre': 'nombre_8900',
#   'apellido': 'apellido_8900',
#   'departamento': 4,
#   'sueldo': 15696.0,
#   'fecha': '2000-01-07',
#   'email': 'nombre_8900.apellido_8900@python.com'},
#  56: {'id': 2481,
#   'nombre': 'nombre_2481',
#   'apellido': 'apellido_2481',
#   'departamento': 4,
#   'sueldo': 18589.0,
#   'fecha': '2017-08-04',
#   'email': 'nombre_2481.apellido_2481@python.com'},
#  57: {'id': 3825,
#   'nombre': 'nombre_3825',
#   'apellido': 'apellido_3825',
#   'departamento': 4,
#   'sueldo': 17112.0,
#   'fecha': '2013-11-29',
#   'email': 'nombre_3825.apellido_3825@python.com'},
#  58: {'id': 2121,
#   'nombre': 'nombre_2121',
#   'apellido': 'apellido_2121',
#   'departamento': 5,
#   'sueldo': 19237.0,
#   'fecha': '2018-07-30',
#   'email': 'nombre_2121.apellido_2121@python.com'},
#  59: {'id': 5655,
#   'nombre': 'nombre_5655',
#   'apellido': 'apellido_5655',
#   'departamento': 10,
#   'sueldo': 12303.0,
#   'fecha': '2008-11-25',
#   'email': 'nombre_5655.apellido_5655@python.com'},
#  60: {'id': 1056,
#   'nombre': 'nombre_1056',
#   'apellido': 'apellido_1056',
#   'departamento': 10,
#   'sueldo': 16860.0,
#   'fecha': '2021-06-29',
#   'email': 'nombre_1056.apellido_1056@python.com'},
#  61: {'id': 2698,
#   'nombre': 'nombre_2698',
#   'apellido': 'apellido_2698',
#   'departamento': 5,
#   'sueldo': 18910.0,
#   'fecha': '2016-12-30',
#   'email': 'nombre_2698.apellido_2698@python.com'},
#  62: {'id': 7283,
#   'nombre': 'nombre_7283',
#   'apellido': 'apellido_7283',
#   'departamento': 1,
#   'sueldo': 11293.0,
#   'fecha': '2004-06-11',
#   'email': 'nombre_7283.apellido_7283@python.com'},
#  63: {'id': 1927,
#   'nombre': 'nombre_1927',
#   'apellido': 'apellido_1927',
#   'departamento': 2,
#   'sueldo': 13131.0,
#   'fecha': '2019-02-09',
#   'email': 'nombre_1927.apellido_1927@python.com'},
#  64: {'id': 861,
#   'nombre': 'nombre_861',
#   'apellido': 'apellido_861',
#   'departamento': 1,
#   'sueldo': 18394.0,
#   'fecha': '2022-01-10',
#   'email': 'nombre_861.apellido_861@python.com'},
#  65: {'id': 3033,
#   'nombre': 'nombre_3033',
#   'apellido': 'apellido_3033',
#   'departamento': 7,
#   'sueldo': 15095.0,
#   'fecha': '2016-01-30',
#   'email': 'nombre_3033.apellido_3033@python.com'},
#  66: {'id': 4609,
#   'nombre': 'nombre_4609',
#   'apellido': 'apellido_4609',
#   'departamento': 5,
#   'sueldo': 14243.0,
#   'fecha': '2011-10-07',
#   'email': 'nombre_4609.apellido_4609@python.com'},
#  67: {'id': 7843,
#   'nombre': 'nombre_7843',
#   'apellido': 'apellido_7843',
#   'departamento': 7,
#   'sueldo': 11519.0,
#   'fecha': '2002-11-29',
#   'email': 'nombre_7843.apellido_7843@python.com'},
#  68: {'id': 5345,
#   'nombre': 'nombre_5345',
#   'apellido': 'apellido_5345',
#   'departamento': 4,
#   'sueldo': 13805.0,
#   'fecha': '2009-10-01',
#   'email': 'nombre_5345.apellido_5345@python.com'},
#  69: {'id': 8480,
#   'nombre': 'nombre_8480',
#   'apellido': 'apellido_8480',
#   'departamento': 5,
#   'sueldo': 10561.0,
#   'fecha': '2001-03-02',
#   'email': 'nombre_8480.apellido_8480@python.com'},
#  70: {'id': 9999,
#   'nombre': 'nombre_9999',
#   'apellido': 'apellido_9999',
#   'departamento': 4,
#   'sueldo': 10975.0,
#   'fecha': '1997-01-03',
#   'email': 'nombre_9999.apellido_9999@python.com'},
#  71: {'id': 8950,
#   'nombre': 'nombre_8950',
#   'apellido': 'apellido_8950',
#   'departamento': 2,
#   'sueldo': 11964.0,
#   'fecha': '1999-11-18',
#   'email': 'nombre_8950.apellido_8950@python.com'},
#  72: {'id': 8791,
#   'nombre': 'nombre_8791',
#   'apellido': 'apellido_8791',
#   'departamento': 7,
#   'sueldo': 11673.0,
#   'fecha': '2000-04-25',
#   'email': 'nombre_8791.apellido_8791@python.com'},
#  73: {'id': 9834,
#   'nombre': 'nombre_9834',
#   'apellido': 'apellido_9834',
#   'departamento': 5,
#   'sueldo': 18726.0,
#   'fecha': '1997-06-17',
#   'email': 'nombre_9834.apellido_9834@python.com'},
#  74: {'id': 2966,
#   'nombre': 'nombre_2966',
#   'apellido': 'apellido_2966',
#   'departamento': 6,
#   'sueldo': 13095.0,
#   'fecha': '2016-04-06',
#   'email': 'nombre_2966.apellido_2966@python.com'},
#  75: {'id': 4439,
#   'nombre': 'nombre_4439',
#   'apellido': 'apellido_4439',
#   'departamento': 8,
#   'sueldo': 11601.0,
#   'fecha': '2012-03-25',
#   'email': 'nombre_4439.apellido_4439@python.com'},
#  76: {'id': 2904,
#   'nombre': 'nombre_2904',
#   'apellido': 'apellido_2904',
#   'departamento': 7,
#   'sueldo': 16649.0,
#   'fecha': '2016-06-07',
#   'email': 'nombre_2904.apellido_2904@python.com'},
#  77: {'id': 8253,
#   'nombre': 'nombre_8253',
#   'apellido': 'apellido_8253',
#   'departamento': 5,
#   'sueldo': 13245.0,
#   'fecha': '2001-10-15',
#   'email': 'nombre_8253.apellido_8253@python.com'},
#  78: {'id': 5850,
#   'nombre': 'nombre_5850',
#   'apellido': 'apellido_5850',
#   'departamento': 10,
#   'sueldo': 11976.0,
#   'fecha': '2008-05-14',
#   'email': 'nombre_5850.apellido_5850@python.com'},
#  79: {'id': 8689,
#   'nombre': 'nombre_8689',
#   'apellido': 'apellido_8689',
#   'departamento': 9,
#   'sueldo': 19574.0,
#   'fecha': '2000-08-05',
#   'email': 'nombre_8689.apellido_8689@python.com'},
#  80: {'id': 3158,
#   'nombre': 'nombre_3158',
#   'apellido': 'apellido_3158',
#   'departamento': 4,
#   'sueldo': 13117.0,
#   'fecha': '2015-09-27',
#   'email': 'nombre_3158.apellido_3158@python.com'},
#  81: {'id': 2700,
#   'nombre': 'nombre_2700',
#   'apellido': 'apellido_2700',
#   'departamento': 2,
#   'sueldo': 17487.0,
#   'fecha': '2016-12-28',
#   'email': 'nombre_2700.apellido_2700@python.com'},
#  82: {'id': 3891,
#   'nombre': 'nombre_3891',
#   'apellido': 'apellido_3891',
#   'departamento': 6,
#   'sueldo': 17651.0,
#   'fecha': '2013-09-24',
#   'email': 'nombre_3891.apellido_3891@python.com'},
#  83: {'id': 1202,
#   'nombre': 'nombre_1202',
#   'apellido': 'apellido_1202',
#   'departamento': 10,
#   'sueldo': 11020.0,
#   'fecha': '2021-02-03',
#   'email': 'nombre_1202.apellido_1202@python.com'},
#  84: {'id': 3314,
#   'nombre': 'nombre_3314',
#   'apellido': 'apellido_3314',
#   'departamento': 1,
#   'sueldo': 14369.0,
#   'fecha': '2015-04-24',
#   'email': 'nombre_3314.apellido_3314@python.com'},
#  85: {'id': 7045,
#   'nombre': 'nombre_7045',
#   'apellido': 'apellido_7045',
#   'departamento': 10,
#   'sueldo': 14119.0,
#   'fecha': '2005-02-04',
#   'email': 'nombre_7045.apellido_7045@python.com'},
#  86: {'id': 6549,
#   'nombre': 'nombre_6549',
#   'apellido': 'apellido_6549',
#   'departamento': 8,
#   'sueldo': 18406.0,
#   'fecha': '2006-06-15',
#   'email': 'nombre_6549.apellido_6549@python.com'},
#  87: {'id': 43,
#   'nombre': 'nombre_43',
#   'apellido': 'apellido_43',
#   'departamento': 8,
#   'sueldo': 16915.0,
#   'fecha': '2024-04-07',
#   'email': 'nombre_43.apellido_43@python.com'},
#  88: {'id': 1308,
#   'nombre': 'nombre_1308',
#   'apellido': 'apellido_1308',
#   'departamento': 5,
#   'sueldo': 17648.0,
#   'fecha': '2020-10-20',
#   'email': 'nombre_1308.apellido_1308@python.com'},
#  89: {'id': 9357,
#   'nombre': 'nombre_9357',
#   'apellido': 'apellido_9357',
#   'departamento': 4,
#   'sueldo': 10049.0,
#   'fecha': '1998-10-07',
#   'email': 'nombre_9357.apellido_9357@python.com'},
#  90: {'id': 2239,
#   'nombre': 'nombre_2239',
#   'apellido': 'apellido_2239',
#   'departamento': 10,
#   'sueldo': 16462.0,
#   'fecha': '2018-04-03',
#   'email': 'nombre_2239.apellido_2239@python.com'},
#  91: {'id': 3917,
#   'nombre': 'nombre_3917',
#   'apellido': 'apellido_3917',
#   'departamento': 10,
#   'sueldo': 16694.0,
#   'fecha': '2013-08-29',
#   'email': 'nombre_3917.apellido_3917@python.com'},
#  92: {'id': 5545,
#   'nombre': 'nombre_5545',
#   'apellido': 'apellido_5545',
#   'departamento': 10,
#   'sueldo': 13885.0,
#   'fecha': '2009-03-15',
#   'email': 'nombre_5545.apellido_5545@python.com'},
#  93: {'id': 5609,
#   'nombre': 'nombre_5609',
#   'apellido': 'apellido_5609',
#   'departamento': 6,
#   'sueldo': 14648.0,
#   'fecha': '2009-01-10',
#   'email': 'nombre_5609.apellido_5609@python.com'},
#  94: {'id': 9518,
#   'nombre': 'nombre_9518',
#   'apellido': 'apellido_9518',
#   'departamento': 1,
#   'sueldo': 13301.0,
#   'fecha': '1998-04-29',
#   'email': 'nombre_9518.apellido_9518@python.com'},
#  95: {'id': 4638,
#   'nombre': 'nombre_4638',
#   'apellido': 'apellido_4638',
#   'departamento': 4,
#   'sueldo': 17643.0,
#   'fecha': '2011-09-08',
#   'email': 'nombre_4638.apellido_4638@python.com'},
#  96: {'id': 1301,
#   'nombre': 'nombre_1301',
#   'apellido': 'apellido_1301',
#   'departamento': 9,
#   'sueldo': 16396.0,
#   'fecha': '2020-10-27',
#   'email': 'nombre_1301.apellido_1301@python.com'},
#  97: {'id': 1864,
#   'nombre': 'nombre_1864',
#   'apellido': 'apellido_1864',
#   'departamento': 3,
#   'sueldo': 19127.0,
#   'fecha': '2019-04-13',
#   'email': 'nombre_1864.apellido_1864@python.com'},
#  98: {'id': 526,
#   'nombre': 'nombre_526',
#   'apellido': 'apellido_526',
#   'departamento': 9,
#   'sueldo': 11581.0,
#   'fecha': '2022-12-11',
#   'email': 'nombre_526.apellido_526@python.com'},
#  99: {'id': 646,
#   'nombre': 'nombre_646',
#   'apellido': 'apellido_646',
#   'departamento': 9,
#   'sueldo': 16426.0,
#   'fecha': '2022-08-13',
#   'email': 'nombre_646.apellido_646@python.com'},
#  100: {'id': 2274,
#   'nombre': 'nombre_2274',
#   'apellido': 'apellido_2274',
#   'departamento': 7,
#   'sueldo': 15647.0,
#   'fecha': '2018-02-27',
#   'email': 'nombre_2274.apellido_2274@python.com'},
#  101: {'id': 3285,
#   'nombre': 'nombre_3285',
#   'apellido': 'apellido_3285',
#   'departamento': 1,
#   'sueldo': 14938.0,
#   'fecha': '2015-05-23',
#   'email': 'nombre_3285.apellido_3285@python.com'},
#  102: {'id': 105,
#   'nombre': 'nombre_105',
#   'apellido': 'apellido_105',
#   'departamento': 6,
#   'sueldo': 12033.0,
#   'fecha': '2024-02-05',
#   'email': 'nombre_105.apellido_105@python.com'},
#  103: {'id': 7392,
#   'nombre': 'nombre_7392',
#   'apellido': 'apellido_7392',
#   'departamento': 6,
#   'sueldo': 12443.0,
#   'fecha': '2004-02-23',
#   'email': 'nombre_7392.apellido_7392@python.com'},
#  104: {'id': 8984,
#   'nombre': 'nombre_8984',
#   'apellido': 'apellido_8984',
#   'departamento': 9,
#   'sueldo': 17580.0,
#   'fecha': '1999-10-15',
#   'email': 'nombre_8984.apellido_8984@python.com'},
#  105: {'id': 3944,
#   'nombre': 'nombre_3944',
#   'apellido': 'apellido_3944',
#   'departamento': 10,
#   'sueldo': 18508.0,
#   'fecha': '2013-08-02',
#   'email': 'nombre_3944.apellido_3944@python.com'},
#  106: {'id': 7327,
#   'nombre': 'nombre_7327',
#   'apellido': 'apellido_7327',
#   'departamento': 10,
#   'sueldo': 14885.0,
#   'fecha': '2004-04-28',
#   'email': 'nombre_7327.apellido_7327@python.com'},
#  107: {'id': 1053,
#   'nombre': 'nombre_1053',
#   'apellido': 'apellido_1053',
#   'departamento': 4,
#   'sueldo': 10041.0,
#   'fecha': '2021-07-02',
#   'email': 'nombre_1053.apellido_1053@python.com'},
#  108: {'id': 9409,
#   'nombre': 'nombre_9409',
#   'apellido': 'apellido_9409',
#   'departamento': 8,
#   'sueldo': 16822.0,
#   'fecha': '1998-08-16',
#   'email': 'nombre_9409.apellido_9409@python.com'},
#  109: {'id': 7670,
#   'nombre': 'nombre_7670',
#   'apellido': 'apellido_7670',
#   'departamento': 7,
#   'sueldo': 13026.0,
#   'fecha': '2003-05-21',
#   'email': 'nombre_7670.apellido_7670@python.com'},
#  110: {'id': 1043,
#   'nombre': 'nombre_1043',
#   'apellido': 'apellido_1043',
#   'departamento': 5,
#   'sueldo': 16444.0,
#   'fecha': '2021-07-12',
#   'email': 'nombre_1043.apellido_1043@python.com'},
#  111: {'id': 880,
#   'nombre': 'nombre_880',
#   'apellido': 'apellido_880',
#   'departamento': 10,
#   'sueldo': 18450.0,
#   'fecha': '2021-12-22',
#   'email': 'nombre_880.apellido_880@python.com'},
#  112: {'id': 3859,
#   'nombre': 'nombre_3859',
#   'apellido': 'apellido_3859',
#   'departamento': 3,
#   'sueldo': 11596.0,
#   'fecha': '2013-10-26',
#   'email': 'nombre_3859.apellido_3859@python.com'},
#  113: {'id': 6948,
#   'nombre': 'nombre_6948',
#   'apellido': 'apellido_6948',
#   'departamento': 8,
#   'sueldo': 11721.0,
#   'fecha': '2005-05-12',
#   'email': 'nombre_6948.apellido_6948@python.com'},
#  114: {'id': 7785,
#   'nombre': 'nombre_7785',
#   'apellido': 'apellido_7785',
#   'departamento': 6,
#   'sueldo': 11147.0,
#   'fecha': '2003-01-26',
#   'email': 'nombre_7785.apellido_7785@python.com'},
#  115: {'id': 8141,
#   'nombre': 'nombre_8141',
#   'apellido': 'apellido_8141',
#   'departamento': 3,
#   'sueldo': 11011.0,
#   'fecha': '2002-02-04',
#   'email': 'nombre_8141.apellido_8141@python.com'},
#  116: {'id': 7560,
#   'nombre': 'nombre_7560',
#   'apellido': 'apellido_7560',
#   'departamento': 2,
#   'sueldo': 17123.0,
#   'fecha': '2003-09-08',
#   'email': 'nombre_7560.apellido_7560@python.com'},
#  117: {'id': 1796,
#   'nombre': 'nombre_1796',
#   'apellido': 'apellido_1796',
#   'departamento': 9,
#   'sueldo': 14164.0,
#   'fecha': '2019-06-20',
#   'email': 'nombre_1796.apellido_1796@python.com'},
#  118: {'id': 256,
#   'nombre': 'nombre_256',
#   'apellido': 'apellido_256',
#   'departamento': 8,
#   'sueldo': 12023.0,
#   'fecha': '2023-09-07',
#   'email': 'nombre_256.apellido_256@python.com'},
#  119: {'id': 635,
#   'nombre': 'nombre_635',
#   'apellido': 'apellido_635',
#   'departamento': 6,
#   'sueldo': 19111.0,
#   'fecha': '2022-08-24',
#   'email': 'nombre_635.apellido_635@python.com'},
#  120: {'id': 3916,
#   'nombre': 'nombre_3916',
#   'apellido': 'apellido_3916',
#   'departamento': 6,
#   'sueldo': 19838.0,
#   'fecha': '2013-08-30',
#   'email': 'nombre_3916.apellido_3916@python.com'},
#  121: {'id': 7375,
#   'nombre': 'nombre_7375',
#   'apellido': 'apellido_7375',
#   'departamento': 7,
#   'sueldo': 16252.0,
#   'fecha': '2004-03-11',
#   'email': 'nombre_7375.apellido_7375@python.com'},
#  122: {'id': 8708,
#   'nombre': 'nombre_8708',
#   'apellido': 'apellido_8708',
#   'departamento': 1,
#   'sueldo': 12820.0,
#   'fecha': '2000-07-17',
#   'email': 'nombre_8708.apellido_8708@python.com'},
#  123: {'id': 3726,
#   'nombre': 'nombre_3726',
#   'apellido': 'apellido_3726',
#   'departamento': 4,
#   'sueldo': 15646.0,
#   'fecha': '2014-03-08',
#   'email': 'nombre_3726.apellido_3726@python.com'},
#  124: {'id': 5842,
#   'nombre': 'nombre_5842',
#   'apellido': 'apellido_5842',
#   'departamento': 4,
#   'sueldo': 12752.0,
#   'fecha': '2008-05-22',
#   'email': 'nombre_5842.apellido_5842@python.com'},
#  125: {'id': 1915,
#   'nombre': 'nombre_1915',
#   'apellido': 'apellido_1915',
#   'departamento': 8,
#   'sueldo': 11867.0,
#   'fecha': '2019-02-21',
#   'email': 'nombre_1915.apellido_1915@python.com'},
#  126: {'id': 1049,
#   'nombre': 'nombre_1049',
#   'apellido': 'apellido_1049',
#   'departamento': 4,
#   'sueldo': 11786.0,
#   'fecha': '2021-07-06',
#   'email': 'nombre_1049.apellido_1049@python.com'},
#  127: {'id': 4145,
#   'nombre': 'nombre_4145',
#   'apellido': 'apellido_4145',
#   'departamento': 10,
#   'sueldo': 16471.0,
#   'fecha': '2013-01-13',
#   'email': 'nombre_4145.apellido_4145@python.com'},
#  128: {'id': 8058,
#   'nombre': 'nombre_8058',
#   'apellido': 'apellido_8058',
#   'departamento': 6,
#   'sueldo': 13323.0,
#   'fecha': '2002-04-28',
#   'email': 'nombre_8058.apellido_8058@python.com'},
#  129: {'id': 1479,
#   'nombre': 'nombre_1479',
#   'apellido': 'apellido_1479',
#   'departamento': 4,
#   'sueldo': 10889.0,
#   'fecha': '2020-05-02',
#   'email': 'nombre_1479.apellido_1479@python.com'},
#  130: {'id': 8638,
#   'nombre': 'nombre_8638',
#   'apellido': 'apellido_8638',
#   'departamento': 10,
#   'sueldo': 15410.0,
#   'fecha': '2000-09-25',
#   'email': 'nombre_8638.apellido_8638@python.com'},
#  131: {'id': 3754,
#   'nombre': 'nombre_3754',
#   'apellido': 'apellido_3754',
#   'departamento': 4,
#   'sueldo': 14569.0,
#   'fecha': '2014-02-08',
#   'email': 'nombre_3754.apellido_3754@python.com'},
#  132: {'id': 7157,
#   'nombre': 'nombre_7157',
#   'apellido': 'apellido_7157',
#   'departamento': 9,
#   'sueldo': 16632.0,
#   'fecha': '2004-10-15',
#   'email': 'nombre_7157.apellido_7157@python.com'},
#  133: {'id': 9398,
#   'nombre': 'nombre_9398',
#   'apellido': 'apellido_9398',
#   'departamento': 7,
#   'sueldo': 16683.0,
#   'fecha': '1998-08-27',
#   'email': 'nombre_9398.apellido_9398@python.com'},
#  134: {'id': 5335,
#   'nombre': 'nombre_5335',
#   'apellido': 'apellido_5335',
#   'departamento': 1,
#   'sueldo': 18026.0,
#   'fecha': '2009-10-11',
#   'email': 'nombre_5335.apellido_5335@python.com'},
#  135: {'id': 3559,
#   'nombre': 'nombre_3559',
#   'apellido': 'apellido_3559',
#   'departamento': 10,
#   'sueldo': 15766.0,
#   'fecha': '2014-08-22',
#   'email': 'nombre_3559.apellido_3559@python.com'},
#  136: {'id': 2656,
#   'nombre': 'nombre_2656',
#   'apellido': 'apellido_2656',
#   'departamento': 10,
#   'sueldo': 18162.0,
#   'fecha': '2017-02-10',
#   'email': 'nombre_2656.apellido_2656@python.com'},
#  137: {'id': 1781,
#   'nombre': 'nombre_1781',
#   'apellido': 'apellido_1781',
#   'departamento': 4,
#   'sueldo': 14342.0,
#   'fecha': '2019-07-05',
#   'email': 'nombre_1781.apellido_1781@python.com'},
#  138: {'id': 9763,
#   'nombre': 'nombre_9763',
#   'apellido': 'apellido_9763',
#   'departamento': 8,
#   'sueldo': 11616.0,
#   'fecha': '1997-08-27',
#   'email': 'nombre_9763.apellido_9763@python.com'},
#  139: {'id': 9233,
#   'nombre': 'nombre_9233',
#   'apellido': 'apellido_9233',
#   'departamento': 3,
#   'sueldo': 13165.0,
#   'fecha': '1999-02-08',
#   'email': 'nombre_9233.apellido_9233@python.com'},
#  140: {'id': 6854,
#   'nombre': 'nombre_6854',
#   'apellido': 'apellido_6854',
#   'departamento': 1,
#   'sueldo': 13597.0,
#   'fecha': '2005-08-14',
#   'email': 'nombre_6854.apellido_6854@python.com'},
#  141: {'id': 3610,
#   'nombre': 'nombre_3610',
#   'apellido': 'apellido_3610',
#   'departamento': 1,
#   'sueldo': 12318.0,
#   'fecha': '2014-07-02',
#   'email': 'nombre_3610.apellido_3610@python.com'},
#  142: {'id': 321,
#   'nombre': 'nombre_321',
#   'apellido': 'apellido_321',
#   'departamento': 2,
#   'sueldo': 12108.0,
#   'fecha': '2023-07-04',
#   'email': 'nombre_321.apellido_321@python.com'},
#  143: {'id': 6892,
#   'nombre': 'nombre_6892',
#   'apellido': 'apellido_6892',
#   'departamento': 2,
#   'sueldo': 16510.0,
#   'fecha': '2005-07-07',
#   'email': 'nombre_6892.apellido_6892@python.com'},
#  144: {'id': 3543,
#   'nombre': 'nombre_3543',
#   'apellido': 'apellido_3543',
#   'departamento': 2,
#   'sueldo': 17695.0,
#   'fecha': '2014-09-07',
#   'email': 'nombre_3543.apellido_3543@python.com'},
#  145: {'id': 4242,
#   'nombre': 'nombre_4242',
#   'apellido': 'apellido_4242',
#   'departamento': 4,
#   'sueldo': 17761.0,
#   'fecha': '2012-10-08',
#   'email': 'nombre_4242.apellido_4242@python.com'},
#  146: {'id': 3672,
#   'nombre': 'nombre_3672',
#   'apellido': 'apellido_3672',
#   'departamento': 8,
#   'sueldo': 16024.0,
#   'fecha': '2014-05-01',
#   'email': 'nombre_3672.apellido_3672@python.com'},
#  147: {'id': 4115,
#   'nombre': 'nombre_4115',
#   'apellido': 'apellido_4115',
#   'departamento': 7,
#   'sueldo': 15905.0,
#   'fecha': '2013-02-12',
#   'email': 'nombre_4115.apellido_4115@python.com'},
#  148: {'id': 894,
#   'nombre': 'nombre_894',
#   'apellido': 'apellido_894',
#   'departamento': 5,
#   'sueldo': 12541.0,
#   'fecha': '2021-12-08',
#   'email': 'nombre_894.apellido_894@python.com'},
#  149: {'id': 8505,
#   'nombre': 'nombre_8505',
#   'apellido': 'apellido_8505',
#   'departamento': 9,
#   'sueldo': 10367.0,
#   'fecha': '2001-02-05',
#   'email': 'nombre_8505.apellido_8505@python.com'},
#  150: {'id': 3890,
#   'nombre': 'nombre_3890',
#   'apellido': 'apellido_3890',
#   'departamento': 8,
#   'sueldo': 10616.0,
#   'fecha': '2013-09-25',
#   'email': 'nombre_3890.apellido_3890@python.com'},
#  151: {'id': 5267,
#   'nombre': 'nombre_5267',
#   'apellido': 'apellido_5267',
#   'departamento': 9,
#   'sueldo': 11228.0,
#   'fecha': '2009-12-18',
#   'email': 'nombre_5267.apellido_5267@python.com'},
#  152: {'id': 6618,
#   'nombre': 'nombre_6618',
#   'apellido': 'apellido_6618',
#   'departamento': 5,
#   'sueldo': 10162.0,
#   'fecha': '2006-04-07',
#   'email': 'nombre_6618.apellido_6618@python.com'},
#  153: {'id': 3522,
#   'nombre': 'nombre_3522',
#   'apellido': 'apellido_3522',
#   'departamento': 6,
#   'sueldo': 14986.0,
#   'fecha': '2014-09-28',
#   'email': 'nombre_3522.apellido_3522@python.com'},
#  154: {'id': 3736,
#   'nombre': 'nombre_3736',
#   'apellido': 'apellido_3736',
#   'departamento': 9,
#   'sueldo': 15206.0,
#   'fecha': '2014-02-26',
#   'email': 'nombre_3736.apellido_3736@python.com'},
#  155: {'id': 1312,
#   'nombre': 'nombre_1312',
#   'apellido': 'apellido_1312',
#   'departamento': 2,
#   'sueldo': 17919.0,
#   'fecha': '2020-10-16',
#   'email': 'nombre_1312.apellido_1312@python.com'},
#  156: {'id': 9894,
#   'nombre': 'nombre_9894',
#   'apellido': 'apellido_9894',
#   'departamento': 9,
#   'sueldo': 16905.0,
#   'fecha': '1997-04-18',
#   'email': 'nombre_9894.apellido_9894@python.com'},
#  157: {'id': 193,
#   'nombre': 'nombre_193',
#   'apellido': 'apellido_193',
#   'departamento': 6,
#   'sueldo': 10154.0,
#   'fecha': '2023-11-09',
#   'email': 'nombre_193.apellido_193@python.com'},
#  158: {'id': 4690,
#   'nombre': 'nombre_4690',
#   'apellido': 'apellido_4690',
#   'departamento': 2,
#   'sueldo': 11266.0,
#   'fecha': '2011-07-18',
#   'email': 'nombre_4690.apellido_4690@python.com'},
#  159: {'id': 5262,
#   'nombre': 'nombre_5262',
#   'apellido': 'apellido_5262',
#   'departamento': 10,
#   'sueldo': 14724.0,
#   'fecha': '2009-12-23',
#   'email': 'nombre_5262.apellido_5262@python.com'},
#  160: {'id': 6075,
#   'nombre': 'nombre_6075',
#   'apellido': 'apellido_6075',
#   'departamento': 3,
#   'sueldo': 19039.0,
#   'fecha': '2007-10-02',
#   'email': 'nombre_6075.apellido_6075@python.com'},
#  161: {'id': 9385,
#   'nombre': 'nombre_9385',
#   'apellido': 'apellido_9385',
#   'departamento': 9,
#   'sueldo': 12405.0,
#   'fecha': '1998-09-09',
#   'email': 'nombre_9385.apellido_9385@python.com'},
#  162: {'id': 9324,
#   'nombre': 'nombre_9324',
#   'apellido': 'apellido_9324',
#   'departamento': 1,
#   'sueldo': 15114.0,
#   'fecha': '1998-11-09',
#   'email': 'nombre_9324.apellido_9324@python.com'},
#  163: {'id': 6126,
#   'nombre': 'nombre_6126',
#   'apellido': 'apellido_6126',
#   'departamento': 9,
#   'sueldo': 18655.0,
#   'fecha': '2007-08-12',
#   'email': 'nombre_6126.apellido_6126@python.com'},
#  164: {'id': 8828,
#   'nombre': 'nombre_8828',
#   'apellido': 'apellido_8828',
#   'departamento': 8,
#   'sueldo': 19704.0,
#   'fecha': '2000-03-19',
#   'email': 'nombre_8828.apellido_8828@python.com'},
#  165: {'id': 6325,
#   'nombre': 'nombre_6325',
#   'apellido': 'apellido_6325',
#   'departamento': 2,
#   'sueldo': 11369.0,
#   'fecha': '2007-01-25',
#   'email': 'nombre_6325.apellido_6325@python.com'},
#  166: {'id': 9354,
#   'nombre': 'nombre_9354',
#   'apellido': 'apellido_9354',
#   'departamento': 4,
#   'sueldo': 11515.0,
#   'fecha': '1998-10-10',
#   'email': 'nombre_9354.apellido_9354@python.com'},
#  167: {'id': 9853,
#   'nombre': 'nombre_9853',
#   'apellido': 'apellido_9853',
#   'departamento': 8,
#   'sueldo': 18895.0,
#   'fecha': '1997-05-29',
#   'email': 'nombre_9853.apellido_9853@python.com'},
#  168: {'id': 5250,
#   'nombre': 'nombre_5250',
#   'apellido': 'apellido_5250',
#   'departamento': 3,
#   'sueldo': 14027.0,
#   'fecha': '2010-01-04',
#   'email': 'nombre_5250.apellido_5250@python.com'},
#  169: {'id': 5648,
#   'nombre': 'nombre_5648',
#   'apellido': 'apellido_5648',
#   'departamento': 9,
#   'sueldo': 15092.0,
#   'fecha': '2008-12-02',
#   'email': 'nombre_5648.apellido_5648@python.com'},
#  170: {'id': 3686,
#   'nombre': 'nombre_3686',
#   'apellido': 'apellido_3686',
#   'departamento': 5,
#   'sueldo': 13496.0,
#   'fecha': '2014-04-17',
#   'email': 'nombre_3686.apellido_3686@python.com'},
#  171: {'id': 2930,
#   'nombre': 'nombre_2930',
#   'apellido': 'apellido_2930',
#   'departamento': 6,
#   'sueldo': 19946.0,
#   'fecha': '2016-05-12',
#   'email': 'nombre_2930.apellido_2930@python.com'},
#  172: {'id': 8022,
#   'nombre': 'nombre_8022',
#   'apellido': 'apellido_8022',
#   'departamento': 7,
#   'sueldo': 10032.0,
#   'fecha': '2002-06-03',
#   'email': 'nombre_8022.apellido_8022@python.com'},
#  173: {'id': 5688,
#   'nombre': 'nombre_5688',
#   'apellido': 'apellido_5688',
#   'departamento': 5,
#   'sueldo': 11739.0,
#   'fecha': '2008-10-23',
#   'email': 'nombre_5688.apellido_5688@python.com'},
#  174: {'id': 3679,
#   'nombre': 'nombre_3679',
#   'apellido': 'apellido_3679',
#   'departamento': 9,
#   'sueldo': 15106.0,
#   'fecha': '2014-04-24',
#   'email': 'nombre_3679.apellido_3679@python.com'},
#  175: {'id': 6836,
#   'nombre': 'nombre_6836',
#   'apellido': 'apellido_6836',
#   'departamento': 4,
#   'sueldo': 10568.0,
#   'fecha': '2005-09-01',
#   'email': 'nombre_6836.apellido_6836@python.com'},
#  176: {'id': 7196,
#   'nombre': 'nombre_7196',
#   'apellido': 'apellido_7196',
#   'departamento': 3,
#   'sueldo': 19041.0,
#   'fecha': '2004-09-06',
#   'email': 'nombre_7196.apellido_7196@python.com'},
#  177: {'id': 4640,
#   'nombre': 'nombre_4640',
#   'apellido': 'apellido_4640',
#   'departamento': 10,
#   'sueldo': 15708.0,
#   'fecha': '2011-09-06',
#   'email': 'nombre_4640.apellido_4640@python.com'},
#  178: {'id': 9495,
#   'nombre': 'nombre_9495',
#   'apellido': 'apellido_9495',
#   'departamento': 2,
#   'sueldo': 13746.0,
#   'fecha': '1998-05-22',
#   'email': 'nombre_9495.apellido_9495@python.com'},
#  179: {'id': 4736,
#   'nombre': 'nombre_4736',
#   'apellido': 'apellido_4736',
#   'departamento': 9,
#   'sueldo': 19433.0,
#   'fecha': '2011-06-02',
#   'email': 'nombre_4736.apellido_4736@python.com'},
#  180: {'id': 5454,
#   'nombre': 'nombre_5454',
#   'apellido': 'apellido_5454',
#   'departamento': 9,
#   'sueldo': 13458.0,
#   'fecha': '2009-06-14',
#   'email': 'nombre_5454.apellido_5454@python.com'},
#  181: {'id': 9280,
#   'nombre': 'nombre_9280',
#   'apellido': 'apellido_9280',
#   'departamento': 3,
#   'sueldo': 16470.0,
#   'fecha': '1998-12-23',
#   'email': 'nombre_9280.apellido_9280@python.com'},
#  182: {'id': 8036,
#   'nombre': 'nombre_8036',
#   'apellido': 'apellido_8036',
#   'departamento': 9,
#   'sueldo': 10800.0,
#   'fecha': '2002-05-20',
#   'email': 'nombre_8036.apellido_8036@python.com'},
#  183: {'id': 7651,
#   'nombre': 'nombre_7651',
#   'apellido': 'apellido_7651',
#   'departamento': 2,
#   'sueldo': 19542.0,
#   'fecha': '2003-06-09',
#   'email': 'nombre_7651.apellido_7651@python.com'},
#  184: {'id': 5954,
#   'nombre': 'nombre_5954',
#   'apellido': 'apellido_5954',
#   'departamento': 7,
#   'sueldo': 14207.0,
#   'fecha': '2008-01-31',
#   'email': 'nombre_5954.apellido_5954@python.com'},
#  185: {'id': 921,
#   'nombre': 'nombre_921',
#   'apellido': 'apellido_921',
#   'departamento': 3,
#   'sueldo': 10914.0,
#   'fecha': '2021-11-11',
#   'email': 'nombre_921.apellido_921@python.com'},
#  186: {'id': 3942,
#   'nombre': 'nombre_3942',
#   'apellido': 'apellido_3942',
#   'departamento': 8,
#   'sueldo': 14379.0,
#   'fecha': '2013-08-04',
#   'email': 'nombre_3942.apellido_3942@python.com'},
#  187: {'id': 452,
#   'nombre': 'nombre_452',
#   'apellido': 'apellido_452',
#   'departamento': 7,
#   'sueldo': 12205.0,
#   'fecha': '2023-02-23',
#   'email': 'nombre_452.apellido_452@python.com'},
#  188: {'id': 5413,
#   'nombre': 'nombre_5413',
#   'apellido': 'apellido_5413',
#   'departamento': 1,
#   'sueldo': 12582.0,
#   'fecha': '2009-07-25',
#   'email': 'nombre_5413.apellido_5413@python.com'},
#  189: {'id': 2920,
#   'nombre': 'nombre_2920',
#   'apellido': 'apellido_2920',
#   'departamento': 9,
#   'sueldo': 10825.0,
#   'fecha': '2016-05-22',
#   'email': 'nombre_2920.apellido_2920@python.com'},
#  190: {'id': 1270,
#   'nombre': 'nombre_1270',
#   'apellido': 'apellido_1270',
#   'departamento': 7,
#   'sueldo': 13104.0,
#   'fecha': '2020-11-27',
#   'email': 'nombre_1270.apellido_1270@python.com'},
#  191: {'id': 2174,
#   'nombre': 'nombre_2174',
#   'apellido': 'apellido_2174',
#   'departamento': 8,
#   'sueldo': 12031.0,
#   'fecha': '2018-06-07',
#   'email': 'nombre_2174.apellido_2174@python.com'},
#  192: {'id': 3166,
#   'nombre': 'nombre_3166',
#   'apellido': 'apellido_3166',
#   'departamento': 9,
#   'sueldo': 18871.0,
#   'fecha': '2015-09-19',
#   'email': 'nombre_3166.apellido_3166@python.com'},
#  193: {'id': 6005,
#   'nombre': 'nombre_6005',
#   'apellido': 'apellido_6005',
#   'departamento': 4,
#   'sueldo': 19026.0,
#   'fecha': '2007-12-11',
#   'email': 'nombre_6005.apellido_6005@python.com'},
#  194: {'id': 4279,
#   'nombre': 'nombre_4279',
#   'apellido': 'apellido_4279',
#   'departamento': 4,
#   'sueldo': 10629.0,
#   'fecha': '2012-09-01',
#   'email': 'nombre_4279.apellido_4279@python.com'},
#  195: {'id': 609,
#   'nombre': 'nombre_609',
#   'apellido': 'apellido_609',
#   'departamento': 7,
#   'sueldo': 18082.0,
#   'fecha': '2022-09-19',
#   'email': 'nombre_609.apellido_609@python.com'},
#  196: {'id': 250,
#   'nombre': 'nombre_250',
#   'apellido': 'apellido_250',
#   'departamento': 2,
#   'sueldo': 12680.0,
#   'fecha': '2023-09-13',
#   'email': 'nombre_250.apellido_250@python.com'},
#  197: {'id': 4423,
#   'nombre': 'nombre_4423',
#   'apellido': 'apellido_4423',
#   'departamento': 7,
#   'sueldo': 14576.0,
#   'fecha': '2012-04-10',
#   'email': 'nombre_4423.apellido_4423@python.com'},
#  198: {'id': 6265,
#   'nombre': 'nombre_6265',
#   'apellido': 'apellido_6265',
#   'departamento': 10,
#   'sueldo': 15151.0,
#   'fecha': '2007-03-26',
#   'email': 'nombre_6265.apellido_6265@python.com'},
#  199: {'id': 9814,
#   'nombre': 'nombre_9814',
#   'apellido': 'apellido_9814',
#   'departamento': 5,
#   'sueldo': 12519.0,
#   'fecha': '1997-07-07',
#   'email': 'nombre_9814.apellido_9814@python.com'},
#  200: {'id': 6915,
#   'nombre': 'nombre_6915',
#   'apellido': 'apellido_6915',
#   'departamento': 4,
#   'sueldo': 18735.0,
#   'fecha': '2005-06-14',
#   'email': 'nombre_6915.apellido_6915@python.com'},
#  201: {'id': 4854,
#   'nombre': 'nombre_4854',
#   'apellido': 'apellido_4854',
#   'departamento': 10,
#   'sueldo': 16556.0,
#   'fecha': '2011-02-04',
#   'email': 'nombre_4854.apellido_4854@python.com'},
#  202: {'id': 1547,
#   'nombre': 'nombre_1547',
#   'apellido': 'apellido_1547',
#   'departamento': 1,
#   'sueldo': 18918.0,
#   'fecha': '2020-02-24',
#   'email': 'nombre_1547.apellido_1547@python.com'},
#  203: {'id': 3599,
#   'nombre': 'nombre_3599',
#   'apellido': 'apellido_3599',
#   'departamento': 3,
#   'sueldo': 18207.0,
#   'fecha': '2014-07-13',
#   'email': 'nombre_3599.apellido_3599@python.com'},
#  204: {'id': 7840,
#   'nombre': 'nombre_7840',
#   'apellido': 'apellido_7840',
#   'departamento': 1,
#   'sueldo': 12108.0,
#   'fecha': '2002-12-02',
#   'email': 'nombre_7840.apellido_7840@python.com'},
#  205: {'id': 1537,
#   'nombre': 'nombre_1537',
#   'apellido': 'apellido_1537',
#   'departamento': 6,
#   'sueldo': 16575.0,
#   'fecha': '2020-03-05',
#   'email': 'nombre_1537.apellido_1537@python.com'},
#  206: {'id': 8081,
#   'nombre': 'nombre_8081',
#   'apellido': 'apellido_8081',
#   'departamento': 2,
#   'sueldo': 16382.0,
#   'fecha': '2002-04-05',
#   'email': 'nombre_8081.apellido_8081@python.com'},
#  207: {'id': 1252,
#   'nombre': 'nombre_1252',
#   'apellido': 'apellido_1252',
#   'departamento': 7,
#   'sueldo': 11039.0,
#   'fecha': '2020-12-15',
#   'email': 'nombre_1252.apellido_1252@python.com'},
#  208: {'id': 2736,
#   'nombre': 'nombre_2736',
#   'apellido': 'apellido_2736',
#   'departamento': 3,
#   'sueldo': 19012.0,
#   'fecha': '2016-11-22',
#   'email': 'nombre_2736.apellido_2736@python.com'},
#  209: {'id': 8852,
#   'nombre': 'nombre_8852',
#   'apellido': 'apellido_8852',
#   'departamento': 10,
#   'sueldo': 11121.0,
#   'fecha': '2000-02-24',
#   'email': 'nombre_8852.apellido_8852@python.com'},
#  210: {'id': 8188,
#   'nombre': 'nombre_8188',
#   'apellido': 'apellido_8188',
#   'departamento': 5,
#   'sueldo': 17031.0,
#   'fecha': '2001-12-19',
#   'email': 'nombre_8188.apellido_8188@python.com'},
#  211: {'id': 3891,
#   'nombre': 'nombre_3891',
#   'apellido': 'apellido_3891',
#   'departamento': 10,
#   'sueldo': 10499.0,
#   'fecha': '2013-09-24',
#   'email': 'nombre_3891.apellido_3891@python.com'},
#  212: {'id': 4506,
#   'nombre': 'nombre_4506',
#   'apellido': 'apellido_4506',
#   'departamento': 5,
#   'sueldo': 17160.0,
#   'fecha': '2012-01-18',
#   'email': 'nombre_4506.apellido_4506@python.com'},
#  213: {'id': 9854,
#   'nombre': 'nombre_9854',
#   'apellido': 'apellido_9854',
#   'departamento': 1,
#   'sueldo': 13569.0,
#   'fecha': '1997-05-28',
#   'email': 'nombre_9854.apellido_9854@python.com'},
#  214: {'id': 8708,
#   'nombre': 'nombre_8708',
#   'apellido': 'apellido_8708',
#   'departamento': 9,
#   'sueldo': 14813.0,
#   'fecha': '2000-07-17',
#   'email': 'nombre_8708.apellido_8708@python.com'},
#  215: {'id': 4995,
#   'nombre': 'nombre_4995',
#   'apellido': 'apellido_4995',
#   'departamento': 9,
#   'sueldo': 13807.0,
#   'fecha': '2010-09-16',
#   'email': 'nombre_4995.apellido_4995@python.com'},
#  216: {'id': 5533,
#   'nombre': 'nombre_5533',
#   'apellido': 'apellido_5533',
#   'departamento': 6,
#   'sueldo': 14688.0,
#   'fecha': '2009-03-27',
#   'email': 'nombre_5533.apellido_5533@python.com'},
#  217: {'id': 9829,
#   'nombre': 'nombre_9829',
#   'apellido': 'apellido_9829',
#   'departamento': 2,
#   'sueldo': 12810.0,
#   'fecha': '1997-06-22',
#   'email': 'nombre_9829.apellido_9829@python.com'},
#  218: {'id': 1174,
#   'nombre': 'nombre_1174',
#   'apellido': 'apellido_1174',
#   'departamento': 9,
#   'sueldo': 13416.0,
#   'fecha': '2021-03-03',
#   'email': 'nombre_1174.apellido_1174@python.com'},
#  219: {'id': 2448,
#   'nombre': 'nombre_2448',
#   'apellido': 'apellido_2448',
#   'departamento': 2,
#   'sueldo': 13758.0,
#   'fecha': '2017-09-06',
#   'email': 'nombre_2448.apellido_2448@python.com'},
#  220: {'id': 3481,
#   'nombre': 'nombre_3481',
#   'apellido': 'apellido_3481',
#   'departamento': 5,
#   'sueldo': 17799.0,
#   'fecha': '2014-11-08',
#   'email': 'nombre_3481.apellido_3481@python.com'},
#  221: {'id': 5378,
#   'nombre': 'nombre_5378',
#   'apellido': 'apellido_5378',
#   'departamento': 6,
#   'sueldo': 12201.0,
#   'fecha': '2009-08-29',
#   'email': 'nombre_5378.apellido_5378@python.com'},
#  222: {'id': 9588,
#   'nombre': 'nombre_9588',
#   'apellido': 'apellido_9588',
#   'departamento': 6,
#   'sueldo': 13039.0,
#   'fecha': '1998-02-18',
#   'email': 'nombre_9588.apellido_9588@python.com'},
#  223: {'id': 6857,
#   'nombre': 'nombre_6857',
#   'apellido': 'apellido_6857',
#   'departamento': 9,
#   'sueldo': 19482.0,
#   'fecha': '2005-08-11',
#   'email': 'nombre_6857.apellido_6857@python.com'},
#  224: {'id': 9925,
#   'nombre': 'nombre_9925',
#   'apellido': 'apellido_9925',
#   'departamento': 8,
#   'sueldo': 14835.0,
#   'fecha': '1997-03-18',
#   'email': 'nombre_9925.apellido_9925@python.com'},
#  225: {'id': 4053,
#   'nombre': 'nombre_4053',
#   'apellido': 'apellido_4053',
#   'departamento': 6,
#   'sueldo': 18106.0,
#   'fecha': '2013-04-15',
#   'email': 'nombre_4053.apellido_4053@python.com'},
#  226: {'id': 1123,
#   'nombre': 'nombre_1123',
#   'apellido': 'apellido_1123',
#   'departamento': 3,
#   'sueldo': 17179.0,
#   'fecha': '2021-04-23',
#   'email': 'nombre_1123.apellido_1123@python.com'},
#  227: {'id': 6667,
#   'nombre': 'nombre_6667',
#   'apellido': 'apellido_6667',
#   'departamento': 5,
#   'sueldo': 13206.0,
#   'fecha': '2006-02-17',
#   'email': 'nombre_6667.apellido_6667@python.com'},
#  228: {'id': 4079,
#   'nombre': 'nombre_4079',
#   'apellido': 'apellido_4079',
#   'departamento': 2,
#   'sueldo': 18830.0,
#   'fecha': '2013-03-20',
#   'email': 'nombre_4079.apellido_4079@python.com'},
#  229: {'id': 9794,
#   'nombre': 'nombre_9794',
#   'apellido': 'apellido_9794',
#   'departamento': 5,
#   'sueldo': 17418.0,
#   'fecha': '1997-07-27',
#   'email': 'nombre_9794.apellido_9794@python.com'},
#  230: {'id': 6650,
#   'nombre': 'nombre_6650',
#   'apellido': 'apellido_6650',
#   'departamento': 10,
#   'sueldo': 19688.0,
#   'fecha': '2006-03-06',
#   'email': 'nombre_6650.apellido_6650@python.com'},
#  231: {'id': 3113,
#   'nombre': 'nombre_3113',
#   'apellido': 'apellido_3113',
#   'departamento': 8,
#   'sueldo': 16138.0,
#   'fecha': '2015-11-11',
#   'email': 'nombre_3113.apellido_3113@python.com'},
#  232: {'id': 7267,
#   'nombre': 'nombre_7267',
#   'apellido': 'apellido_7267',
#   'departamento': 9,
#   'sueldo': 12759.0,
#   'fecha': '2004-06-27',
#   'email': 'nombre_7267.apellido_7267@python.com'},
#  233: {'id': 9349,
#   'nombre': 'nombre_9349',
#   'apellido': 'apellido_9349',
#   'departamento': 7,
#   'sueldo': 19450.0,
#   'fecha': '1998-10-15',
#   'email': 'nombre_9349.apellido_9349@python.com'},
#  234: {'id': 5873,
#   'nombre': 'nombre_5873',
#   'apellido': 'apellido_5873',
#   'departamento': 9,
#   'sueldo': 13245.0,
#   'fecha': '2008-04-21',
#   'email': 'nombre_5873.apellido_5873@python.com'},
#  235: {'id': 9638,
#   'nombre': 'nombre_9638',
#   'apellido': 'apellido_9638',
#   'departamento': 7,
#   'sueldo': 13400.0,
#   'fecha': '1997-12-30',
#   'email': 'nombre_9638.apellido_9638@python.com'},
#  236: {'id': 1478,
#   'nombre': 'nombre_1478',
#   'apellido': 'apellido_1478',
#   'departamento': 4,
#   'sueldo': 16742.0,
#   'fecha': '2020-05-03',
#   'email': 'nombre_1478.apellido_1478@python.com'},
#  237: {'id': 3400,
#   'nombre': 'nombre_3400',
#   'apellido': 'apellido_3400',
#   'departamento': 10,
#   'sueldo': 15640.0,
#   'fecha': '2015-01-28',
#   'email': 'nombre_3400.apellido_3400@python.com'},
#  238: {'id': 1411,
#   'nombre': 'nombre_1411',
#   'apellido': 'apellido_1411',
#   'departamento': 9,
#   'sueldo': 19607.0,
#   'fecha': '2020-07-09',
#   'email': 'nombre_1411.apellido_1411@python.com'},
#  239: {'id': 8951,
#   'nombre': 'nombre_8951',
#   'apellido': 'apellido_8951',
#   'departamento': 8,
#   'sueldo': 18600.0,
#   'fecha': '1999-11-17',
#   'email': 'nombre_8951.apellido_8951@python.com'},
#  240: {'id': 1796,
#   'nombre': 'nombre_1796',
#   'apellido': 'apellido_1796',
#   'departamento': 6,
#   'sueldo': 15460.0,
#   'fecha': '2019-06-20',
#   'email': 'nombre_1796.apellido_1796@python.com'},
#  241: {'id': 3534,
#   'nombre': 'nombre_3534',
#   'apellido': 'apellido_3534',
#   'departamento': 7,
#   'sueldo': 17490.0,
#   'fecha': '2014-09-16',
#   'email': 'nombre_3534.apellido_3534@python.com'},
#  242: {'id': 7995,
#   'nombre': 'nombre_7995',
#   'apellido': 'apellido_7995',
#   'departamento': 1,
#   'sueldo': 11119.0,
#   'fecha': '2002-06-30',
#   'email': 'nombre_7995.apellido_7995@python.com'},
#  243: {'id': 4443,
#   'nombre': 'nombre_4443',
#   'apellido': 'apellido_4443',
#   'departamento': 2,
#   'sueldo': 12583.0,
#   'fecha': '2012-03-21',
#   'email': 'nombre_4443.apellido_4443@python.com'},
#  244: {'id': 6960,
#   'nombre': 'nombre_6960',
#   'apellido': 'apellido_6960',
#   'departamento': 4,
#   'sueldo': 17236.0,
#   'fecha': '2005-04-30',
#   'email': 'nombre_6960.apellido_6960@python.com'},
#  245: {'id': 6345,
#   'nombre': 'nombre_6345',
#   'apellido': 'apellido_6345',
#   'departamento': 3,
#   'sueldo': 12156.0,
#   'fecha': '2007-01-05',
# ...
#   'apellido': 'apellido_2184',
#   'departamento': 1,
#   'sueldo': 11527.0,
#   'fecha': '2018-05-28',
#   'email': 'nombre_2184.apellido_2184@python.com'},
#  420: {'id': 7204,
#   'nombre': 'nombre_7204',
#   'apellido': 'apellido_7204',
#   'departamento': 5,
#   'sueldo': 13394.0,
#   'fecha': '2004-08-29',
#   'email': 'nombre_7204.apellido_7204@python.com'},
#  421: {'id': 3806,
#   'nombre': 'nombre_3806',
#   'apellido': 'apellido_3806',
#   'departamento': 8,
#   'sueldo': 19842.0,
#   'fecha': '2013-12-18',
#   'email': 'nombre_3806.apellido_3806@python.com'},
#  422: {'id': 2425,
#   'nombre': 'nombre_2425',
#   'apellido': 'apellido_2425',
#   'departamento': 5,
#   'sueldo': 12232.0,
#   'fecha': '2017-09-29',
#   'email': 'nombre_2425.apellido_2425@python.com'},
#  423: {'id': 3160,
#   'nombre': 'nombre_3160',
#   'apellido': 'apellido_3160',
#   'departamento': 6,
#   'sueldo': 11039.0,
#   'fecha': '2015-09-25',
#   'email': 'nombre_3160.apellido_3160@python.com'},
#  424: {'id': 2155,
#   'nombre': 'nombre_2155',
#   'apellido': 'apellido_2155',
#   'departamento': 6,
#   'sueldo': 15680.0,
#   'fecha': '2018-06-26',
#   'email': 'nombre_2155.apellido_2155@python.com'},
#  425: {'id': 4628,
#   'nombre': 'nombre_4628',
#   'apellido': 'apellido_4628',
#   'departamento': 7,
#   'sueldo': 16648.0,
#   'fecha': '2011-09-18',
#   'email': 'nombre_4628.apellido_4628@python.com'},
#  426: {'id': 5019,
#   'nombre': 'nombre_5019',
#   'apellido': 'apellido_5019',
#   'departamento': 7,
#   'sueldo': 11569.0,
#   'fecha': '2010-08-23',
#   'email': 'nombre_5019.apellido_5019@python.com'},
#  427: {'id': 7832,
#   'nombre': 'nombre_7832',
#   'apellido': 'apellido_7832',
#   'departamento': 4,
#   'sueldo': 13762.0,
#   'fecha': '2002-12-10',
#   'email': 'nombre_7832.apellido_7832@python.com'},
#  428: {'id': 1036,
#   'nombre': 'nombre_1036',
#   'apellido': 'apellido_1036',
#   'departamento': 9,
#   'sueldo': 19047.0,
#   'fecha': '2021-07-19',
#   'email': 'nombre_1036.apellido_1036@python.com'},
#  429: {'id': 419,
#   'nombre': 'nombre_419',
#   'apellido': 'apellido_419',
#   'departamento': 2,
#   'sueldo': 11998.0,
#   'fecha': '2023-03-28',
#   'email': 'nombre_419.apellido_419@python.com'},
#  430: {'id': 9744,
#   'nombre': 'nombre_9744',
#   'apellido': 'apellido_9744',
#   'departamento': 8,
#   'sueldo': 17134.0,
#   'fecha': '1997-09-15',
#   'email': 'nombre_9744.apellido_9744@python.com'},
#  431: {'id': 4948,
#   'nombre': 'nombre_4948',
#   'apellido': 'apellido_4948',
#   'departamento': 3,
#   'sueldo': 12968.0,
#   'fecha': '2010-11-02',
#   'email': 'nombre_4948.apellido_4948@python.com'},
#  432: {'id': 3169,
#   'nombre': 'nombre_3169',
#   'apellido': 'apellido_3169',
#   'departamento': 9,
#   'sueldo': 19858.0,
#   'fecha': '2015-09-16',
#   'email': 'nombre_3169.apellido_3169@python.com'},
#  433: {'id': 7422,
#   'nombre': 'nombre_7422',
#   'apellido': 'apellido_7422',
#   'departamento': 3,
#   'sueldo': 15035.0,
#   'fecha': '2004-01-24',
#   'email': 'nombre_7422.apellido_7422@python.com'},
#  434: {'id': 2552,
#   'nombre': 'nombre_2552',
#   'apellido': 'apellido_2552',
#   'departamento': 3,
#   'sueldo': 10568.0,
#   'fecha': '2017-05-25',
#   'email': 'nombre_2552.apellido_2552@python.com'},
#  435: {'id': 4645,
#   'nombre': 'nombre_4645',
#   'apellido': 'apellido_4645',
#   'departamento': 5,
#   'sueldo': 15701.0,
#   'fecha': '2011-09-01',
#   'email': 'nombre_4645.apellido_4645@python.com'},
#  436: {'id': 951,
#   'nombre': 'nombre_951',
#   'apellido': 'apellido_951',
#   'departamento': 9,
#   'sueldo': 14952.0,
#   'fecha': '2021-10-12',
#   'email': 'nombre_951.apellido_951@python.com'},
#  437: {'id': 6276,
#   'nombre': 'nombre_6276',
#   'apellido': 'apellido_6276',
#   'departamento': 7,
#   'sueldo': 11296.0,
#   'fecha': '2007-03-15',
#   'email': 'nombre_6276.apellido_6276@python.com'},
#  438: {'id': 9095,
#   'nombre': 'nombre_9095',
#   'apellido': 'apellido_9095',
#   'departamento': 3,
#   'sueldo': 15372.0,
#   'fecha': '1999-06-26',
#   'email': 'nombre_9095.apellido_9095@python.com'},
#  439: {'id': 5622,
#   'nombre': 'nombre_5622',
#   'apellido': 'apellido_5622',
#   'departamento': 4,
#   'sueldo': 11142.0,
#   'fecha': '2008-12-28',
#   'email': 'nombre_5622.apellido_5622@python.com'},
#  440: {'id': 6065,
#   'nombre': 'nombre_6065',
#   'apellido': 'apellido_6065',
#   'departamento': 1,
#   'sueldo': 17947.0,
#   'fecha': '2007-10-12',
#   'email': 'nombre_6065.apellido_6065@python.com'},
#  441: {'id': 6929,
#   'nombre': 'nombre_6929',
#   'apellido': 'apellido_6929',
#   'departamento': 5,
#   'sueldo': 12839.0,
#   'fecha': '2005-05-31',
#   'email': 'nombre_6929.apellido_6929@python.com'},
#  442: {'id': 7915,
#   'nombre': 'nombre_7915',
#   'apellido': 'apellido_7915',
#   'departamento': 7,
#   'sueldo': 12433.0,
#   'fecha': '2002-09-18',
#   'email': 'nombre_7915.apellido_7915@python.com'},
#  443: {'id': 4510,
#   'nombre': 'nombre_4510',
#   'apellido': 'apellido_4510',
#   'departamento': 8,
#   'sueldo': 13884.0,
#   'fecha': '2012-01-14',
#   'email': 'nombre_4510.apellido_4510@python.com'},
#  444: {'id': 1554,
#   'nombre': 'nombre_1554',
#   'apellido': 'apellido_1554',
#   'departamento': 4,
#   'sueldo': 16535.0,
#   'fecha': '2020-02-17',
#   'email': 'nombre_1554.apellido_1554@python.com'},
#  445: {'id': 2461,
#   'nombre': 'nombre_2461',
#   'apellido': 'apellido_2461',
#   'departamento': 2,
#   'sueldo': 13133.0,
#   'fecha': '2017-08-24',
#   'email': 'nombre_2461.apellido_2461@python.com'},
#  446: {'id': 9721,
#   'nombre': 'nombre_9721',
#   'apellido': 'apellido_9721',
#   'departamento': 2,
#   'sueldo': 18889.0,
#   'fecha': '1997-10-08',
#   'email': 'nombre_9721.apellido_9721@python.com'},
#  447: {'id': 9240,
#   'nombre': 'nombre_9240',
#   'apellido': 'apellido_9240',
#   'departamento': 2,
#   'sueldo': 11005.0,
#   'fecha': '1999-02-01',
#   'email': 'nombre_9240.apellido_9240@python.com'},
#  448: {'id': 5924,
#   'nombre': 'nombre_5924',
#   'apellido': 'apellido_5924',
#   'departamento': 6,
#   'sueldo': 15010.0,
#   'fecha': '2008-03-01',
#   'email': 'nombre_5924.apellido_5924@python.com'},
#  449: {'id': 7825,
#   'nombre': 'nombre_7825',
#   'apellido': 'apellido_7825',
#   'departamento': 4,
#   'sueldo': 11917.0,
#   'fecha': '2002-12-17',
#   'email': 'nombre_7825.apellido_7825@python.com'},
#  450: {'id': 7310,
#   'nombre': 'nombre_7310',
#   'apellido': 'apellido_7310',
#   'departamento': 3,
#   'sueldo': 12244.0,
#   'fecha': '2004-05-15',
#   'email': 'nombre_7310.apellido_7310@python.com'},
#  451: {'id': 2823,
#   'nombre': 'nombre_2823',
#   'apellido': 'apellido_2823',
#   'departamento': 6,
#   'sueldo': 18660.0,
#   'fecha': '2016-08-27',
#   'email': 'nombre_2823.apellido_2823@python.com'},
#  452: {'id': 7884,
#   'nombre': 'nombre_7884',
#   'apellido': 'apellido_7884',
#   'departamento': 2,
#   'sueldo': 16298.0,
#   'fecha': '2002-10-19',
#   'email': 'nombre_7884.apellido_7884@python.com'},
#  453: {'id': 4904,
#   'nombre': 'nombre_4904',
#   'apellido': 'apellido_4904',
#   'departamento': 10,
#   'sueldo': 13197.0,
#   'fecha': '2010-12-16',
#   'email': 'nombre_4904.apellido_4904@python.com'},
#  454: {'id': 8118,
#   'nombre': 'nombre_8118',
#   'apellido': 'apellido_8118',
#   'departamento': 5,
#   'sueldo': 13906.0,
#   'fecha': '2002-02-27',
#   'email': 'nombre_8118.apellido_8118@python.com'},
#  455: {'id': 1484,
#   'nombre': 'nombre_1484',
#   'apellido': 'apellido_1484',
#   'departamento': 5,
#   'sueldo': 13034.0,
#   'fecha': '2020-04-27',
#   'email': 'nombre_1484.apellido_1484@python.com'},
#  456: {'id': 7662,
#   'nombre': 'nombre_7662',
#   'apellido': 'apellido_7662',
#   'departamento': 2,
#   'sueldo': 12805.0,
#   'fecha': '2003-05-29',
#   'email': 'nombre_7662.apellido_7662@python.com'},
#  457: {'id': 3153,
#   'nombre': 'nombre_3153',
#   'apellido': 'apellido_3153',
#   'departamento': 4,
#   'sueldo': 12720.0,
#   'fecha': '2015-10-02',
#   'email': 'nombre_3153.apellido_3153@python.com'},
#  458: {'id': 897,
#   'nombre': 'nombre_897',
#   'apellido': 'apellido_897',
#   'departamento': 8,
#   'sueldo': 18205.0,
#   'fecha': '2021-12-05',
#   'email': 'nombre_897.apellido_897@python.com'},
#  459: {'id': 9425,
#   'nombre': 'nombre_9425',
#   'apellido': 'apellido_9425',
#   'departamento': 6,
#   'sueldo': 10153.0,
#   'fecha': '1998-07-31',
#   'email': 'nombre_9425.apellido_9425@python.com'},
#  460: {'id': 1454,
#   'nombre': 'nombre_1454',
#   'apellido': 'apellido_1454',
#   'departamento': 5,
#   'sueldo': 13045.0,
#   'fecha': '2020-05-27',
#   'email': 'nombre_1454.apellido_1454@python.com'},
#  461: {'id': 9291,
#   'nombre': 'nombre_9291',
#   'apellido': 'apellido_9291',
#   'departamento': 9,
#   'sueldo': 19970.0,
#   'fecha': '1998-12-12',
#   'email': 'nombre_9291.apellido_9291@python.com'},
#  462: {'id': 590,
#   'nombre': 'nombre_590',
#   'apellido': 'apellido_590',
#   'departamento': 8,
#   'sueldo': 15785.0,
#   'fecha': '2022-10-08',
#   'email': 'nombre_590.apellido_590@python.com'},
#  463: {'id': 5240,
#   'nombre': 'nombre_5240',
#   'apellido': 'apellido_5240',
#   'departamento': 1,
#   'sueldo': 14253.0,
#   'fecha': '2010-01-14',
#   'email': 'nombre_5240.apellido_5240@python.com'},
#  464: {'id': 5356,
#   'nombre': 'nombre_5356',
#   'apellido': 'apellido_5356',
#   'departamento': 1,
#   'sueldo': 16441.0,
#   'fecha': '2009-09-20',
#   'email': 'nombre_5356.apellido_5356@python.com'},
#  465: {'id': 3358,
#   'nombre': 'nombre_3358',
#   'apellido': 'apellido_3358',
#   'departamento': 4,
#   'sueldo': 18730.0,
#   'fecha': '2015-03-11',
#   'email': 'nombre_3358.apellido_3358@python.com'},
#  466: {'id': 8099,
#   'nombre': 'nombre_8099',
#   'apellido': 'apellido_8099',
#   'departamento': 3,
#   'sueldo': 17501.0,
#   'fecha': '2002-03-18',
#   'email': 'nombre_8099.apellido_8099@python.com'},
#  467: {'id': 3637,
#   'nombre': 'nombre_3637',
#   'apellido': 'apellido_3637',
#   'departamento': 4,
#   'sueldo': 14138.0,
#   'fecha': '2014-06-05',
#   'email': 'nombre_3637.apellido_3637@python.com'},
#  468: {'id': 4947,
#   'nombre': 'nombre_4947',
#   'apellido': 'apellido_4947',
#   'departamento': 2,
#   'sueldo': 10319.0,
#   'fecha': '2010-11-03',
#   'email': 'nombre_4947.apellido_4947@python.com'},
#  469: {'id': 8552,
#   'nombre': 'nombre_8552',
#   'apellido': 'apellido_8552',
#   'departamento': 3,
#   'sueldo': 19878.0,
#   'fecha': '2000-12-20',
#   'email': 'nombre_8552.apellido_8552@python.com'},
#  470: {'id': 3482,
#   'nombre': 'nombre_3482',
#   'apellido': 'apellido_3482',
#   'departamento': 10,
#   'sueldo': 13309.0,
#   'fecha': '2014-11-07',
#   'email': 'nombre_3482.apellido_3482@python.com'},
#  471: {'id': 7954,
#   'nombre': 'nombre_7954',
#   'apellido': 'apellido_7954',
#   'departamento': 10,
#   'sueldo': 11362.0,
#   'fecha': '2002-08-10',
#   'email': 'nombre_7954.apellido_7954@python.com'},
#  472: {'id': 1131,
#   'nombre': 'nombre_1131',
#   'apellido': 'apellido_1131',
#   'departamento': 8,
#   'sueldo': 17264.0,
#   'fecha': '2021-04-15',
#   'email': 'nombre_1131.apellido_1131@python.com'},
#  473: {'id': 206,
#   'nombre': 'nombre_206',
#   'apellido': 'apellido_206',
#   'departamento': 2,
#   'sueldo': 14829.0,
#   'fecha': '2023-10-27',
#   'email': 'nombre_206.apellido_206@python.com'},
#  474: {'id': 8323,
#   'nombre': 'nombre_8323',
#   'apellido': 'apellido_8323',
#   'departamento': 10,
#   'sueldo': 19395.0,
#   'fecha': '2001-08-06',
#   'email': 'nombre_8323.apellido_8323@python.com'},
#  475: {'id': 7445,
#   'nombre': 'nombre_7445',
#   'apellido': 'apellido_7445',
#   'departamento': 7,
#   'sueldo': 14664.0,
#   'fecha': '2004-01-01',
#   'email': 'nombre_7445.apellido_7445@python.com'},
#  476: {'id': 2042,
#   'nombre': 'nombre_2042',
#   'apellido': 'apellido_2042',
#   'departamento': 8,
#   'sueldo': 10419.0,
#   'fecha': '2018-10-17',
#   'email': 'nombre_2042.apellido_2042@python.com'},
#  477: {'id': 6034,
#   'nombre': 'nombre_6034',
#   'apellido': 'apellido_6034',
#   'departamento': 6,
#   'sueldo': 17398.0,
#   'fecha': '2007-11-12',
#   'email': 'nombre_6034.apellido_6034@python.com'},
#  478: {'id': 126,
#   'nombre': 'nombre_126',
#   'apellido': 'apellido_126',
#   'departamento': 5,
#   'sueldo': 19610.0,
#   'fecha': '2024-01-15',
#   'email': 'nombre_126.apellido_126@python.com'},
#  479: {'id': 7848,
#   'nombre': 'nombre_7848',
#   'apellido': 'apellido_7848',
#   'departamento': 6,
#   'sueldo': 10530.0,
#   'fecha': '2002-11-24',
#   'email': 'nombre_7848.apellido_7848@python.com'},
#  480: {'id': 5831,
#   'nombre': 'nombre_5831',
#   'apellido': 'apellido_5831',
#   'departamento': 6,
#   'sueldo': 11339.0,
#   'fecha': '2008-06-02',
#   'email': 'nombre_5831.apellido_5831@python.com'},
#  481: {'id': 5694,
#   'nombre': 'nombre_5694',
#   'apellido': 'apellido_5694',
#   'departamento': 3,
#   'sueldo': 16299.0,
#   'fecha': '2008-10-17',
#   'email': 'nombre_5694.apellido_5694@python.com'},
#  482: {'id': 2708,
#   'nombre': 'nombre_2708',
#   'apellido': 'apellido_2708',
#   'departamento': 7,
#   'sueldo': 10724.0,
#   'fecha': '2016-12-20',
#   'email': 'nombre_2708.apellido_2708@python.com'},
#  483: {'id': 6230,
#   'nombre': 'nombre_6230',
#   'apellido': 'apellido_6230',
#   'departamento': 9,
#   'sueldo': 18752.0,
#   'fecha': '2007-04-30',
#   'email': 'nombre_6230.apellido_6230@python.com'},
#  484: {'id': 1136,
#   'nombre': 'nombre_1136',
#   'apellido': 'apellido_1136',
#   'departamento': 4,
#   'sueldo': 15554.0,
#   'fecha': '2021-04-10',
#   'email': 'nombre_1136.apellido_1136@python.com'},
#  485: {'id': 4594,
#   'nombre': 'nombre_4594',
#   'apellido': 'apellido_4594',
#   'departamento': 6,
#   'sueldo': 12421.0,
#   'fecha': '2011-10-22',
#   'email': 'nombre_4594.apellido_4594@python.com'},
#  486: {'id': 7551,
#   'nombre': 'nombre_7551',
#   'apellido': 'apellido_7551',
#   'departamento': 3,
#   'sueldo': 16163.0,
#   'fecha': '2003-09-17',
#   'email': 'nombre_7551.apellido_7551@python.com'},
#  487: {'id': 7942,
#   'nombre': 'nombre_7942',
#   'apellido': 'apellido_7942',
#   'departamento': 6,
#   'sueldo': 14973.0,
#   'fecha': '2002-08-22',
#   'email': 'nombre_7942.apellido_7942@python.com'},
#  488: {'id': 4770,
#   'nombre': 'nombre_4770',
#   'apellido': 'apellido_4770',
#   'departamento': 3,
#   'sueldo': 12443.0,
#   'fecha': '2011-04-29',
#   'email': 'nombre_4770.apellido_4770@python.com'},
#  489: {'id': 6717,
#   'nombre': 'nombre_6717',
#   'apellido': 'apellido_6717',
#   'departamento': 10,
#   'sueldo': 18979.0,
#   'fecha': '2005-12-29',
#   'email': 'nombre_6717.apellido_6717@python.com'},
#  490: {'id': 8339,
#   'nombre': 'nombre_8339',
#   'apellido': 'apellido_8339',
#   'departamento': 1,
#   'sueldo': 19140.0,
#   'fecha': '2001-07-21',
#   'email': 'nombre_8339.apellido_8339@python.com'},
#  491: {'id': 9566,
#   'nombre': 'nombre_9566',
#   'apellido': 'apellido_9566',
#   'departamento': 5,
#   'sueldo': 17240.0,
#   'fecha': '1998-03-12',
#   'email': 'nombre_9566.apellido_9566@python.com'},
#  492: {'id': 4233,
#   'nombre': 'nombre_4233',
#   'apellido': 'apellido_4233',
#   'departamento': 4,
#   'sueldo': 13245.0,
#   'fecha': '2012-10-17',
#   'email': 'nombre_4233.apellido_4233@python.com'},
#  493: {'id': 3735,
#   'nombre': 'nombre_3735',
#   'apellido': 'apellido_3735',
#   'departamento': 10,
#   'sueldo': 19986.0,
#   'fecha': '2014-02-27',
#   'email': 'nombre_3735.apellido_3735@python.com'},
#  494: {'id': 7097,
#   'nombre': 'nombre_7097',
#   'apellido': 'apellido_7097',
#   'departamento': 9,
#   'sueldo': 19626.0,
#   'fecha': '2004-12-14',
#   'email': 'nombre_7097.apellido_7097@python.com'},
#  495: {'id': 996,
#   'nombre': 'nombre_996',
#   'apellido': 'apellido_996',
#   'departamento': 4,
#   'sueldo': 18997.0,
#   'fecha': '2021-08-28',
#   'email': 'nombre_996.apellido_996@python.com'},
#  496: {'id': 7485,
#   'nombre': 'nombre_7485',
#   'apellido': 'apellido_7485',
#   'departamento': 3,
#   'sueldo': 10201.0,
#   'fecha': '2003-11-22',
#   'email': 'nombre_7485.apellido_7485@python.com'},
#  497: {'id': 6188,
#   'nombre': 'nombre_6188',
#   'apellido': 'apellido_6188',
#   'departamento': 3,
#   'sueldo': 11632.0,
#   'fecha': '2007-06-11',
#   'email': 'nombre_6188.apellido_6188@python.com'},
#  498: {'id': 5634,
#   'nombre': 'nombre_5634',
#   'apellido': 'apellido_5634',
#   'departamento': 1,
#   'sueldo': 11698.0,
#   'fecha': '2008-12-16',
#   'email': 'nombre_5634.apellido_5634@python.com'},
#  499: {'id': 4716,
#   'nombre': 'nombre_4716',
#   'apellido': 'apellido_4716',
#   'departamento': 10,
#   'sueldo': 14708.0,
#   'fecha': '2011-06-22',
#   'email': 'nombre_4716.apellido_4716@python.com'},
#  500: {'id': 6898,
#   'nombre': 'nombre_6898',
#   'apellido': 'apellido_6898',
#   'departamento': 1,
#   'sueldo': 16191.0,
#   'fecha': '2000-08-03',
#   'email': 'nombre_6898.apellido_6898@python.com'}}

# %% [markdown]
# Ejecutando el código anterior comprobamos que se nos ha añadido un elemento a nuestro diccionario *empleados_db* y sus datos concuerdan con los valores generados aleatoriamente, por lo que podemos decir que nuestra función funciona correctamente.

# %%
##############################################################################################################################
